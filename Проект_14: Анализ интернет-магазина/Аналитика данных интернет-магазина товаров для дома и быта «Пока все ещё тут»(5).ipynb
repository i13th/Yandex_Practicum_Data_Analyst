# %% [markdown]
# # Аналитика данных интернет-магазина товаров для дома и быта «Пока все ещё тут»

# %% [markdown]
# ## Описание проекта

# %% [markdown]
# Целью исследования является анализ пользовательского опыта в интернет-магазине товаров для дома и быта «Пока все ещё тут».
#
# Интернет-магазин товаров для дома «Пока все ещё тут» в срочном порядке ищет аналитиков. Вы поможете нашему магазину стать лучше, а клиентам — обустроить дом своей мечты. Наши ближайшие задачи — расчёт метрик и создание гипотез на основе полученных данных.
#
# «Пока все ещё тут» — мы создаём уют!

# %% [markdown]
# ## Описание данных

# %% [markdown]
# Датасет описывает транзакции интернет-магазина товаров для дома и быта «Пока все ещё тут».
#
# Путь к файлу: /datasets/ecom_dataset_upd.csv
#
# Набор данных включает следующие поля:
#
# * date — дата заказа;
# * customer_id — идентификатор покупателя;
# * order_id — идентификатор заказа;
# * product — наименование товара;
# * quantity — количество товара в заказе;
# * price — цена товара.

# %% [markdown]
# ## Цели исследования

# %% [markdown]
# Выявление профилей потребления покупателей и их сегментация.
#
# Цели проекта:
#
# * провести исследовательский анализ данных;
# * проанализировать торговый ассортимент;
# * сегментировать покупателей на основе истории их покупок;
# * сформулировать и проверить статистические гипотезы.

# %% [markdown]
# ## План проекта

# %% [markdown]
# ### Шаг 1. Загрузка данных

# %% [markdown]
# * Импортирование библиотек;
# * Импортирование данных в датасет;
# * Просмотр и анализ данных датасета;
# * Вывод.

# %% [markdown]
# ### Шаг 2. Предобработка данных

# %% [markdown]
# * Просмотр и обработка аномалий в данных;
# * Добавление нужных столбцов;
# * Вывод.

# %% [markdown]
# ### Шаг 3. Исследовательский анализ данных

# %% [markdown]
# * Проведем категоризацию наименования товара;
# * Составим рейтинг по самым продаваемым товарам в каждой категории по количеству заказов;
# * Составим рейтинг по самым прибыльным товарам в каждой категории;
# * Посмотрим сезонность товаров по категориям и проанализируем продажи категорий товаров по временам года;
# * Посчитаем выручку и количество покупателей по категориям;
# * Вывод.

# %% [markdown]
# ### Шаг 4. Сегментация покупателей на основе истории их покупок

# %% [markdown]
# * Сделаем кластеризацию;
# * Обучим модель кластеризации алгоритмом K-Means;
# * Спрогнозируем сегменты покупателей;
# * Выведем статистику по кластерам;
# * Вывод.

# %% [markdown]
# ### Шаг 5. Проверка статистических гипотез

# %% [markdown]
# 1. Гипотеза. Статистическая значимость различий в среднем чеке заказа между сегментами покупателей присутствует.
#
# Сформулируем нулевую и альтернативную гипотезы:
#
# H0: Статистическая значимость различий в среднем чеке заказа между сегментами покупателей отсутствует.
#
# H1: Статистическая значимость различий в среднем чеке заказа между сегментами покупателей присутствует.
#
# 2. Гипотеза. Статистическая значимость различий в среднем объёме продаж между сегментами присутствует.
#
# Сформулируем нулевую и альтернативную гипотезы:
#
# H0: Статистическая значимость различий в среднем объёме продаж между сегментами отсутствует.
#
# H1: Статистическая значимость различий в среднем объёме продаж между сегментами присутствует.
#
# 3. Вывод.

# %% [markdown]
# ### Общие выводы и рекомендации

# %% [markdown]
# ### Презентация

# %% [markdown]
# ## Шаг 1. Загрузка данных

# %%
# Импортируем библиотеки.

import pandas as pd
import numpy as np
import seaborn as sns; sns.set()
import scipy.stats as stats
import scipy.stats as st
import matplotlib.pyplot as plt
# %matplotlib inline
import math as mth
from pymystem3 import Mystem
from collections import Counter
import os
import itertools
import plotly.express as px
import requests
import re
import datetime as dt
from scipy.stats import kruskal
from statsmodels.stats.multitest import multipletests
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from scipy.cluster import hierarchy
from sklearn.metrics import silhouette_score
from statsmodels.stats.multitest import multipletests
from matplotlib import gridspec
from scipy.stats import shapiro, levene

import warnings
warnings.filterwarnings('ignore')

# %%
# Импортируем данные в датасет.

try:
    ecom_online = pd.read_csv('/datasets/ecom_dataset_upd.csv', sep=',')
except:
    ecom_online = pd.read_csv('https://code.s3.yandex.net/datasets/ecom_dataset_upd.csv', sep=',')

# %%
# Проверяем и выводим данные.

def inspect(df):
    pd.set_option('display.float_format', '{:.2f}'.format)
    pd.options.display.max_colwidth = 120
    display(df.head(15)) 
    df.info()
    print ('Количество дубликатов -', df.duplicated().sum())
    print ('Количество пропусков:')
    print(df.isna().sum())
    numeric_columns=df.describe().columns
    display(df.describe())
    display()
    df.columns = [x.lower().replace(' ', '_') for x in df.columns.values]
    for column_name in df.columns:
        if column_name not in numeric_columns:
            if 'session' in column_name or 'dt' in column_name:
                df[column_name] = pd.to_datetime(df[column_name])
            else:
                display(df[column_name].value_counts())
                print(50*'*')
    return df
ecom_online = inspect(ecom_online)
# Out:
#           date                           customer_id  order_id  \
# 0   2018100100  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 1   2018100100  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 2   2018100100  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 3   2018100100  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 4   2018100100  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 5   2018100100  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 6   2018100100  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 7   2018100108  375e0724-f033-4c76-b579-84969cf38ee2     68479
# 8   2018100108  6644e5b4-9934-4863-9778-aaa125207701     68478
# 9   2018100109  c971fb21-d54c-4134-938f-16b62ee86d3b     68480
# 10  2018100111  161e1b98-45ba-4b4e-8236-e6e3e70f6f7c     68483
# 11  2018100112  86432d8d-b706-463b-bd5d-6a9e170daee3     68484
# 12  2018100113  4d93d3f6-8b24-403b-a74b-f5173e40d7db     68485
# 13  2018100115  0948b0c2-990b-4a11-b835-69ac4714b21d     68486
# 14  2018100116  a576fa59-7b28-4a4c-a496-92f128754a94     68487
#
#                                                                                       product  \
# 0                                             Комнатное растение в горшке Алое Вера, d12, h30
# 1                                          Комнатное растение в горшке Кофе Арабика, d12, h25
# 2                                                                 Радермахера d-12 см h-20 см
# 3                                                            Хризолидокарпус Лутесценс d-9 см
# 4                                                              Циперус Зумула d-12 см h-25 см
# 5                                                                     Шеффлера Лузеана d-9 см
# 6                                                            Юкка нитчатая d-12 см h-25-35 см
# 7                                             Настенная сушилка для белья Gimi Brio Super 100
# 8                                    Таз пластмассовый 21,0 л круглый "Водолей" С614, 1404056
# 9                    Чехол для гладильной доски Colombo Persia Beige 130х50 см из хлопка 5379
# 10  Вешалка для брюк металлическая с резиновым покрытием 26 см цвет: синяя, Attribute, AHS331
# 11                           Сушилка для белья потолочная Zalger Lift Basic 1520 200 см, 10 м
# 12                           Чехол Eurogold Clean Basic хлопок для досок 120х38-120х42 см C42
# 13         Крючок одежный 2-х рожковый серый металлик с полимерным покрытием *Тонар*, 1110027
# 14                                         Корзина мягкая пластиковая 17 л, М-пластика, M2880
#
#     quantity  price
# 0          1 142.00
# 1          1 194.00
# 2          1 112.00
# 3          1 179.00
# 4          1 112.00
# 5          1 164.00
# 6          1 134.00
# 7          1 824.00
# 8          1 269.00
# 9          1 674.00
# 10        10  82.00
# 11         1 614.00
# 12         1 187.00
# 13        96  38.00
# 14         1 188.00
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7474 entries, 0 to 7473
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         7474 non-null   int64
#  1   customer_id  7474 non-null   object
#  2   order_id     7474 non-null   int64
#  3   product      7474 non-null   object
#  4   quantity     7474 non-null   int64
#  5   price        7474 non-null   float64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 350.5+ KB
# Количество дубликатов - 0
# Количество пропусков:
# date           0
# customer_id    0
# order_id       0
# product        0
# quantity       0
# price          0
# dtype: int64
#                date  order_id  quantity    price
# count       7474.00   7474.00   7474.00  7474.00
# mean  2018912614.03  49449.88      2.36   478.74
# std       427887.84  32679.64     14.50   901.62
# min   2018100100.00  12624.00      1.00     9.00
# 25%   2019021713.00  14833.00      1.00    97.00
# 50%   2019051409.00  68768.00      1.00   135.00
# 75%   2019063013.00  71257.75      1.00   439.00
# max   2020013115.00 112789.00   1000.00 14917.00
# 1d6c8c1f-a799-4418-9af2-1ded47d7a85c    888
# db77c238-3c80-4032-9e3c-c30a43f4a650    203
# c971fb21-d54c-4134-938f-16b62ee86d3b    144
# 3d5fef90-4a65-4a7e-84cf-010eba7b038d     90
# 42d3cb27-6519-4627-9b4a-5aa8ee600203     63
#                                        ...
# eb8a6adb-9211-4973-97c4-85f4f2695363      1
# 21b4642e-9cdf-4738-a290-b42d3e748c0f      1
# 43cd72d6-40ff-49e7-bcb2-79e3a176c48f      1
# e43ca8b0-1ca5-4ab5-a77f-5038dfcd6d59      1
# 96c574af-cb6e-4e5c-8b67-07c46115a7c2      1
# Name: customer_id, Length: 2451, dtype: int64
# **************************************************
# Рассада Кабачка сорт Зебра кассета 6 шт E6                                    79
# Рассада Кабачка сорт Золотинка кассета 6 шт E6                                78
# Рассада Кабачка сорт Белогор кассета 6 шт E6                                  77
# Пеларгония розебудная Red Pandora укорененный черенок                         77
# Рассада Кабачка сорт Аэронавт, кассета по 6шт                                 76
#                                                                               ..
# Коврик для ванной комнаты FOCUS акрил 90х60 см зеленый, Spirella, 1014213      1
# Термостакан WEBBER ВЕ-6031 ЧАЙ 450 мл                                          1
# Вешалка-плечики 3 шт без эссенции цвет светло-бирюзовый FWM-002/Aruba blue     1
# Фаленопсис королевский Голубой 1 ствол d-12 см                                 1
# Рассада томата (помидор) сорт Золотое руно, кассета по 6шт                     1
# Name: product, Length: 2343, dtype: int64
# **************************************************

# %%
# Для наглядности построим гистограммы по некоторым данным

ecom_online.hist(figsize=(20, 15));

# %% [markdown]
# **Вывод:**
#
# В датасете ecom_online присутствует 6 столбцов, и он состоит из 7474 наблюдений. Вес 350.5+ KB.
#
# Дубликаты и пропуски отсутствуют. Названия столбцов в датаcете уже приведены к нижнему регистру и нужному формату.
#
# Нужно будет заменит типы данных для столбца date. Также, нужно будет проверить датасет на неявные дубликаты.

# %% [markdown]
# ## Шаг 2. Предобработка данных

# %%
# Приведем столбцы с датой в нужный формат.

ecom_online['date'] = pd.to_datetime(ecom_online['date'], format='%Y%m%d%H')

# %%
# Проверим, за какой период предоставлены данные.

ecom_online['date'].dt.year.unique()
# Out:
# array([2018, 2019, 2020])

# %% [markdown]
# Данные предоставлены за 2018, 2019 и 2020 года.

# %%
# Проверим минимальные и максимальные даты.

print(min(ecom_online['date']))
print(max(ecom_online['date']))
# Out:
# 2018-10-01 00:00:00
# 2020-01-31 15:00:00

# %% [markdown]
# Данные в датасете даются от 01.10.2018 по 31.01.2020.

# %% [markdown]
# **Создадим отдельно колонки с месяцем и годом**

# %%
ecom_online['year_month'] = pd.to_datetime(ecom_online['date']).dt.strftime('%Y-%m')
ecom_online['month'] = pd.to_datetime(ecom_online['date']).dt.strftime('%m')
ecom_online['year'] = pd.to_datetime(ecom_online['date']).dt.strftime('%Y')

# %%
# Проверим.

ecom_online.head()
# Out:
#         date                           customer_id  order_id  \
# 0 2018-10-01  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 1 2018-10-01  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 2 2018-10-01  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 3 2018-10-01  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 4 2018-10-01  ee47d746-6d2f-4d3c-9622-c31412542920     68477
#
#                                               product  quantity  price  \
# 0     Комнатное растение в горшке Алое Вера, d12, h30         1 142.00
# 1  Комнатное растение в горшке Кофе Арабика, d12, h25         1 194.00
# 2                         Радермахера d-12 см h-20 см         1 112.00
# 3                    Хризолидокарпус Лутесценс d-9 см         1 179.00
# 4                      Циперус Зумула d-12 см h-25 см         1 112.00
#
#   year_month month  year
# 0    2018-10    10  2018
# 1    2018-10    10  2018
# 2    2018-10    10  2018
# 3    2018-10    10  2018
# 4    2018-10    10  2018

# %% [markdown]
# **Проверим наличие неявных дубликатов**

# %%
duplicates_all = ecom_online.duplicated().sum()
duplicates = len(ecom_online
                 [ecom_online[
                     ['product', 
                      'customer_id', 
                      'order_id']].duplicated() == True][['product', 'order_id']])

print('Количество дубликатов: {}'.format(duplicates_all))
print('Количество неявных дубликатов: {}'.format(duplicates))
print('Доля дубликатов от общего количества: {:.2%}'.format((duplicates_all + duplicates)/len(ecom_online)))
# Out:
# Количество дубликатов: 0
# Количество неявных дубликатов: 1886
# Доля дубликатов от общего количества: 25.23%

# %% [markdown]
# 1886 неявных дубликатов - это скорее всего и есть то задвоение заказов о которых предупреждали, когда из интернета и из системы идет один и тот же заказ. Поэтому, предлагаю удалить задвоение.

# %%
# Удаляем дубликаты.

ecom_online = ecom_online.drop_duplicates(subset=['order_id', 'product'], keep='last').reset_index()

# %%
# Проверим.

ecom_online[['customer_id', 'order_id', 'product']].duplicated().sum()
# Out:
# 0

# %%
# Посмотрим заказы, в которых есть разные даты.

dates = ecom_online.groupby('order_id').agg({'date':'nunique'}).sort_values(by='date', ascending=False).query('date > 1')
print('Заказы, в которых несколько разных дат: {}'.format(len(dates)))
# Out:
# Заказы, в которых несколько разных дат: 16

# %% [markdown]
# Очень похоже на какие-то сбои при заказе, либо ошибку в записи данных. Поэтому, предлагаю также избавиться от таких заказов.

# %%
# Выделим их.

list_dates = list(dates.index)

# %%
# Удалим.

ecom_online = ecom_online.drop(ecom_online[ecom_online['order_id'].isin(list_dates)].index)

# %%
# В датасете есть один заказ на 1000 штук. Предлагаю посмотреть его.

ecom_online[ecom_online['quantity']==1000]
# Out:
#       index                date                           customer_id  \
# 3782   5456 2019-06-18 15:00:00  312e9a3e-5fca-43ff-a6a1-892d2b2d5ba6
#
#       order_id  \
# 3782     71743
#
#                                                                 product  \
# 3782  Вантуз с деревянной ручкой d14 см красный, Burstenmann, 0522/0000
#
#       quantity  price year_month month  year
# 3782      1000 675.00    2019-06    06  2019

# %%
# Проверим, покупал ли этот id еще что-то.

ecom_online[ecom_online['customer_id']=='312e9a3e-5fca-43ff-a6a1-892d2b2d5ba6']
# Out:
#       index                date                           customer_id  \
# 3782   5456 2019-06-18 15:00:00  312e9a3e-5fca-43ff-a6a1-892d2b2d5ba6
#
#       order_id  \
# 3782     71743
#
#                                                                 product  \
# 3782  Вантуз с деревянной ручкой d14 см красный, Burstenmann, 0522/0000
#
#       quantity  price year_month month  year
# 3782      1000 675.00    2019-06    06  2019

# %% [markdown]
# Скорее всего, это какой-то тестовый заказ для проверки системы. Он такой один и клиент под таким id больше не совершал покупок. Поэтому, предлагаю это наблюдение удалить.

# %%
# Удаляем.

ecom_online = ecom_online.drop(ecom_online[ecom_online['customer_id'] == '312e9a3e-5fca-43ff-a6a1-892d2b2d5ba6'].index)

# %%
# Проверим удаление.

ecom_online[ecom_online['customer_id']=='312e9a3e-5fca-43ff-a6a1-892d2b2d5ba6']
# Out:
# Empty DataFrame
# Columns: [index, date, customer_id, order_id, product, quantity, price, year_month, month, year]
# Index: []

# %%
# Подсчитаем количество заказов по покупателелям.

orders_per_customer = ecom_online.groupby('customer_id', as_index=False).agg({'order_id':'nunique'})
orders_per_customer.columns = ['customer_id', 'orders']

# %%
# Посчитаем 95-й и 99-й выборочные перцентили количества заказов по покупателелям.

percentiles = np.percentile(orders_per_customer['orders'], [95, 99])
print('95-й перцентиль количества заказов на покупателя: {} заказа'.format(percentiles[0]))
print('99-й перцентиль количества заказов на покупателя: {} заказа'.format(percentiles[1]))
# Out:
# 95-й перцентиль количества заказов на покупателя: 2.0 заказа
# 99-й перцентиль количества заказов на покупателя: 3.0 заказа

# %%
# Посмотрим аномальных пользователей.

anomaly_customers = pd.concat([orders_per_customer[orders_per_customer['orders']>3]['customer_id']], axis = 0)
print('Всего аномальных покупателей: {} покупателей'.format(len(anomaly_customers)))
# Out:
# Всего аномальных покупателей: 8 покупателей

# %%
# Отсеим аномальных пользователей.

ecom_online = ecom_online.query('customer_id not in @anomaly_customers')

# Посчитаем общее кол-во покупателей. 

customers = len(ecom_online['customer_id'].unique())
print("Всего покупателей за все время после отсеивания: {} покупателей".format(customers))
# Out:
# Всего покупателей за все время после отсеивания: 2407 покупателей

# %%
# Проверим датасет.

ecom_online.shape
# Out:
# (5192, 10)

# %%
# Добавим столбец с выручкой по заказам.

ecom_online['revenue'] = ecom_online['quantity'] * ecom_online['price']

# %%
# Проверим.

ecom_online.head(20)
# Out:
#     index                date                           customer_id  order_id  \
# 0       0 2018-10-01 00:00:00  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 1       1 2018-10-01 00:00:00  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 2       2 2018-10-01 00:00:00  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 3       3 2018-10-01 00:00:00  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 4       4 2018-10-01 00:00:00  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 5       5 2018-10-01 00:00:00  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 6       6 2018-10-01 00:00:00  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 7       7 2018-10-01 08:00:00  375e0724-f033-4c76-b579-84969cf38ee2     68479
# 8       8 2018-10-01 08:00:00  6644e5b4-9934-4863-9778-aaa125207701     68478
# 10     10 2018-10-01 11:00:00  161e1b98-45ba-4b4e-8236-e6e3e70f6f7c     68483
# 11     11 2018-10-01 12:00:00  86432d8d-b706-463b-bd5d-6a9e170daee3     68484
# 13     13 2018-10-01 15:00:00  0948b0c2-990b-4a11-b835-69ac4714b21d     68486
# 14     14 2018-10-01 16:00:00  a576fa59-7b28-4a4c-a496-92f128754a94     68487
# 17     22 2018-10-02 11:00:00  f08d9018-438e-4e96-b519-f74c0302a433     14480
# 18     23 2018-10-02 11:00:00  f08d9018-438e-4e96-b519-f74c0302a433     14480
# 19     24 2018-10-02 11:00:00  f08d9018-438e-4e96-b519-f74c0302a433     14480
# 20     25 2018-10-02 11:00:00  1bc8ad38-3392-4042-8cde-aa5de306c947     68494
# 21     26 2018-10-02 11:00:00  1bc8ad38-3392-4042-8cde-aa5de306c947     68494
# 22     27 2018-10-02 11:00:00  1bc8ad38-3392-4042-8cde-aa5de306c947     68494
# 23     28 2018-10-02 11:00:00  1bc8ad38-3392-4042-8cde-aa5de306c947     68494
#
#                                                                                       product  \
# 0                                             Комнатное растение в горшке Алое Вера, d12, h30
# 1                                          Комнатное растение в горшке Кофе Арабика, d12, h25
# 2                                                                 Радермахера d-12 см h-20 см
# 3                                                            Хризолидокарпус Лутесценс d-9 см
# 4                                                              Циперус Зумула d-12 см h-25 см
# 5                                                                     Шеффлера Лузеана d-9 см
# 6                                                            Юкка нитчатая d-12 см h-25-35 см
# 7                                             Настенная сушилка для белья Gimi Brio Super 100
# 8                                    Таз пластмассовый 21,0 л круглый "Водолей" С614, 1404056
# 10  Вешалка для брюк металлическая с резиновым покрытием 26 см цвет: синяя, Attribute, AHS331
# 11                           Сушилка для белья потолочная Zalger Lift Basic 1520 200 см, 10 м
# 13         Крючок одежный 2-х рожковый серый металлик с полимерным покрытием *Тонар*, 1110027
# 14                                         Корзина мягкая пластиковая 17 л, М-пластика, M2880
# 17                                     Многолетнее растение Тимьян-чабрец розовый объем 0,5 л
# 18                                     Рассада зелени для кухни Базилик Тонус, кассета по 6шт
# 19                                       Рассада зелени для кухни Мелиссы в горшке диам. 9 см
# 20                                    Муляж "Райские Яблочки Зеленые" 2 шт полиуретан, d 3 см
# 21                                Муляж Банан, желтый, 21 см, полиуретан, Fancy Fair/ff XJ210
# 22                                                   Муляж Виноград 14 см цвет в ассортименте
# 23                                       Муляж ГРАНАТ 9см, красный, Fancy Fair, SL90, красный
#
#     quantity  price year_month month  year  revenue
# 0          1 142.00    2018-10    10  2018   142.00
# 1          1 194.00    2018-10    10  2018   194.00
# 2          1 112.00    2018-10    10  2018   112.00
# 3          1 179.00    2018-10    10  2018   179.00
# 4          1 112.00    2018-10    10  2018   112.00
# 5          1 164.00    2018-10    10  2018   164.00
# 6          1 134.00    2018-10    10  2018   134.00
# 7          1 824.00    2018-10    10  2018   824.00
# 8          1 269.00    2018-10    10  2018   269.00
# 10        10  82.00    2018-10    10  2018   820.00
# 11         1 614.00    2018-10    10  2018   614.00
# 13        96  38.00    2018-10    10  2018  3648.00
# 14         1 188.00    2018-10    10  2018   188.00
# 17         1  89.00    2018-10    10  2018    89.00
# 18         1 169.00    2018-10    10  2018   169.00
# 19         1 101.00    2018-10    10  2018   101.00
# 20         1  29.00    2018-10    10  2018    29.00
# 21         1  59.00    2018-10    10  2018    59.00
# 22         1 104.00    2018-10    10  2018   104.00
# 23         1  59.00    2018-10    10  2018    59.00

# %% [markdown]
# **Вывод**
#
# Привели столбец с датой в нужный формат. Проверили, за какой период предоставлены данные - данные предоставлены с 2018-10-01 00:00:00 по 2020-01-31 15:00:00.
#
# При выявлении 1886 неявных дубликатов - удалили их, так как это скорее всего и есть то задвоение заказов о которых предупреждали, когда из интернета и из системы идет один и тот же заказ.
#
# Удалили заказы, в которых есть разные даты, так как это похоже на сбои при заказе, либо ошибку в записи данных и тестовый заказ для проверки системы на 1000 единиц одного наименования товара.
#
# Удалили заказы, в которых несколько разных дат и воспользовались 99м перцентилем, чтобы отсечь аномальных клиентов.
#
# Отдельно создали колонки с месяцем и годом. Также добавлен столбец с выручкой по заказам.

# %% [markdown]
# ## Шаг 3. Исследовательский анализ данных

# %% [markdown]
# **Проведем категоризацию наименования товара**

# %%
# Посмотрим уникальные значения и выведем леммы.

m = Mystem()
unique_product = ecom_online['product'].unique()
lemmas = []
for i in unique_product:
    result = ''.join(m.lemmatize(i)).strip()
    lemmas.append(result)
lemmas
# Out:
# ['комнатный растение в горшок алый вера, d12, h30',
#  'комнатный растение в горшок кофе арабика, d12, h25',
#  'радермахер d-12 см h-20 см',
#  'хризолидокарпус лутесценс d-9 см',
#  'циперус зумула d-12 см h-25 см',
#  'шеффлер лузеан d-9 см',
#  'юкка нитчатый d-12 см h-25-35 см',
#  'настенный сушилка для белье Gimi Brio Super 100',
#  'таз пластмассовый 21,0 л круглый "водолей" С614, 1404056',
#  'вешалка для брюки металлический с резиновый покрытие 26 см цвет: синий, Attribute, AHS331',
#  'сушилка для белье потолочный Zalger Lift Basic 1520 200 см, 10 м',
#  'крючок одежный 2-х рожковый серый металлик с полимерный покрытие *тонар*, 1110027',
#  'корзина мягкий пластиковый 17 л, м-пластика, M2880',
#  'многолетний растение тимьян-чабрец розовый объем 0,5 л',
#  'рассада зелень для кухня базилик тонус, кассета по 6шт',
#  'рассада зелень для кухня мелисса в горшок диам. 9 см',
#  'муляж "райский яблочко зеленый" 2 шт полиуретан, d 3 см',
#  'муляж банан, желтый, 21 см, полиуретан, Fancy Fair/ff XJ210',
#  'муляж виноград 14 см цвет в ассортимент',
#  'муляж гранат 9см, красный, Fancy Fair, SL90, красный',
#  'муляж груша мини 2 шт, желтый 4 см',
#  'муляж груша, желтый, 9,5 см, полиуретан, Fancy Fair/ff LI95-03',
#  'муляж зеленый яблоко полиуретан d-6 см',
#  'муляж клубника 1 шт полиуретан d-6 см',
#  'муляж клубника на магнит',
#  'муляж красный яблоко мини полиуретан d-6 см',
#  'муляж лимон, желтый, 9 см, полиуретан, Fancy Fair/ff NM90',
#  'муляж мандарин, оранжевый, 8 см, полиуретан, Fancy Fair/ff JZ80',
#  'муляж перец, зеленый, 10 см, полиуретан, Fancy Fair/ff GP8',
#  'муляж перец, красный, 10 см, полиуретан, Fancy Fair/ff RP8',
#  'муляж персик мини полиуретан d-6 см',
#  'муляж томат, оранжевый, 9 см, полиуретан, Fancy Fair/ff T9',
#  'муляж черешня 3см 10 шт., желтый, Fancy Fair, SCR30/10, желтый',
#  'сумка для тележка большой комбинированный 45*30*25, 1209021',
#  'тарелка обеденный лимон фиц 25см, G9547, Luminarc, франция',
#  'ерш для туалет с подставка MALIBU фарфор 47х12,5 см белый, Spirella, 1001768',
#  'пеларгония зональный диам. 12 см малиновый с красный полумахровый',
#  'пеларгония зональный диам. 12 см сиреневый-красный простой',
#  'пеларгония зональный диам. 12 см сиреневый полумахровый',
#  'пеларгония зональный диам. 12 см сиреневый простой',
#  'сушилка для белье настенный Zalger Prima 510-720 веревочный 7 линия 25 м',
#  'котел алюминиевый 70,0 л без крышка балезино, хозлэнд, 1502050',
#  'суккулент микс d-5 см',
#  'эхеверие перл фон нюрнберг d-7 см',
#  'доска гладильный Eurogold Professional 130х48 см металлический сетка 35748W',
#  'коврик придверный 45х75см. с рельефный рисунок "Welcome", коричневый, CR005',
#  'коврик Bacchetta MagicStop 0,3x1,5 м бежевый для сушка посуда 2289',
#  'корзина для гладить белье Natural Style, 45 л, 27*38*59 см, коричневый, D 00708-213, Curver 00708-213',
#  'корзина пластиковый для белье 60л. с крышка бежевый 1860/2, виолета',
#  'подкладка под чехол Zalger 520140 135х50 см поролон',
#  'набор кружка для пиво гамбург 2шт 500мл, H5072, Luminarc, россия',
#  'коврик интерьерный для кухня Village Street Floral из пвх прямоугольный 50х107 см, Apache, 4663',
#  'дозатор для мыло Hausmann белый HM-B0194R-2',
#  'ерш унитазный с подставка WC "стандарт", мультипласт 1712010',
#  'нож для чистка овощ WEBBER из нержавеющий сталь 12х6,8х1,5 см ВЕ-5275',
#  'подкладка под чехол Zalger 520114 135х50 см войлок',
#  'муляж виноград, желтый, 24 см, полиуретан, Fancy Fair/G60-Y',
#  'муляж виноград, зеленый, 26 см, полиуретан, Fancy Fair/G85-G',
#  'муляж виноград, черный, 26 см, полиуретан, Fancy Fair/G85-B',
#  'муляж вишня, вишневый, 3 см, 10 шт, полиуретан, Fancy Fair/ff CR30/10',
#  'муляж груша, желтый, 9,5 см, полиуретан, Fancy Fair/ff LI95-01',
#  'муляж персик, оранжевый, 9 см, полиуретан, Fancy Fair/ff TZ90',
#  'набор фужер Luminarc дампьер сильвер для вино 260 мл 6 шт H7939',
#  'цветок искусственный гвоздик тканевый красный 50 см',
#  'эвкалипт гунни d-17 см h-60 см',
#  'сумка-тележка хозяйственный Gimi Market желтый',
#  'герань домашний (пеларгония зональный) цвести , D12, H25-30, красный, махровый',
#  'сумка-тележка хозяйственный Andersen Scala Shopper Plus, Elba, черный 133-051-80',
#  'сумка-тележка хозяйственный Rolser Jet Cuadro MH Joy серо-желтый, JET019 marengo JOY',
#  'плед флисовый 100% полиэстер 185х240 см бежевый, Wellness, WP184-айленд_2',
#  'скатерть династия 100% полиэфир прямоугольный 350х180 см сливочный, Wellness, WT355-династия*02',
#  'герань домашний (пеларгония зональный) цвести D12, H25-30, лососевый, махровый',
#  'коврик хлопковый 40х60 см цвет в ассортимент 6194',
#  'коврик хлопковый 45х75 см цвет в ассортимент 6195',
#  'сушилка для белье на батарея, СБ5-45, ника',
#  'кувшин пластмассовый с крышка "кумган" 2,0 л 1408003',
#  'вилка столовая RIPPLE сталь 3 мм, 3 шт, Attribute, ACR013',
#  'ложка столовая RIPPLE сталь 3 мм, 3 шт, Attribute, ACR023',
#  'ложка чайная RIPPLE сталь 2,5 мм, 3 шт, Attribute, ACR033',
#  'нож столовый RIPPLE 80 г 2 шт, Attribute, ACR042',
#  'муляж перец чили в связка, зеленый, 60 см, полиуретан, Fancy Fair/ff GP60',
#  'адиантум лиза d-12 см',
#  'герань домашний (пеларгония зональный) цвести D12, H25-30, белый, махровый',
#  'герань домашний (пеларгония зональный) цвести D12, H25-30, коралловый, полумахровый',
#  'ковер придверный "MULTY RUS" 120х180см., коричневый, РР214/07034',
#  'перчатка латексный № 3 для дом утолщенный, Rozenbal, R105628',
#  'стремянка алюминиевый Hailo 4302-301 LivingStep Comfort PLus 2 ступенчатый алюминиевый',
#  'пеларгония зональный диам. 12 см темнорозовый полумахровый',
#  'гладильный доска Gimi Jean Green Line 107х30 см',
#  'сумка-тележка хозяйственный Gimi Market синий',
#  'лестница-стремянка Dogrular Ufuk оцинковывать 7-ми ступенчатый',
#  'сумка-тележка 2-х колесный Gimi Argo синий',
#  'толкушка для картофель из нержавеющий сталь Proline, Leifheit, 03032',
#  'искусственный цветок роза маргарита пластик 58 см',
#  'ерш для бутылка из натуральный волокно и металл 23 см кремовый, Burstenmann, 0473/0003',
#  'набор вешалка для костюм 45см 4шт цвет: кремовый, Attribute, AHP224',
#  'таз пластмассовый 20,0 л пищевой овальный "Ekko" 2776, 1404043',
#  'сушилка для белье потолочно-настенный Gimi Lift 220, 5030',
#  'таз пластмассовый 15,0 л пищевой овальный "Ekko" 2775, 1404032',
#  'таз пластмассовый 18,0 л пищевой (Иж), 1404047',
#  'таз пластмассовый 20,0 л пищевой (минеральный вода), 1404045',
#  'таз пластмассовый 24,0 л пищевой круглый (Иж), 1404006',
#  'настенный сушилка для белье Gimi Brio Super 60',
#  'сушилка для белье потолочный лиана 2,2 м 1703010',
#  'банка со стеклянный крышка, COLOR SERIES, круглый, 10*10*12 см, 300 мл VALIANT, JP-S300',
#  'банка со стеклянный крышка, COLOR SERIES, круглый, 7*7,6*12,5 см, 280 мл VALIANT, JP-S280',
#  'сумка-тележка 3-х колесный Gimi Tris Floral синий',
#  'набор ковер для ванный комната, "офелия", 40х50/50х80см., серый/бежевый, NTBM50804050-26-190',
#  'сушилка для белье виолета Ricko 5м Rk-5/100 настенный',
#  'комплект для ванный и туалет Dasch 50х80 см и 55х55 см TL-2-E лавр бежевый 5755',
#  'стяжка оконный с болт ст-55 цинк, 1108354',
#  'муляж апельсин 8 см полиуретан',
#  'муляж яблоко зеленый 9 см полиуретан',
#  'сумка-тележка хозяйственный Welfull Daisy, черный 100-002-80',
#  'кампануть махровый двухцветный d-10 см',
#  'пеларгония душистый d-13 см',
#  'сушилка для белье Gimi Alablock',
#  'тележка багажный DELTA ТБР-22 синий грузоподъемность 20 кг сумка и 50 кг каркас россия',
#  'пеларгония зональный диам. 12 см красный махровый',
#  'пеларгония зональный диам. 12 см ярко красный махровый',
#  'пеларгония зональный махровый белый',
#  'сумка-тележка хозяйственный Rolser Jet C. Capri Joy синий, JET017 azul JOY',
#  'противень прямоугольный алюминиевый 340х240х25 см эксперт, Scovo, СЭ-052, /1503028',
#  'сушилка для белье потолочно-настенный Gimi Lift 180',
#  'герань домашний (пеларгония зональный) цвести D12, H25-30, малиновый, махровый',
#  'калатея микс d-12 см',
#  'коврик придверный влаговпитывать ребристый из полимерный материал 90х120 см серый, Vortex, K041',
#  'нолина в цветной керамика d-7 см',
#  'плечики пластмассовый (размер 48 - 54 ) "мп", 1205160',
#  'подушка декоративный флисовый 100% полиэстер 40*40 см синий клетка, Wellness, WP44-атланта_34',
#  'полотенце кухонный мила* mix, 100% хлопок 170 г/м2, 38х63,5 см, цвет в ассортимент, Wellness, 4630005366090',
#  'хлорофитум d-13 см',
#  'цикламен d-13 см',
#  'пеларгония зональный диам. 12 см розовый полумахровый',
#  'пеларгония зональный диам. 12 см розовый с малиновый полумахровый',
#  'пеларгония зональный диам. 12 см розовый-малиновый простой',
#  'пеларгония зональный махровый лососевый',
#  'герань домашний (пеларгония зональный) цвести D12, H25-30, малиновый с красный, полумахровый',
#  'глоксиния d-13 см',
#  'азалий индик биколор d-12 см',
#  'гортензия микс d-12 см',
#  'хризантема космо микс d-12 см',
#  'сушилка для белье потолочный лиана 1,6 м 1703005',
#  'муляж тыква d-8 см',
#  'герань домашний (пеларгония зональный) цвести D12, H25-30, розовый с малиновый, полумахровый',
#  'герань домашний (пеларгония зональный) цвести D12, H25-30, розовый, махровый',
#  'герань домашний (пеларгония зональный) цвести D12, H25-30, розовый-красный, полумахровый',
#  'герань домашний (пеларгония зональный) цвести D12, H25-30, розовый-малиновый, простой',
#  'герань домашний (пеларгония зональный) цвести D12, H25-30, сиреневый-красный, простой',
#  'герань домашний (пеларгония зональный) цвести D12, H25-30, сиреневый, простой',
#  'герань домашний (пеларгония зональный) цвести D12, H25-30, темнорозовый, полумахровый',
#  'герань домашний (пеларгония зональный) цвести D12, H25-30, ярко красный, махровый',
#  'коврик интерьерный для кухня Tuscan Wine из пвх прямоугольный 45х75 см, Apache, 4660',
#  'сушилка для белье Gimi Lampo',
#  'гладильный доска ника верона 1 чехол одри 122х42 см ДВ1о',
#  'стеклянный крышка для сковорода ALPENKOK 24 см AK-24GL',
#  'стеклянный крышка для сковорода ALPENKOK 28 см AK-28GL',
#  'салфетка Protec Textil Lino 30х43 см серый 6226',
#  'чехол Eurogold Clean Metallic металлизированый с поролон для доска 110х30-114x34 см C34F3M',
#  'вкладыш для хранение посуда 2 шт d-38 cm MARMITON, LG17056',
#  'миксер DELTA LUX DL-5068 серо-голубой 400 вт 4 насадка 5 скоростной режим турбореживать',
#  'коврик влаговпитывающий индия 50*80 см зигзаг серый 6204',
#  'кофр для хранение медикамент Hausmann 9 отделение 30x22x12 см 4W-107',
#  'стиральный биопорошок BONSAI концентрировать для белый белье россия 4607974420573',
#  'чистить крем для трудновыводимый пятно Mama Lemon stain remover 500 гр индонезия 8998866106207',
#  'термокружок AVEX Recharge 500 мл голубой AVEX0681',
#  'щетка для смахивание пыль 60 см разноцветный, Burstenmann, 0528/0000',
#  'мирт d-20 см h-25 см',
#  'цветущий комнатный растение хризантема диаметр горшок 18 см',
#  'чехол для гладильный доска Zalger 520138 140х50 см металлизированный с поролон для доска 135х45 см',
#  'крепеж для пружина дверной, 1107055',
#  'пружина дверной 240 мм оцинковывать (д-19 мм) без крепление, 1107014',
#  'сушилка для белье потолочно-настенный Gimi Lift 240, 5031',
#  'таз пластмассовый со стиральный доска (Иж), 1404021',
#  'мини-сковорода Marmiton "сердце" с антипригарный покрытие 12 см, LG17085',
#  'сковорода алюминиевый с антипригарный покрытие MARBLE ALPENKOK d = 26 см AK-0039A/26N',
#  'стеклянный крышка для сковорода ALPENKOK 26 см AK-26GL',
#  'сушилка для белье напольный Colombo Star 18, 3679',
#  'герань домашний (пеларгония зональный) цвести D12, H25-30, белый, полумахровый',
#  'кориандр в кассета 6 шт',
#  'рассада зелень для кухня базилик арарат, кассета по 6шт',
#  'рассада зелень для кухня петрушка универсал, кассета по 6шт',
#  'рассада зелень для кухня шалфей в горшок диам. 9 см',
#  'чехол для одежда EVA 60х95 см EVE4214',
#  'чехол для одежда Hausmann розовый принт 60х100 см HM-EA1104',
#  'чехол для платье из неткать материал 60*135 см белый, Hausmann, 2B-360135',
#  'сушилка для белье потолочный лиана 2,4 м 1703011',
#  'герань домашний (пеларгония зональный) цвести D12, H25-30, малиновый розовый, простой',
#  'жидкий мыло Vestar хозяйственный 750 мл россия 4620757212370',
#  'ковер придверный "лапша" 60х90см коричневый',
#  'коврик резиновый ажурный Iron Grill 45х75 см 6207',
#  'пена для ванна Vestar хвойный пихта 900 мл россия 4620757212424',
#  'тележка хозяйственный складной, ТХ0253, 50 кг, пэмби',
#  'таз пластмассовый 10,0 л круглый (350х170) "м- пластик" М2506, 1404091',
#  'таз пластмассовый 13,0 л пищевой с мерка (минеральный вода), 1404028',
#  'таз пластмассовый 14,0 л пищевой (Иж), 1404079',
#  'таз пластмассовый 15,0 л пищевой (минеральный вода), 1404038',
#  'таз пластмассовый 16,0 л круглый С12129, 1404034',
#  'таз пластмассовый 16,0 л пищевой с ручка (С203/303) "полимербыт", 1404039',
#  'гладильный доска ника Haushalt M HM 122х40 см',
#  'подрукавник складной ника п',
#  'штора со встроенный кольцо под штанга для ванна и душа жаккард, полиамидный покрытие, 180х200, аквамарин, HSC/ST04/aquamarin',
#  'штора со встроенный кольцо под штанга для ванна и душа жаккард, полиамидный покрытие, 180х200, голубой, HSC/ST12/blue',
#  'штора со встроенный кольцо под штанга для ванна и душа жаккард, полиамидный покрытие, 180х200, бежевый, HSC/ST05/beige',
#  'штора со встроенный кольцо под штанга для ванна и душа жаккард, полиамидный покрытие, 180х200, белый, HSC/ST04/white',
#  'сушилка для белье на батарея, СБ5-65, ника',
#  'сушилка для белье Attribute мини 2,5 м навесный ADM125',
#  'аспарагус d-12 см h-30 см',
#  'афеляндр скуаррос дания микс в кашпо с автополив',
#  'набор свереть по дерево из 8 шт, 3-10 мм *888* 6867540, 0512261',
#  'сверло-фреза, 6 мм, нитрид титан *888* 6862060, 0512262',
#  'сверло-фреза, 8 мм, нитрид титан *888* 6862080, 0512263',
#  'пеларгония зональный диам. 12 см лососевый махровый',
#  'гладильный доска дсп "бэлль-ЮНИОР2", 112*34,5, БЮ2, ника',
#  'контейнер для овощ полимербыт 3-х секционный лоток 9 л 4312600',
#  'сушилка для белье лиана люкс 130 см потолочный',
#  'стремянка алюминиевый 5 ступень, СА5, ника',
#  'чехол для гладильный доска UNIVERSAL 160х60 см, Attribute, ABU004',
#  'гладильный доска Sarayli Orion 130x44 см',
#  'мусорный контейнер Hailo ProfiLine SoLid 14 0514-089 14 л белый',
#  'гладильный доска перф металл "ника 10+", 122*40, Н10+, ника',
#  'сушилка для белье RAINBOW COLOR напольный из хромировать сталь 201,5х55х93 см, Gimi',
#  'зубной паста Zact с эффект отбеливание кофейный и никотиновый налет 150 г 8806325-603849',
#  'зубной паста Zact Lion Smokers Toothpaste 100 г 8850002805040',
#  'зубной паста Zact Lion Whitening Toothpaste 100 г 8850002805064',
#  'нож для тонкий нарезка ALPENKOK из нержавеющий сталь пилообразный "Comfort" 12,7 см синий AK-2082',
#  'антуриум андрианум блэк d-12 см',
#  'комнатный растение в горшок аспарагус мейер, d12, h30',
#  'молодило микс d-9 см',
#  'фиалка d-11 см',
#  'гладильный доска-стремянка 95х33 см, 848N, DASCH',
#  'гербер d-13 см',
#  'душица обыкновенный d-9 см',
#  'мелисса лекарственный d-9 см',
#  'роза кордан красный мерседес d-10 см',
#  'роза кордан красный d-10 см',
#  'фиалка карнавал d-12 см',
#  'хризантема белый кристалл d-15 см',
#  'хризантема красный тобаго d-15 см',
#  'сушилка для белье потолочный лиана 2,0 м 1703009',
#  'тележка хозяйственный складной, ТХ0252, 30 кг, пэмби',
#  'карниз алюминиевый телескопический для штора Spirella / спирелла Magic, хром, 125-220 см, 1050767',
#  'пеларгония зональный диам. 12 см малиновый-красный простой',
#  'гладильный доска Sarayli New Elegant 125x45 см',
#  'салфетка Protec Textil Polyline 30х43 см аметист белый 6230',
#  'лестница-стремянка Dogrular Ufuk Al алюминевый 6-ти ступенчатый',
#  'ерш для унитаз Spirella VENISE с подставка керамический 4007036',
#  'контейнер для мусор FLIP BIN CURVER 25 л красный 02171-547-00',
#  'контейнер для мусор FLIP BIN CURVER 25 л оранжевый 02171-535-00',
#  'стремянка металлический 4 ступень, СМ4, ника',
#  'швабра многофункциональный, Rozenbal, R212522',
#  'ящик для хранение TEXTILEBOX CURVER 5,7 л 34x20x13 см прозрачный 03003-001-00',
#  'сушилка для белье потолочный лиана люкс 140, ЛДН-т',
#  'скатерть лувр 100% полиэфир овальный 300х150 см салатовый Wellness WTO305-лувр*18',
#  'подголовник для ванный комната из пвх 25х34 синий, Bacchetta, 1620',
#  'гладильный доска фанера "стелла премиум 2", 122*38, СТП2, ника',
#  'пеларгония зональный диам. 12 см белый махровый',
#  'пеларгония зональный диам. 12 см коралловый полумахровый',
#  'пеларгония розоцветный ред розебуд молодой растение',
#  'сумка-тележка хозяйственный Rolser Jet Joy синий, JET001 azul JOY',
#  'банка с металлический крышка, COLOR SERIES, круглый, 11*11*12 см, 960 мл VALIANT, JK-D960',
#  'банка с металлический крышка, COLOR SERIES, круглый, 11*11*17 см, 1350 мл VALIANT, JK-C1350',
#  'ведро для мусор Hailo 0516-570 16 л, бежевый',
#  'штора текстильный для ванна и душа полиэстер, "бамбук" 180х200см, зеленый/белый, DSCN3579',
#  'тарелка обеденный Luminarc грин форест 26 см H7239',
#  'рассада зелень для кухня лаванда в горшок диам. 9 см',
#  'рассада зелень для кухня розмарин в горшок диам. 9 см',
#  'рассада зелень для кухня тимьян в горшок диам. 9 см',
#  'коврик придверный, полукруглый из резина и кокос, 40х68 см, Format Mezzaluna, розетта, коричневый, PHP SRL, 20657',
#  'ножеточка универсальный "рыбка" 1519028',
#  'вешалка-плечики без эссенция цвет темно-розовый FWM-002/Quartz pink',
#  'искусственный цветок пластиковый мак 3 бутон 48 см',
#  'искусственный цветок ромашка пластик 45 см',
#  'цветок искусственный гвоздик пластиковый одиночный в ассортимент 50 см',
#  'цветок искусственный мак 45 см пластик',
#  'цветок искусственный мак 55 см пластик',
#  'цветок искусственный нарцисс одиночный в ассортимент 35 см',
#  'цветок искусственный роза алый бархатный раскрытый бутон 63 см',
#  'цветок искусственный ромашка 3 цветок 50 см пластик',
#  'цветок искусственный тюльпан 45 см пластик цвет в ассортимент',
#  'цветок искусственный тюльпан в ассортимент одиночный 63 см',
#  'салфетка камушек транспарент 30*40 см 5187 Dasch',
#  'тележка багажный DELTA ТБР-22 коричневый грузоподъемность 20 кг сумка и 50 кг каркас россия',
#  'гладильный доска Colombo Avantgard 120х40 см',
#  'бегония ампельный, диам. 12 см',
#  'рассада пеларгония (герань) зональный блу айза Mix смесь объем 0,5 л',
#  'хризантема корейский смесь окраска объем 0,75 л',
#  'чехол для гладильный доска с дизайн Venezia 140х55 см из хлопок',
#  'настольный гладильный доска фанера, 85*30, НД, ника',
#  'кувшин пластмассовый с крышка 2,0 л, (S-751) "пластхозторг" 1408004',
#  'розмарин d-12 см',
#  'масленка коровка с крышка 17см, 73115, Luminarc, франция',
#  'плечики пластмассовый размер 52 - 54 тула 1205158',
#  'сушилка для белье Gimi Jolly 18',
#  'сушилка для белье Eurogold STABILO 18 напольный 0503 SE',
#  'стремянка бытовой Framar Slimmy 3 ступень',
#  'сумка-тележка 2-х колесный Gimi Argo фуксия',
#  'подрукавник Gimi Planet для гладильный доска',
#  'чехол для гладильный доска I LOVE GIMI L из полиэстер и хлопок 136*58 см, Gimi',
#  'штора для ванный комната Quadretto 240х200 см белый, Bacchetta, 4062',
#  'сидение в ванна раздвижной, белый, СВ5, ника',
#  'утюг электрический с керамический покрытие DELTA LUX DL-350 зеленый, 2200 вт , россия',
#  'чехол для гладильный доска Attribute METAL 140х60 см ABM106',
#  'муляж яблоко 9 см красный',
#  'корыто оцинковывать 45 л бесшовный, 1301031',
#  'тележка багажный DELTA ТБР-20 черный с серый грузоподъемность 25 кг сумка 50 кг каркас россия',
#  'штора для ванный комната 182х182 см пвх Meiwa, Krackle прозрачный 5911',
#  'тележка багажный DELTA ТБР-20 синий грузоподъемность 25 кг сумка и 50 кг каркас россия',
#  'гладильный доска ника бэлль 106,5х29 см б',
#  'муляж вишня 3 см 10 шт полиуретан',
#  'муляж груша желтый 9,5 см полиуретан',
#  'муляж лимон желтый 9 см полиуретан',
#  'муляж мандарин оранжевый 8 см полиуретан',
#  'муляж перец чили в связка, красный, 60 см, полиуретан, Fancy Fair/ff RP60',
#  'муляж чеснок в связка 60 см полиуретан',
#  'сервировочный салфетка пвх 26х41 см ванда 6001',
#  'коврик противоскользящий кружевной 88х38 см прозрачный 5528',
#  'штора для ванный комната Bacchetta City текстильный 180х200 см 6023',
#  'гладильный доска ника стелла классик 1 122х34,5 см СТК1',
#  'штора для ванный комната Bacchetta Dama текстильный 180х200 см 3655',
#  'салатник Luminarc кутюр 16 см H3386',
#  'салатник Luminarc кутюр 27 см H3529',
#  'тарелка десертный кутюр 20,5 см J2402 Luminarc',
#  'тарелка суповой кутюр 22,5 см J2397 Luminarc',
#  'коврик придверный полипропиленовый с пвх STEP IN TRADITIONAL 90х150 см коричневый',
#  'сумка-тележка хозяйственный Andersen Scala Shopper Plus, Lini, синий 133-108-90',
#  'гладильный доска ника SOPHY корица HSK 123х46 см',
#  'коврик противоскользящий пузырек 70х38 см прозрачный 5523',
#  'чехол для гладильный доска универсальный с поролон 2, 1290 х 500, ЧП2, ника',
#  'сумка-тележка хозяйственный GIMI Argo голубой',
#  'муляж ананас светло-коричневый 10 см полиуретан',
#  'муляж баклажан 18 см',
#  'муляж банан желтый 21 см полиуретан',
#  'муляж гранат 9 см красный',
#  'муляж груша мини 2 шт желтый 4 см',
#  'муляж манго оранжевый 13 см полиуретан',
#  'муляж морковь 16 см',
#  'муляж персик 9 см полиуретан',
#  'муляж тыква d-20 см',
#  'муляж черешня 10 штука d 2,5 см, цвет в ассортимент',
#  'сумка-тележка хозяйственный Rolser BAB010 negro JOY-1800 черный',
#  'чехол для гладильный доска Zalger 520133 120х40 см хлопок поролон для доска 115х35 см',
#  'сумка-тележка 2-х колесный Gimi Galaxy черный',
#  'сковорода Scovo эксперт дема СЭ-040 для блин алюминиевый с антипригарный покрытие, 25 см, 1503020',
#  'герань домашний (пеларгония зональный) цвести , D12, H25-30, лососевый, полумахровый',
#  'коврик придверный с дизайн, из резина и кокос Aberdeen Welcome 45x76, 4395',
#  'коврик придверный Redstone Mix из полиэстер и перерабатывать резина 60х91 см серо-коричневый, Apache, 4651',
#  'коврик придверный Stonehedge Grey из полиэстер и перерабатывать резина 60х91 см серый, Apache, 4652',
#  'сумка-тележка хозяйственный Rolser IMX005 marengo Logic DOS+2 серый',
#  'банка стеклянный STEEL TOUCH 1700 мл, Attribute, ABS017',
#  'тарелка десертный стоунмания оранж 20,5 см H3557 Luminarc',
#  'тарелка обеденный стоунмания оранж 25 см H3556 Luminarc',
#  'тарелка суповой стоунмания оранж 20 см H3558 Luminarc',
#  'скатерть из пвх MEIWA FPLUS-PLAIN SARASA AZ BE овальный 152х228 см бежевый 5789',
#  'сумка-тележка 2-х колесный складной Gimi Flexi серый',
#  'сумка-тележка 2-х колесный Gimi Ideal синий',
#  'шнур резиновый для тележка 110 см, 1209002',
#  'шнур резиновый для тележка 80 см, 1209001',
#  'сумка-тележка хозяйственный Rolser MOU041 malva RD6 сиреневый',
#  'рассада зелень для кухня душица в горшок диам. 9 см',
#  'таз пластмассовый строительный прямоугольный 80 л, 1404085',
#  'урна уличный "гео", Hobbyka/хоббик, 59*37,5см, сталь',
#  'скатерть азалий 88% полиэфир 12% хлопок прямоугольный 350х150 см персиковый Wellness MC355-азалий*05',
#  'сумка-тележка хозяйственный Gimi Bella серый',
#  'чайный набор Luminarc рейнбоу 220 мл J5978',
#  'штора для ванный текстильная180х200 Quadretto белый, Bacchetta, 3003',
#  'набор эмалированный салатник METALLONI ветка рябина EM-00003A/31 12,14,16 см',
#  'муляж вишня на магнит',
#  'пеларгония зональный диам. 12 см малиновый махровый',
#  'пеларгония зональный диам. 12 см розовый махровый',
#  'пеларгония зональный розоцветный ред розебад (Red rosebud)',
#  'набор вешалка мягкий тканевый с перекладина и клипса 48х23 см 2 шт валиант / Valiant VAL 7057gc',
#  'стремянка 5 ступенчатый Hailo 8925-901 L9 алюминиевый',
#  'антуриум андрианум ванилла d-12 см',
#  'коврик придверный Attribute NATURE кокосовый 60x40 см AMC015',
#  'овощеварка алюминиевый Scovo МТ-045, хозлэнд, 1502079',
#  'сметка с совок престиж, York, G6207',
#  'коврик придверный, полипропилен, 40х70 см, Kokarda, спать кот, бежевый, PHP SRL, 20734',
#  'чехол для гладильный доска BASIC 120х40 см, Attribute, ABB004',
#  'халат вафельный виктория_3-42 , 100% хлопок 265 g/m2, размер 52-54, салатовый, Wellness, 2000000168616',
#  'измерительный алюминиевый угольник, 20*30 см, Truper, E-8X12/14386',
#  'линейка, длина 30 см, Truper, RGL-30/14387',
#  'муляж баклажан мини 2 шт',
#  'муляж гранат мини 4 шт',
#  'муляж перец чили мини 2 шт, красный 7 см',
#  'набор фужер для вино аллюр 6шт 250мл, G5747, Luminarc, франция',
#  'набор фужер для вино маскарад 6шт 250мл, G5544, Luminarc, франция',
#  'сушилка для белье лиана люкс 190 см потолочный',
#  'сушилка для белье Leifheit 81570 PEGASUS 150 87х157х55 см',
#  'сумка-тележка хозяйственный Rolser BAB008 marengo JOY-1800 серый',
#  'штора для ванный комната Diamante 240х200 см бежевый, Bacchetta, 4800',
#  'чехол для гладильный доска Leifheit Beach and Bubbles 130x45 см 71596',
#  'терка WEBBER из нержавеющий сталь ВЕ-048 4 грань 20 см с красный ручка',
#  'терка WEBBER из нержавеющий сталь ВЕ-054 6 грань 21 см',
#  'вилка столовая Better цветной горох BT-C2003E-TD1/D1',
#  'контейнер для приготовление 2-х яйцо глазунья полимербыт C452',
#  'кружка 350 мл ROSARIO радуга керамический коричневый Ф13-005L',
#  'кружка для чай ягода клубника 250 мл 1606-д',
#  'кружка Luminarc лили флауэр 320 мл J8565-1',
#  'ложка обувной металлический красить 43 см с крючок, 1205156',
#  'лопатка Attribute BAMBOO AGB110',
#  'лопатка c прорезь Attribute BAMBOO AGB111',
#  'набор фужер для красный вино 235 мл, 6 шт., серия касабланка, 51258B',
#  'набор фужер для шампанский френч брассери 6шт 170мл, H9452, Luminarc, франция',
#  'полотенце махровый гармония, 100% хлопок 335 г/м2, 32х70 см, Wellness, 4630005362832',
#  'салфетка махровый радуга в разноцветный полоска, 100% хлопок 312 г/м2, 31х31 см, Wellness, 4630005360012',
#  'салфетница металлический WEBBER с хромированный покрытие 14,7*4*9 см BE-0293',
#  'стакан низкий лабиринт 250 мл для напиток 05с1262',
#  'стакан пластмассовый 300 мл, конус. (к-308) "пластхозторг" 1535027',
#  'столовый ложка Better цветной горох BT-C2003E-TD2/D1',
#  'чайный ложка Better цветной горох BT-C2003E-TD3/D1',
#  'цветок искусственный крокус 20 см',
#  'цветок искусственный гербер, 45см',
#  'ковер придверный имитация трава 60х90см , цвет серый',
#  'тележка багажный DELTA ТБР-23 грузоподъемность 50 кг россия',
#  'тарелка десертный ирис D3700 Luminarc',
#  'гладильный доска Attribute TEFLONIX 130х46 см ABT142',
#  'коврик для ванный комната GOBI полиэстер 120х70 см темно-зеленый, Spirella, 1012778',
#  'альбук спиралиса фризлый-сизл d-12 см',
#  'коврик Sochi 50х80 см коричневый 5801',
#  'овощечистка с плавать лезвие Comfortline из нержавеющий сталь и пластика 11 см белый, Leifheit, 03151',
#  'бальзамин новогвинейский d-13 см',
#  'бегония клубневой d-13 см',
#  'крассула оват d-10 см',
#  'гладильный доска ника BRUNA M HBM 122х40 см',
#  'артемизия (полынь горький) d-9 см',
#  'пеларгония зональный махровый микс d-12 см',
#  'герань домашний (пеларгония зональный) цвести D12, H25-30, красный-розовый, простой',
#  'насадка к швабра FLEXINETT пластик + микрофибра, Rozenbal, R212585',
#  'средство для удаление известковый налет с поверхность сантехнический прибор DECS антикальций 500 мл россия 4660015923266',
#  'коврик ворсовый для ванный комната OrthoSpa River Rocks grey из микрофибры и пвх прямоугольный 50х85 см серый-белый, Apache, 4666',
#  'сумка-тележка 2-х колесный Gimi Galaxy голубой',
#  'вешалка напольный ATLANT 90х42 см VATL-1 светлый степанов',
#  'тележка хозяйственный ролл с крыло, Attribute, ATT101',
#  'бензин для зажигалка, 1205214',
#  'скатерть прямоугольный ажурный Imperial 140х200 см бежевый с тесненый рисунок Towa Co 5174',
#  'паста для полировка "гои" 25 гр',
#  'цветок искусственный гортензия, 58 см, цвет в ассортимент',
#  'тележка багажный DELTA ТБР-15 цвет в ассортимент грузоподъемность 30 кг россия',
#  'гладильный доска ника дсп эконом 106,5х29 ЭК1',
#  'сумка-тележка хозяйственный GIMI Argo салатовый',
#  'сумка-тележка хозяйственный Gimi Easy Go синий',
#  'таз пластмассовый 40,0 л пищевой овальный (Иж), 1404094',
#  'сушилка для белье лиана люкс 120 см потолочный',
#  'скатерть из пвх MEIWA FPLUS-171 AZ WH/BE овальный 132х178 см белый-бежевый 5785',
#  'петля-стрела ПС-286 мм (рыбинск), 1104019',
#  'подголовник для ванный комната из пвх 25х34 Mickey, Bacchetta, 4811',
#  'сушилка для белье потолочный Zalger Lift Comfort 520 180 см 9 м',
#  'лаванда d-9 см',
#  'мята d-9 см',
#  'сушилка для белье виолета FH COLOR LUX 22 м белый ВЛ867',
#  'муляж виноград зеленый 26 см полиуретан',
#  'вешалка-стойка № 9 дерево зми медный антик ВНП 211 м',
#  'стремянка металлический 3 ступень, СМ3, ника',
#  'рассада зелень для кухня лаванда в кассета по 6 шт',
#  'рассада зелень для кухня розмарин в кассета по 6 шт',
#  'рассада зелень для кухня тимьян в кассета по 6 шт',
#  'муляж виноград желтый 24 см полиуретан',
#  'муляж желудь 2 шт',
#  'муляж яблоко, оранжевый, 8,5 см, полиуретан',
#  'сумка-тележка GIMI Argo синий',
#  'каланхое каландив белый d-7 см',
#  'примула акаулис микс d-10 см',
#  'держатель для туалетный бумага С373 "полимербыт" 1713006',
#  'ерш унитазный с подставка WC "люкс", мультипласт, 1712007',
#  'пробка для ванна резиновый (д-40 мм) 1206155',
#  'штора для ванный с кольцо RL-0071 мыльный пузырь 180х180 см',
#  'чехол для гладильный доска Zalger 520116 130х46 см хлопок для доска 125х42 см',
#  'чехол для гладильный доска Zalger 520124 140х58 см хлопок для доска до 135х53 см',
#  'измельчитель овощ ручной ШК-4 деревянный, 3 нож, 1516020',
#  'сумка-тележка DELTA ТБР-20 синий грузоподъемность 25 кг сумка и 50 кг каркас россия',
#  'коврик придверный из резина и кокос, 40х68 см, Format Classic, соломка, коричневый, PHP SRL, 20135',
#  'лоток для холодец эмалированный 1,5 л с пластмассовый крышка с рисунок с-2508Кп/4 стэм 1506085',
#  'сумка-тележка GIMI Easy Go красный',
#  'вешалка-плечики 3 шт без эссенция цвет светло-бирюзовый FWM-002/Aruba blue',
#  'вешалка мягкий для деликатный вещь 3 шт желтый',
#  'губка спираль металлический EUROHOUSE 2 шт EH3599',
#  'перчатка латексный 10 шт, р-р м, R105817, ROZENBAL',
#  'перчатка резиновый универсальный Centi, р-р M, York, G9212',
#  'чехол для одежда большой 137х60х10 см светло-бежевый валиант / Valiant TR-107H',
#  'чехол для одежда EVA 150x65 см MHE017',
#  'мыло жидкий reffil Mama Utimate облепиха 500 мл россия 8809193042321',
#  'ерш унитазный пластмассовый, ваир 1712002',
#  'кофр для хранение Hausmann подкроватный 80х40х15 см 2B-28040',
#  'сумка-тележка GIMI Argo красный',
#  'декоративный композиция искуственный цветок букет роза три цветок, цвет в ассортимент 85 см',
#  'салатник романтик гарден 17 см J7900 Luminarc',
#  'фен дорожный DELTA DL-0904 бордовый с черный 2 режим мощность 1400 вт россия',
#  'чайник электрический аксинья кс-1003 корпус из жаропрочный стекло черный 2200 вт 1,8 л',
#  'штора для ванный и душа текстильный, 180х200см, "цветок", голубой, HSP394-B',
#  'штора для ванный комната пвх 180х180 см водоросль, 5919',
#  'вешалка настенный ника ВН3 3 крючок медный антик',
#  'вешалка самоклеять на 4 крючок 1110008',
#  'штора для ванный и душа текстильный, 180х200см."лилия", бежевый/белый с розовый цветок, H125',
#  'салатник аморить браун 16,5 см J2113 Luminarc',
#  'салатник колорама рэд 17 см J7772 Luminarc',
#  'салатник рапсоди оранж 16,5 см H8728 Luminarc',
#  'салатник Luminarc арти грин 16,5 см J1392',
#  'салатник Luminarc арти пинк 16,5 см L2857',
#  'салатник Luminarc арти пурпл 16 см G9834',
#  'салатник Luminarc арти пурпл 16,5 см L2858',
#  'салатник Luminarc амбиантэ анис 16 см L6415',
#  'салатник Luminarc амбиантэ оранж 16 см L6417',
#  'пеларгония зональный диам. 12 см белый полумахровый',
#  'кружка для чай сердечко 250 мл ДСГ55029146',
#  'дендробиум санки полар файр 1 ствол d-12 см',
#  'герань домашний (пеларгония зональный) цвести D12, H25-30, красный, простой',
#  'калоцефалус брауни крашеный осенний микс d-10 см',
#  'коврик придверный APACHE 45х76 см Flagstone 5415',
#  'антижир POSH ONE MAGNUM 828 мл россия 4580390-927058',
#  'каллун гарден герлс трехцветный d-12 см h-27 см',
#  'капсикум сальса оранжевый d-10 см',
#  'кофр малый жесткий 28*30*16 см леопард валиант / Valiant LB301',
#  'мимоза стыдливый d-9 см',
#  'набор кухонный полотенце 100% хлопок 200г/м2 46*71 см 2 шт, Wellness, мелис_3',
#  'соланум d-10 см',
#  'универсальный средство на основа хлор ддля чистка сантехника и другой поверхность DECS Universal 750 мл россия 4660015923228',
#  'мантоварка алюминиевый 6,0 л 3 сетка белый калитва, хозлэнд, 1502074',
#  'пеларгония зональный простой цвет фуксия',
#  'рассада зелень для кухня мелисса в кассета по 6 шт',
#  'гладильный доска ника BLUES 124х46 см 5757',
#  'ложка обувной металлический красить 220, 1205155',
#  'плечики пластмассовый размер 48 - 54 мп 1205160',
#  'ролик для чистка одежда *Clear Line* (20 слой), 1205060',
#  'сменный блок для ролик 2 шт (R160071), Rozenbal, R510100',
#  'таз пластмассовый 4,5 л пищевой "косметь" (ангора) 1404092',
#  'герань домашний (пеларгония зональный) цвести D12, H25-30, ярко розовый, полумахровый',
#  'пеларгония d-13 см с топпер на день учитель в подарочный упаковка',
#  'роза патио белый d-12 см h-30',
#  'роза патио красный d-12 см h-30',
#  'роза патио оранжевый d-12 см h-30',
#  'стремянка 5 ступенчатый Hailo 8150-507 L50 алюминиевый с крючок на красный ручка',
#  'набор бокал император 3 шт 170 мл 06707 E5181 Luminarc франция',
#  'набор стакан для виски 300 мл 6 шт серия карат 52885В',
#  'термометр на окно уличный на липучка т-5 h-20 см 1210035',
#  'термометр уличный оконный тб 202 h-20 см 1210036',
#  'ящик почтовый металлический с ушко для навесный замок домик 1205251',
#  'сушилка для белье напольный Gimi Mito, алюминий',
#  'гладильный доска ника верона 1 чехол ретро 122х42 см ДВ1р',
#  'швабра сальса треугольный мини, Y8110',
#  'бархатцы веселый полянка 0,3 г 4660010777505',
#  'косметь очаровашка 0,05 г 4660010779578',
#  'морковь детский сладость 2 г 4660010775921',
#  'настурция драгоценность вишневый-розовый 1 г 4660010773316',
#  'огурец засолочный 0,3 г 4660010776102',
#  'пеларгония зональный розоцветный ред розебад',
#  'петуния каскад смесь махровый 10 шт 4660010772784',
#  'сумка-тележка хозяйственный Rolser Jet Joy черный, JET010 negro JOY',
#  'герань домашний (пеларгония зональный) цвести D12, H25-30, красный, полумахровый',
#  'шило с пластмассовый ручка утолщать с крючок, 1205083',
#  'тарелка обеденный мунлайт 25 см H7253 Luminarc',
#  'скатерть прямоугольный ажурный Marine 132х177 см бежевый с тесненый рисунок Towa Co 4022',
#  'сушилка для белье ника СБ2Б 20 м',
#  'сушилка для белье ника СБ1 18 м',
#  'вешалка деревянный с расширять плечики и перекладина 44,5х23 см см белый JAPANESE WHITE VALIANT JW-19708',
#  'вешалка для брюки Attribute CLASSIC 38 см AHN271',
#  'набор вешалка для костюм 45 см 4 шт цвет кремовый Attribute AHP224',
#  'набор вешалка универсальный Attribute SILUET CREAM 45 см 4 шт AHP224',
#  'корзина для белье KNIT 57 л темно-коричневый, Curver, 03676-X59-00',
#  'сумка-тележка TWIN стальной каркас 56 л синий, Gimi',
#  'гладильный доска ника стелла классик 2 122х34,5 см СТК2',
#  'тарелка десертный воларэ блэк 22,5 см G9399 Luminarc',
#  'таз пластмассовый 6,0 л пищевой М2511, 1404015',
#  'таз пластмассовый 8,0 л пищевой (минеральный вода), 1404009',
#  'ковш пластмассовый полимербыт С215, 1,5 л 1406006',
#  'гладильный доска ника николь 9 122х40 см',
#  'кухонный ножницы WEBBER из нержавеющий сталь с орехокол ВЕ-5208',
#  'набор нож Attribute CHEF 5 предмет AKF522',
#  'нож кухонный для мясо с пластмассовый ручка 305 х 175 мм, "русский линия" (НХ-36М), метиз 1519003',
#  'нож кухонный для овощ с деревянный ручка 318 х 200 мм, "гурман" (НХ-14М), метиз 1519009',
#  'нож кухонный универсальный с пластмассовый ручка 285 х 150 мм, "русский линия" (НХ-38М) метиз 1519022',
#  'рыбочистка с деревянный ручка с нож 1518024',
#  'тарелка десертный мок браун 19 см H7013 Luminarc',
#  'комод эльфпласт виола 3-х секционный коричневый 339',
#  'корзина для белье виолета ротанг 2350/2 угловой с крышка 60 л бежевый',
#  'сушилка для белье на ванна ника СБ4',
#  'картофелемялка металлический круглый с деревянный ручка 1531002',
#  'сушилка для белье потолочный лиана 1,8 м 1703007',
#  'салатник воларэ блэк 16 см G9403 Luminarc',
#  'тарелка суповой воларэ блэк 23 см G9402 Luminarc',
#  'ароматизированный средство дудаление известковый налет и ржавчина DECS WC гель лимон 750 мл россия 4660015923235',
#  'бальзам для мытье посуда Mama Ultimate EcoSoda 1000 мл россия 044684',
#  'средство для мытье пол ECOMATIC GREEN CLEANER 1000 мл испания 126109',
#  'стремянка бытовой Zalger 111-5 алюминиевый 5 ступенька',
#  'банка стеклянный с крышка Attribute FLEUR 1350 мл ABF100G',
#  'банка стеклянный с крышка Attribute FLEUR 650 мл ABF135W',
#  'коврик кухонный APACHE Olive Oil Sideboard 56х86 см 5062',
#  'штора для ванный 180х200 см, Rigone бежевый',
#  'алиссум (лобулярий) снежный одежда 0,2 г 4650091480302',
#  'гвоздик турецкий роковой страсть 0,05 г 4660010773231',
#  'годеция рембранд 0,1 г 4650091480128',
#  'календула пинк сюрпрайз 0,5 г 4650091480203',
#  'капуста декоративный смесь 0,1 г 4650091480234',
#  'кореопсис толла 0,1 г 4650091480258',
#  'косметь клюквенный клик 0,1 г 4660010770421',
#  'косметь кэнди страйп 0,3 г 4650091480272',
#  'лапчатка огненный пламень 0,02 г 4650091480616',
#  'львиный зев волшебный ковер 0,05 г 4660010779639',
#  'пеларгония зональный диам. 12 см розовый-красный полумахровый',
#  'флокс друммонд смесь 0,1 г 4650091480401',
#  'цинерария серебряный пыль 0,1 г 4660010770797',
#  'эшшольций карминный король 0,5 г 4660010770193',
#  'чехол Eurogold Clean Basic хлопок для доска 120х38-120х42 см C42',
#  'жестяной банка новый паста микс п-90*90h171v140-01014',
#  'кружка нордик 380мл прозрачный H8502 Luminarc франция',
#  'чайник электрический аксинья кс-1002 корпус из жаропрочный стекло белый 2000 вт 1,8 л',
#  'гладильный доска Scab Stiro Lux 122х38 см',
#  'рассекатель пламень на газовый плита с ручка, AN8032',
#  'ополаскиватель для посудомоечный машина Ludwik 750 мл польша 5900861242715',
#  'сетка для глажение ява РТК26 45х65 см, 1200023',
#  'сковорода алюминиевый с антипригарный покрытие MARBLE ALPENKOK d = 22 см AK-0037A/22N',
#  'щетка для посуда *оля*, мультипласт 1807010',
#  'чайник электрический василиса Т33-2000 нержавеющий сталь красный 2000 вт 2 л',
#  'покрывало жаккард шенилл BIRHOME VALENTIN 240х260 см наволочка 50х70 см 2 шт 9234567089661',
#  'вешалка гардеробная радуга 2 зми черный ВНП 299 ч',
#  'ковер придверный EKSPO 90х150 см черный РР114/01019',
#  'набор форма для кекс WEBBER из нержавеющий сталь 6 шт 7,5*3,4 см BE-4343/6',
#  'банка стеклянный WOODEN TOUCH 1700 мл, Attribute, ABB017',
#  'корзина для белье пластмассовый 45 л угловой С299 1704006',
#  'вешалка с закруглять плечики без перекладина с противоскользящий покрытие Valiant 226B10 черный',
#  'весы напольный электронный Soehnle Pino White, 63747',
#  'лестница-стремянка Dogrular Ufuk оцинковывать 4-х ступенчатый',
#  'диффенбахий d-12 см с топпер на день учитель в подарочный упаковка',
#  'комплект постельный белье WELLNESS PLATINUM R185-авеню пододеяльник 180х214 см простыня 200х214 см 2 наволочка 50х70 см',
#  'покрывало жаккард KARNA стеганый KALVEN 260x260 см наволочка 50х70 см 2 шт 8681914002162',
#  'вилка столовая Better цветок BT-C2003E-TD1/D3',
#  'фаленопсис королевский голубой 1 ствол d-12 см',
#  'сумка-тележка хозяйственный Rolser RG SAQUET, синий, SAQ002 azul CONVERT',
#  'бальзамин новогвинейский d-13 см цвет фуксия',
#  'подставка для обувь резиновый Attribute 80x40 см AMC080',
#  'сушилка для белье потолочный лиана люкс 160 см ЛЛП-160',
#  'вешалка-сушилка Gimi Paco',
#  'коврик Bacchetta противоскользящий в душевая кабина 55х55 см бежевый 4819',
#  'штора для ванный комната 240х200 Fragmmento бежевый текстильный 240х200 см 6041',
#  'чехол для гладильный доска Festival 137x60 см из хлопок 4738',
#  'гладильный доска ника белль классик 1 122х34,5 см БК1',
#  'подсолнечник низкорослый d-13 см',
#  'ручка-скоба РС-100 белый *трибатрон*, 1108035',
#  'сушилка для белье на батарея ника СБ6-65 двухъярусный',
#  'пуансетия d-12 см с топпер на день учитель в подарочный упаковка',
#  'лоток для холодец эмалированный 1,5 л с пластмассовый крышка без рисунок с-2508Кп стэм 1506084',
#  'гладильный доска Eurogold Professional 130х48 см 35748W',
#  'пресс для чеснок Attribute WESTERN AGW050',
#  'сушилка для белье потолочный лиана люкс 250 см ЛЛП-250',
#  'тарелка обеденный кашим пурпл 25 см G9324 Luminarc',
#  'сумка-тележка 3-х колесный Gimi Tris красный',
#  'коврик придверный хлопковый 60х180 см мультиколор, Helex, С05',
#  'щетка-сметка с пластиковый ручка лаура SV3020',
#  'термостакан WEBBER BE-6030 кофе 450 мл',
#  'гиностемма укоренять черенок 1 шт',
#  'ель канадский коника ртк 303 горшок 9 л нидерланды',
#  'кипарисовик лавсон элвуди ртк 106 горшок 9 л нидерланды',
#  'аптений d-10 см h-10 см',
#  'сушилка для белье потолочный лиана люкс 170 см ЛЛП-170',
#  'коврик придверный каучуковый 45х75 см черный, Helex, P01',
#  'антуриум андрианум фиорино d-15 см',
#  'таз пластмассовый 12,0 л пищевой (минеральный вода), 1404022',
#  'роза палас белый d-17 см h-50 см h-20',
#  'сушилка для белье Gimi Mito алюминий',
#  'банка из стекло для сыпучий продукт круглый с пластмассовый крышка и цветной вкладка 1,0л 10МР-0001',
#  'сушилка для белье Attribute прима 18 м синий ADP618',
#  'гладильный доска ника эльза премиум 122х40 см элп',
#  'сушилка для белье Gimi Extension',
#  'сушилка для белье потолочный лиана 1,5 м 1703004',
#  'ерш унитазный с деревянный ручка , ваир 1712012',
#  'сумка-тележка 2-х колесный складной Gimi Flexi зеленый',
#  'новогодний дерево ель канадский коника ртк 343 d-9 см',
#  'новогодний дерево ель сербский d-21 см h-60 см',
#  'новогодний дерево ель канадский коника в красный ведерко 3 л h-40 см',
#  'чехол для одежда малый 100х60х10 см светло-бежевый валиант / Valiant TR-106H',
#  'мыльница пластмассовый на ванна М2221 1702010',
#  'коврик Dasch для ванный комната 50х80 см TL-90 листопад зеленый 5730',
#  'кружка прозрачный 250 мл H8437 Luminarc франция',
#  'пеларгония грандифлора махровый микс d-12 см',
#  'муляж мандарин мини на магнит',
#  'салфетка Protec Textil Lino 30х43 см натура 6223',
#  'мыло ручной работа свинюшка в грязюшко 90 г',
#  'гладильный доска Leifheit AirBoard Compact M Plus 120х38 см малиновый 71630',
#  'сушилка для белье на ванна Leifheit Adria 72708',
#  'гладильный доска ника бэлль-ЮНИОР1 112х34,5 см БЮ1',
#  'чехол для одежда Hausmann со стенка из пвх и ручка 60х140 см синий HM-701402NG',
#  'щетка-сметка 3-х рядная деревянный 450 мм (плоский ручка), поиск риф 1801095',
#  'защитный экран подставка и дуршлаг WEBBER 3 в 1 цвет: зеленый d = 28,5 см из силикон BE-0341S',
#  'набор бокал для пиво Cervoise 4 шт 320мл G3775 Luminarc франция',
#  'роза мини розовый d-7 см h-10',
#  'коврик в ванна 36х71 см, розовый',
#  'стремянка-табурет алюминиевый Hailo L90 Step-ke 4442-701 2х2 ступень',
#  'пуансеттия d-12 см красный с розовый',
#  'пуансеттия d-12 см белый',
#  'тележка багажный DELTA ТБР-21 черный грузоподъемность 25 кг для сумка и 50 кг для каркас россия',
#  'цветущий комнатный растение бегония элатиор, цвет в ассортимент',
#  'чайный ложка 6 предмет вена СЧВ107',
#  'нож для мясорубка (супер) лепесток 1512016',
#  'крассула d-17 см h-40 см',
#  'тарелка суповой ирис 21 см J1299 Luminarc',
#  'комплект махровый салфетка топ_2, 100% хлопок 266 г/м2, 28х42 см, 2 шт, цвет в ассортимент, Wellness, 4630005364393',
#  'набор столовый прибор 24 предмет OASIS Domenik DM9634',
#  'пуансеттия d-15 см розовый',
#  'коврик ворсовый для ванный комната OrthoSpa River Rocks natural из микрофибры и пвх прямоугольный 50х85 см серо-коричневый, Apac',
#  'кольцо для штора виолета 12 шт пластик 1212/60',
#  'скатерть сидней 100% полиэфир овальный 300х150 см сиреневый Wellness WTO305-сидней*81',
#  'кувшин Luminarc виктория 1,8 л с крышка J8130',
#  'пуансеттия d-15 см красный',
#  'чехол для одежда объемный Hausmann с овальный окно пвх и ручка 60х140х10 см черный HM-701403AG',
#  'коврик ворсовый пвх придверный Multy 60х180 см коричневый',
#  'чехол для гладильный доска Zalger 520111 см металлизированный с поролон для доска 120х42 см',
#  'вешалка напольный TWIST складной 45*35 VRTW-1 светлый степанов',
#  'чайный набор сельма 220мл, G9434, Luminarc, франция',
#  'скатерть Towa Co ажурный Presea прямоуголный 120х150 см сепия 5514',
#  'вантуз черный с пластиковый ручка малый д-100 (маг), 1206002',
#  'вешалка с закруглять плечики перекладина и крючок с противоскользящий покрытие Valiant 213R11 черный',
#  'чехол для гладильный доска универсальный с поролон антипригарный, чпа, ника',
#  'термокружок Alpenkok AK-04010A синий 400 мл',
#  'гладильный доска ника LORETA GOLF HL 123х46 см',
#  'фоторамка Alparaisa на 7 фотография бронзовый 43х42,5 см С31-017',
#  'этажерка 2 для обувь узкий 4 полк, медный, ЭТ2, ника',
#  'тарелка десертный бамбук 20 см J0276 Luminarc',
#  'скатерть джулия 64% хлопок 36% полиэфир прямоугольный 350х150 см золотой с голубой Wellness MT355-джулия*16',
#  'сервировочный салфетка пвх 26х41 см капучино 6163',
#  'гладильный доска Attribute TEFLONIX 135х46 см оранжевый ABT044',
#  'сушилка для белье потолочный лиана люкс 180 см ЛЛП-180',
#  'сумка-тележка хозяйственный GIMI Ideal серый (tortora)',
#  'новогодний дерево ель канадский коника в декоративный контейнер 1 л h-20 см',
#  'сушилка для белье напольный COLOMBO ALPINA 30MT ST194/3CF',
#  'термос со стеклянный колба 1,2 л 21013',
#  'аспарагус спренжери d-12 см',
#  'сумка-тележка хозяйственный Rolser Jet Claudia Joy черный, JET006 negro JOY',
#  'доска разделочный Alparaisa стеклянный завтрак 20х30 см RD0030-ST',
#  'чайный набор 220 мл карин ромашка, G1988, Luminarc, оаэ',
#  'штора для ванный комната Bacchetta Fragmmento бежевый текстильный 180х200 см 6034',
#  'тарелка суповой Luminarc океан эклипсы 20,5 см L5079',
#  'гладильный доска ника LORA FASHION HLF 123х46 см',
#  'гладильный доска ника бест 122х40 см НБ',
#  'набор бокал для шампанское леди даймонд 6 шт 150 мл G5208 Luminarc франция',
#  'пуансеттия d-23 см белый',
#  'коврик придверный пористый из полимерный материал 60х90 см коричневый, Vortex, D022',
#  'гладильный доска Dogrular домин 125х42 см 223708',
#  'сумка-тележка хозяйственный Rolser RG SAQUET, черный, SAQ002 negro CONVERT',
#  'скатерть 350х180 см WELLNESS WT358-лувр*02 100% полиэстер',
#  'сумка хозяйственный на колесо, 1209020',
#  'сушилка для белье Meliconi Miss Stendy',
#  'кружка бамбук 320 мл G0688 Luminarc франция',
#  'комод эльфпласт № 3 алфавит оранжевый 301о',
#  'скатерть арлета 50% полиэфир 50% хлопок овальный 350х175 см светло-бежевый Wellness MLO357-арлета*17',
#  'сумка-тележка хозяйственный Gimi Brava',
#  'сушилка для белье напольный COLOMBO BELLA 20 м ST387',
#  'штора для ванный комната 240х200 Sintra бежевый текстильный 240х200 см 6039',
#  'кондиционер для белье Sandokkaebi Soft Aroma Aqua Blue свежесть океан флакон 2100 мл корея 8801353-003494',
#  'фарфоровый кружка ROSARIO бабочка 550 мл Ф16-013L',
#  'термокружок Alpenkok AK-04009A красный 400 мл',
#  'сумка-тележка хозяйственный Rolser Pack Gloria Logic RG серый, PAC036 marengo LOGIC RG',
#  'вешалка металлический Valiant с четыре разъемный перекладина противоскользящий покрытие 35*30 см 18B30',
#  'корзина пластиковый для белье 40л. с крышка белый 1840/06, виолета',
#  'вешалка настенный ника ВП6с с полка 6 крючок серебро',
#  'крючок одежный двойной усиленный алюминиевый (дюраль), 1110015',
#  'термос 1л SVB-1000H',
#  'вешалка гардеробная радуга 1 зми белый серебро ВНП 298 бс',
#  'стремянка FRAMAR MAJOR TECH 4 алюминиевый 4-х ступенчатый 4126',
#  'плед флисовый 150х130 см WELLNESS WPLNY135-зима_10 100 % полиэстер',
#  'вилка столовая 3 шт тяжелый серия сапфир СВWeddel-2',
#  'коврик придверный хлопковый 60х140 см мультиколор, Helex, С04',
#  'скатерть виниловый тисненый с ажурный кайма 137х182 см водонепроницаемый ТД5-0077',
#  'коврик придверный полиэстер, 46х76 см, Drifted Nature, изменчивость, Mohawk, 5007',
#  'коврик придверный Alpine Wrought Iron из полиэстер и перерабатывать резина 45x76 см, Apache, 4649',
#  'стремянка Eurogold Colour 2х ступенчатый с противоскользящий покрытие, сталь 2022R/2122R',
#  'электроштопор QWERTY белый 4,5?23,4 см на батарейка 4хАА 71000',
#  'тарелка обеденный Luminarc океан эклипсы 24 см L5078',
#  'коврик для ванный комната, 50*80*1,4 см, мягкий основа, EXPEDITION HISTORY VALIANT, EXP-H-58',
#  'настенный сушилка для белье Gimi Brio Super 120',
#  'чайник эмалированный со свисток 2,5л есть-25001/17',
#  'коврик противоскользящий 69х39 см овальный черепаха 5538',
#  'комплект для мытье пол из нержавеющий сталь и пластика Clean Twist Mop зеленый: швабра-моп + ведро 20 л с механизм отжим, L',
#  'стремянка бытовой Framar Slimmy 4 ступень',
#  'корзина для белье виолета с крышка ротанг 40 л латт 1840/20',
#  'простыня вафельный 200х180 см WELLNESS RW180-01 100% хлопок',
#  'набор вешалка деревянный 3 шт с перекладина 44,5х23х1,2 см лиловый ROMANTIC VALIANT RM-16601s',
#  'декоративный композиция искуственный цветок букет подсолнух 115 см три бутон',
#  'сковорода Scovo дема Мт-029 алюминиевый без крышка с металический ручка, 20 см',
#  'столовый нож RIPPLE 80 г 2 шт Attribute ACR042',
#  'вешалка Valiant для брюки и юбка металлический 30*10.5 см 121B11',
#  'чехол для одежда Hausmann розовый принт 60х100х104',
#  'пеларгония зональный диам. 12 см красный махровый',
#  'пеларгония зональный розоцветный маргарита лососевый 5-7 лист',
#  'скатерть ажурный d-ia Rose круглый д.152 белый 5173 Towa Co. LTd-',
#  'штора для ванный 180х200 см, Rigone зеленый',
#  'сушилка для белье напольный ника СБ1Г 18 м белый-голубой',
#  'фиттоний скелетон d-9 см',
#  'скатерть беатрис 50% полиэфир 50% хлопок прямоугольный 300х145 см светло-коричневый Wellness ML304-беатрис*20',
#  'роза кустовой ред лейс 60 см кения плантация Waridi Limited 10 штука в упаковка',
#  'чехол для одежда Hausmann со стенка из пвх и ручка 60х100 см AG',
#  'гладильный доска Dogrular томрис 120x38 см',
#  'гладильный доска ника бэлль-ЮНИОР2 112х34,5 см БЮ2',
#  'полка QWERTY лондон белый 27х27х10 см и 23х23х10 см 72000',
#  'тимьян d-9 см',
#  'бульонница Luminarc мистигря 500 мл J8770',
#  'сушилка для белье напольный ника СБП1/с 18 м',
#  'нож для овощ и мясо (5024) 1518004',
#  'алоэ вера d-12 см h-25 см',
#  'жестяной банка гусь 0,8 л 11х9,9 см Ц99h110v080-01339',
#  'тележка багажный DELTA ТБР-20 коричневый с оранжевый грузоподъемность 25 кг сумка и 50 кг каркас россия',
#  'пеларгония зональный диам. 12 см красный-розовый простой',
#  'вешалка деревянный с расширять плечики и перекладина 44,5х23 см см серый JAPANESE BLACK VALIANT JB-19708',
#  'комнатный растение в горшок сциндапсус зеленый подвесной горшок, d15-16, h30',
#  'роза одноголовый родос 70 см кения плантация Subati Flowers Limited 10 штука в упаковка',
#  'сумка-тележка GIMI ITALO blue синий',
#  'щетка для мытье посуда колибри М5202 больший',
#  'миксер василиса ВА-506 белый с красный/малиновый 180 вт 7 скоростной режим',
#  'сушилка для белье напольный ника СБ3 10 м',
#  'ключница картина W-12 замок 35х30 см',
#  'разделочный доска Attribute GRANITE 20х30 см ABX111',
#  'штора для ванный Spirella / спирелла TEX Porto, белый, текстиль с гидрофобный пропитка, 180*200 см, 1033938',
#  'тарелка обеденный стелла шоколад 25 см J1762 Luminarc',
#  'чайник электрический василиса Т30-2000 нержавеющий сталь черный c красный 2000 вт 1,8 л',
#  'аптений d-12 см h-15 см',
#  'мантоварка-пароварка WEBBER BE-81 нержавеющий сталь d=30 см',
#  'складной картонный коробка для хранение 30х20х15 см с уголок белый hm-9741-3 Hausmann',
#  'спатифиллум шопен d-12 см',
#  'чехол для гладильный доска Colombo клубок пряжа серый/розовый 140х55 см из хлопок 5550',
#  'сушилка для белье напольный ника СБ3Б 10 м белый',
#  'контейнер герметичный прямоугольный виолета 092/051 500 мл дымчатый',
#  'набор вешалка пластмассовый Rozenbal R181900',
#  'искусственный цветок пластиковый нарцисс 3 бутон королевский 46 см',
#  'емкость для соус с ложка PASABAHCE 200 мл OTS131505-000',
#  'фикус каучуконосный эластик абиджан d-12 см h-30 см',
#  'тарелка суповой Luminarc мариса оранж 20 см J7687',
#  'чехол Eurogold Clean Metallic металлизированый с поролон для доска 120х38-120х42 см C42F3M',
#  'защитный соль для посудомоечный машина Ludwik 1,5 кг польша 5900861242227',
#  'чехол для гладильный доска METAL 135х53 см, Attribute, ABM105',
#  'таз пластмассовый 16,0 л пищевой круглый М2507, 1404037',
#  'гипоаллергенный концентрированный гель для стирка белье VPK для деликатный ткань 2,5 л корея 8809473130144',
#  'коврик придверный с дизайн, из резина и кокос 58,5*89 Gothic Iron Slice / готический узор, 4468',
#  'муляж ананас 21 см',
#  'скатерть 150х120 см WELLNESS WT125-куэн 100% полиэстер',
#  'сумка-тележка 2-х колесный Gimi Argo черный',
#  'коврик кухонный APACHE Coffee Chef 45x75 см 5420',
#  'гладильный доска NIKA HAUSHALT тефлон золотой 122х40 см HP1T/G',
#  'вешалка-перекладина Valiant металлический двойной с антискользящий покрытие 50320',
#  'скатерть муза 100% полиэфир овальный 180х150 см сливочный с цветок, Wellness, WTO185-муза*04',
#  'кружка мерный 11600 1 л',
#  'сушилка для белье лиана люкс 110 см потолочный',
#  'роза патио оранжевый d-12 см h-30',
#  'фиалка d-9 см белый махровый',
#  'штора для ванный Spirella / спирелла TEX Shine текстиль с гидрофобный пропитка, шампань, 180*200 см, 1015640',
#  'модульный стеклянный банка 1,1л, 298264, Brabantia,',
#  'сушилка для белье Zalger Simfony 1255-90 одноуровневый с крыло 20 м',
#  'контейнер для мусор пластиковый 50 л 40,7х30,6х72,7 см ролл топ серый, Curver, D 03977-856',
#  'сушилка для белье настенный ника СН90 серебро 90 см',
#  'перчатка Fabrikators для чистка овощ детский оранжевый KO2PU',
#  'термостакан WEBBER ВЕ-6031 чай 450 мл',
#  'столовый ложка Attribute FORTRESS 2 шт ACF622',
#  'сушилка для белье Hausmann Hermes De Luxe 20 м 03-010C-1',
#  'подставка для нож ALPENKOK круглый из пластика 11*22 см красный AK-202ST',
#  'лестница стремянка зми конек медный антик ТС 277',
#  'чайный набор Luminarc лили флауэр 6 шт 320 мл J8565',
#  'весы напольный Edition Feet механический',
#  'банка стеклянный с металлический крышка и краник Attribute GRAPE 3,8 л ABS038',
#  'карниз для ванный комната виолета раздвижной 210 см с кольцо белый 2110/6',
#  'азалий индик фиолетовый d-10 см h-20',
#  'пеларгония зональный махровый белый взрослый растение',
#  'пеларгония розебудный Emma укоренять черенок',
#  'пеларгония розебудный Mary укоренять черенок',
#  'пеларгония розебудный Prins Nikolai укоренять черенок',
#  'полка QWERTY берлин черный 44х24х10 см 40х20х10 см 36х16х10 см 72008',
#  'штора для ванный комната пвх 180х180 см ракушка бежевый, 5923',
#  'крючок проволочный 75 мм латунь, 1110136',
#  'цветок искусственный тюльпан 40 см пластик цвет в ассортимент',
#  'просеиватель для мука D27см., RSB',
#  'мусорный контейнер Hailo BigBin Swing 45 0845-010 45 л хром',
#  'пеларгония Toscana Angeleyes Amarillo Burgundy укоренять черенок',
#  'пеларгония Toscana Angeleyes Amarillo Rosato укоренять черенок',
#  'пеларгония розебудный Queen Ingrid укоренять черенок',
#  'пеларгония розебудный Red Pandora укоренять черенок',
#  'пеларгония Toscana Angeleyes Bicolor укоренять черенок',
#  'кастрюля чугунный 24 см, красный, 3.6 л, PYREX, SC5AC24/5141',
#  'сидение для гладильный доска Leifheit Niveau, 71325',
#  'штора для ванный 180х200 см, Rigone розовый',
#  'весы настольный электронный DELTA ксе-01 белый 5кг',
#  'крючок проволочный 125 мм медь, 1110132',
#  'гладильный доска ника верона 1 чехол мужчина с роза 122х42 см ДВ1м',
#  'средство для мытье посуда Vestar гранат 1000 мл россия 4620757211700',
#  'толкушка деревянный ( бук ) 1530018',
#  'махровый полотенце 70х35 см WELLNESS EXCLUSIVE 1ДСЖ1_йот_1-67 100% хлопок',
#  'вешалка ника комфорт 6 напольный серебро ВК6с',
#  'швабра для пол с отжим и фиксатор микрофибра, R212608, ROZENBAL',
#  'кодонант укоренять черенок 1 шт',
#  'кофр для хранение Hausmann средний 36х36х30 2 шт. 4c-202',
#  'лестница-стремянка Dogrular Ufuk оцинковывать 8-ми ступенчатый',
#  'гладильный доска ника лина 1 112х34,5 см ДЛ1',
#  'гладильный доска Dogrular эко инж 110х33 см 224414',
#  'средство для быстрый удаление жировой загрязнение DECS антижир 500 мл россия 4660015923259',
#  'совок и щетка на стальной длинный рукоятка 120 см, Rozenbal, R500028',
#  'веник сорго с деревянный ручка с 4-мя шов, Rozenbal, R206204',
#  'сушилка для белье потолочный Zalger Lift Basic 1520 200 см 10 м',
#  'хлебница деревянный (бук) кб-028, 35х28х19 см 1524002',
#  'сумка-тележка хозяйственный GIMI KANGOO THERMO powder коричневый',
#  'гладильный доска белль-Юниор1 34,5х112см дсп 1200006',
#  'искусственный цветок мимоза пластиковый желтый',
#  'гладильный доска Sarayli Grown Lux 45х125 см',
#  'пеларгония розебудный Margaretha укоренять черенок',
#  'тарелка суповой стоунмания капучино 20 см J2132 Luminarc',
#  'антуриум андрианум пикассо голубой d-15 см',
#  'гладильный доска Eurogold Europa Paris 120х38 см 21738F6EC',
#  'скатерть Dasch донна роза из пвх 0401-2 роза овальный 122х152 см 5953',
#  'тарелка десертный Luminarc син сильвер 19 см L0886',
#  'искусственный цветок ландыш пластиковый малый белый',
#  'корзина для белье виолета с крышка ротанг 60 л белый 1860/06',
#  'кружка Luminarc шэйдс блэк 320 мл H8401',
#  'гербер комнатный желтый-оранжевый d-12 см',
#  'насадка-отжим пластиковый бирюзовый для ведро Classic Mop, Leifheit, 52002',
#  'муляж оранжевый яблоко мини полиуретан d-6 см',
#  'тарелка десертный Luminarc дивали 19 см D7358',
#  'ковер придверный EKSPO 40x60 см серый РР105/01001',
#  'гладильный доска ника эльза де люкс 122х40 см эл',
#  "коврик для туалет L'CADESI HURREM 50х60 см с вырез бежевый 315602",
#  'ведро пластиковый универсальный 12 л цвет морской волна, Leifheit, 52000',
#  'искусственный лиана плющ 2,4 м',
#  'салатник Luminarc эмпилабль велад 17 см L7997',
#  'искусственный цветок ландыш пластиковый большой белый',
#  'сумка-тележка хозяйственный Rolser Jet Joy серебро, JET016 plata JOY',
#  'чехол для одежда объемный Hausmann с овальный окно пвх и ручка 60х100х10 см черный HM-701003AG',
#  'цикламен, цвет в ассортимент',
#  'тарелка десертный Attribute LILY TRACERY WHITE 20 см ADL021',
#  'коврик придверный из резина и кокос, 40х68 см, Format Forme, кот, серый, PHP SRL, 20920',
#  'фаленопсис люкс микс 1 ствол d-12 см',
#  'цикламен d-12 см h-20 цвет в ассортимент',
#  'гимнокалициум микс d-5 см',
#  'сумка-тележка хозяйственный Rolser Jet C. Capri Joy черный, JET017 negro JOY',
#  'штора для ванный комната 240х200 Rigone розовый текстильный 240х200 см 6043',
#  'кружка марля эклипсы 250 мл H9184 Luminarc франция',
#  'гладильный доска Eurogold DELUX 130х48 см 35348R',
#  'емкость для свч LUX 4.4 л прямоугольный, Curver, 15537',
#  'блюдце утро эклипсы, J3261, Luminarc, франция',
#  'примула желтый с оранжевый в горшок d-10 см',
#  'гладильный доска ника белль классик 2 122х34,5 см БК2',
#  'сушилка для белье виолета Julia 20 м хром J-20',
#  'сушилка для белье потолочный лиана люкс 150 см ЛЛП-150',
#  'пылесос DELTA DL-0835 синий 1600 вт мешок для сбор пыль 1 в подарок мощность всасывание 300 вт',
#  'зубной паста Systema Tartar против образование зубной камень 120 г корея 8806325-616764',
#  'вешалка деревянный для верхний одежда 45 см',
#  'контейнер для свч полимербыт премиум 0,5 л 4356000',
#  'корзина для белье эльфпласт виола 30 л бежевый 204',
#  'калатея крокат d-15 см',
#  'кофе арабика d-9 см',
#  'вешалка напольный с подставка для сумка BLUES темный на колесико степанов',
#  'пеларгония зональный диам. 12 см розовый рябой полумахровый',
#  'нетканый салфетка в рулон 70 шт EUROHOUSE EH4967',
#  'контейнер для продукт PASABAHCE 1,25 л голубой OTS161560-005',
#  'антуриум тропик найт нидерланды 1 штука в упаковка',
#  'сушилка для белье потолочный лиана люкс 210 см ЛЛП-210',
#  'эхинокактус грузонь d-5 см',
#  'коврик для ванный комната ORSINI хлопок 90х60 см светло-бежевый, Spirella, 1013512',
#  'чехол для костюм 60х110 см Rozenbal R261016',
#  'искусственный цветок букет примула пластиковый лиловый',
#  'термокружок вакуумный Alpenkok из нержавеющий сталь AK-04002A коричневый 400 мл',
#  'корзина для белье бамбук угловой 37х58см, Attribute, ASB386',
#  'набор махровый салфетка фита_3, 100% хлопок 315 г/м2, 34х35 см, 3 шт, цвет в ассортимент, Wellness, 4630005367202',
#  'коврик придверный влаговпитывать Hello, Bonjour, Ciao из перерабатывать резина и ковровый покрытие 60х90 см, Apache, 4658',
#  'сушилка для белье виолета Julia 20 м белый J-20W',
#  'чайник заварочный Luminarc элиз 1,4 л H2258',
#  'коврик интерьерный 45х75 вино Comfort Mats, Mohawk, 5079',
#  'вантуз черный с длинный ручка (D-110 мм, L-380 мм), 1206007',
#  'полка QWERTY мадрид белый/черный 50х30х12 см 2 штука и 30х24х12 см 2 штука 72019',
#  'цветок искусственный роза с закрывать бутон цвет в ассортимент 50 см',
#  'бальзамин новогвинейский d-13 см ярко красный',
#  'сушилка для белье потолочно-настенный Gimi Lift 200',
#  'стремянка Colombo Factotum алюминиевый 3 ступень',
#  'коврик придверный хлопковый 55х110 см мультиколор, Helex, С03',
#  'чехол Eurogold Reflector с металлизированный полоса, поролон для доска 120х38-120x42 см DC42F3R',
#  'искусственный цветок подснежник садовый пластиковый розовый',
#  'комплект махровый полотенце 60х30 см WELLNESS промой_3 100% хлопок',
#  'сумка-тележка 2-х колесный Gimi Galaxy красный',
#  'чехол для гладильный доска Colombo Persia Beige 130х50 см из хлопок 5379',
#  'корыто оцинковывать 45 л бесшовный, 1303007',
#  'сумка-тележка 2-х колесный Gimi Argo красный',
#  'фал капроновый 6 мм в бухта 300м т-1, 1201050',
#  'форма АLPENKOK AK-6062S для выпечка Love розовый 21,5*24,5*4 см',
#  'пеларгония зональный простой цвет фуксия взрослый растение',
#  'орехоколка VIVA, Attribute, ATV600',
#  'корзина для белье эльфпласт виола 30 л коричневый 204к',
#  'фиалка d-9 см малиновый простой',
#  'сушилка для белье Gimi Modular 3 Lux Silver',
#  'штанга для ванный г-образный, угловой 80Х170 см, хром',
#  'рассада зелень для кухня душица-орегано розовый объем 0,5 л',
#  'рассада зелень для кухня мята морокан диам. 9 см',
#  'рассада зелень для кухня мята эппл минт диам. 9 см',
#  'рассада зелень для кухня розмарин блю лагуна диам. 9 см',
#  'рассада зелень для кухня тимьян вульгарис компактус диам. 9 см',
#  'рассада зелень для кухня тимьян-чабрец розовый объем 0,5 л',
#  'рассада пряный трава кофе арабика в горшок d-9 см',
#  'чайный набор Luminarc отантик сильвер 220 мл H8388',
#  'сумка-тележка хозяйственный Andersen Alu Star Shopper, Hava, синий 115-103-90',
#  'гладильный доска Hausmann Classic MONO 120x38 см HM-2122',
#  'сумка-тележка хозяйственный Rolser JET029 azul-lois JOY синий',
#  'увлажнять маска Brown Rice Moisture 330 мл корея 599928',
#  'сушилка для белье Gimi Duplo',
#  'искусственный цветок лилейник пластиковый светло-лиловый',
#  'корзина для гладить белье NATURAL STYLE пластиковый темно-серый 45 л 38х59,2х27 см, Curver, D 00708-308',
#  'пеларгония зональный диам. 12 см малиновый розовый простой',
#  'пеларгония зональный диам. 12 см ярко розовый махровый',
#  'фиалка химера d-12 см',
#  ...]

# %%
# Выведем популярные направления для товаров.

text = m.lemmatize(' '.join(lemmas))
Counter(text)
# Out:
# Counter({'комнатный': 26,
#          ' ': 16887,
#          'растение': 29,
#          'в': 263,
#          'горшок': 128,
#          'алый': 2,
#          'вера': 2,
#          ', ': 999,
#          'd12': 3,
#          'h30': 6,
#          'кофе': 5,
#          'арабика': 4,
#          'h25': 1,
#          'радермахер': 1,
#          'd': 240,
#          '-': 919,
#          '12': 147,
#          'см': 1015,
#          'h': 58,
#          '20': 70,
#          'хризолидокарпус': 1,
#          'лутесценс': 1,
#          '9': 121,
#          'циперус': 1,
#          'зумул': 1,
#          '25': 40,
#          'шеффлер': 2,
#          'лузеан': 1,
#          'юкка': 1,
#          'нитчатый': 1,
#          '35': 7,
#          'настенный': 30,
#          'сушилка': 115,
#          'для': 521,
#          'белье': 139,
#          'Gimi': 57,
#          'Brio': 4,
#          'Super': 6,
#          '100': 53,
#          'таз': 30,
#          'пластмассовый': 52,
#          '21': 20,
#          ',': 281,
#          '0': 158,
#          'л': 239,
#          'круглый': 20,
#          ' "': 20,
#          'водолей': 1,
#          '" ': 17,
#          'С614': 1,
#          '1404056': 1,
#          'вешалка': 48,
#          'брюки': 4,
#          'металлический': 26,
#          'с': 240,
#          'резиновый': 7,
#          'покрытие': 30,
#          '26': 10,
#          'цвет': 45,
#          ': ': 4,
#          'синий': 62,
#          'Attribute': 57,
#          'AHS331': 1,
#          'потолочный': 29,
#          'Zalger': 21,
#          'Lift': 13,
#          'Basic': 5,
#          '1520': 2,
#          '200': 19,
#          '10': 96,
#          'м': 59,
#          'крючок': 15,
#          'одежный': 2,
#          '2': 107,
#          'х': 34,
#          'рожковый': 1,
#          'серый': 37,
#          'металлик': 1,
#          'полимерный': 5,
#          ' *': 11,
#          'тонар': 3,
#          '*, ': 6,
#          '1110027': 1,
#          'корзина': 22,
#          'мягкий': 7,
#          'пластиковый': 54,
#          '17': 17,
#          'пластика': 4,
#          'M2880': 1,
#          'многолетний': 1,
#          'тимьян': 15,
#          'чабрец': 2,
#          'розовый': 82,
#          'объем': 113,
#          '5': 185,
#          'рассада': 214,
#          'зелень': 68,
#          'кухня': 71,
#          'базилик': 11,
#          'тонус': 3,
#          'кассета': 165,
#          'по': 97,
#          '6шт': 33,
#          'мелисса': 5,
#          'диам': 95,
#          '. ': 103,
#          'муляж': 68,
#          'райский': 1,
#          'яблочко': 1,
#          'зеленый': 34,
#          'шт': 165,
#          'полиуретан': 41,
#          '3': 78,
#          'банан': 3,
#          'желтый': 46,
#          'Fancy': 17,
#          'Fair': 17,
#          '/': 124,
#          'ff': 12,
#          'XJ210': 1,
#          'виноград': 8,
#          '14': 12,
#          'ассортимент': 31,
#          'гранат': 4,
#          '9см': 11,
#          'красный': 138,
#          'SL90': 1,
#          'груша': 5,
#          'мини': 21,
#          '4': 97,
#          'LI95': 2,
#          '03': 2,
#          'яблоко': 10,
#          '6': 107,
#          'клубника': 9,
#          '1': 101,
#          'на': 49,
#          'магнит': 4,
#          'лимон': 5,
#          'NM90': 1,
#          'мандарин': 3,
#          'оранжевый': 46,
#          '8': 32,
#          'JZ80': 1,
#          'перец': 8,
#          'GP8': 1,
#          'RP8': 1,
#          'персик': 3,
#          'томат': 93,
#          'T9': 1,
#          'черешня': 2,
#          '3см': 1,
#          '.': 36,
#          'SCR30': 1,
#          'сумка': 96,
#          'тележка': 105,
#          'большой': 12,
#          'комбинированный': 1,
#          '45': 22,
#          '*': 82,
#          '30': 50,
#          '1209021': 1,
#          'тарелка': 33,
#          'обеденный': 12,
#          'фиц': 1,
#          '25см': 1,
#          'G9547': 1,
#          'Luminarc': 78,
#          'франция': 18,
#          'ерш': 10,
#          'туалет': 3,
#          'подставка': 11,
#          'MALIBU': 1,
#          'фарфор': 1,
#          '47х12': 1,
#          'белый': 165,
#          'Spirella': 21,
#          '1001768': 1,
#          'пеларгония': 86,
#          'зональный': 61,
#          'малиновый': 28,
#          'полумахровый': 21,
#          'сиреневый': 21,
#          'простой': 19,
#          'Prima': 1,
#          '510': 2,
#          '720': 1,
#          'веревочный': 1,
#          '7': 69,
#          'линия': 3,
#          'котел': 1,
#          'алюминиевый': 35,
#          '70': 9,
#          'без': 12,
#          'крышка': 37,
#          'балезино': 1,
#          'хозлэнд': 5,
#          '1502050': 1,
#          'суккулент': 1,
#          'микс': 30,
#          'эхеверие': 3,
#          'перл': 1,
#          'фон': 2,
#          'нюрнберг': 1,
#          'доска': 123,
#          'гладильный': 106,
#          'Eurogold': 16,
#          'Professional': 2,
#          '130х48': 5,
#          'сетка': 4,
#          '35748W': 2,
#          'коврик': 66,
#          'придверный': 36,
#          '45х75см': 1,
#          'рельефный': 1,
#          'рисунок': 9,
#          'Welcome': 2,
#          '", ': 12,
#          'коричневый': 26,
#          'CR005': 1,
#          'Bacchetta': 21,
#          'MagicStop': 1,
#          '3x1': 1,
#          'бежевый': 30,
#          'сушка': 1,
#          'посуда': 9,
#          '2289': 1,
#          'гладить': 2,
#          'Natural': 2,
#          'Style': 2,
#          '27': 4,
#          '38': 5,
#          '59': 2,
#          'D': 9,
#          '00708': 3,
#          '213': 2,
#          'Curver': 11,
#          '60л': 1,
#          '1860': 2,
#          'виолета': 24,
#          'подкладка': 2,
#          'под': 7,
#          'чехол': 55,
#          '520140': 1,
#          '135х50': 2,
#          'поролон': 10,
#          'набор': 47,
#          'кружок': 13,
#          'пиво': 2,
#          'гамбург': 1,
#          '2шт': 1,
#          '500мл': 1,
#          'H5072': 1,
#          'россия': 47,
#          'интерьерный': 4,
#          'Village': 1,
#          'Street': 1,
#          'Floral': 2,
#          'из': 78,
#          'пвх': 31,
#          'прямоугольный': 21,
#          '50х107': 1,
#          'Apache': 8,
#          '4663': 1,
#          'дозатор': 2,
#          'мыло': 8,
#          'Hausmann': 26,
#          'HM': 14,
#          'B0194R': 1,
#          'унитазный': 4,
#          'WC': 3,
#          'стандарт': 4,
#          'мультипласт': 3,
#          '1712010': 1,
#          'нож': 20,
#          'чистка': 6,
#          'овощ': 6,
#          'WEBBER': 19,
#          'нержавеющий': 23,
#          'сталь': 34,
#          '12х6': 1,
#          '8х1': 1,
#          'ВЕ': 11,
#          '5275': 1,
#          '520114': 1,
#          'войлок': 2,
#          '24': 10,
#          'G60': 1,
#          'Y': 1,
#          'G85': 2,
#          'G': 2,
#          'черный': 60,
#          'B': 2,
#          'вишня': 5,
#          'вишневый': 3,
#          'CR30': 1,
#          '01': 5,
#          'TZ90': 1,
#          'фужер': 5,
#          'дампьер': 1,
#          'сильвер': 5,
#          'вино': 5,
#          '260': 1,
#          'мл': 66,
#          'H7939': 1,
#          'цветок': 114,
#          'искусственный': 59,
#          'гвоздик': 9,
#          'тканевый': 3,
#          '50': 33,
#          'эвкалипт': 5,
#          'гунни': 2,
#          '60': 20,
#          'хозяйственный': 75,
#          'Market': 2,
#          'герань': 23,
#          'домашний': 21,
#          ' (': 162,
#          ') ': 135,
#          'цвести': 22,
#          ' , ': 8,
#          'D12': 27,
#          'H25': 21,
#          'махровый': 62,
#          'Andersen': 9,
#          'Scala': 7,
#          'Shopper': 9,
#          'Plus': 7,
#          'Elba': 2,
#          '133': 3,
#          '051': 3,
#          '80': 14,
#          'Rolser': 32,
#          'Jet': 10,
#          'Cuadro': 1,
#          'MH': 1,
#          'Joy': 11,
#          'серо': 1,
#          'JET019': 1,
#          'marengo': 6,
#          'JOY': 16,
#          'плед': 3,
#          'флисовый': 4,
#          '% ': 49,
#          'полиэстер': 23,
#          '185х240': 1,
#          'Wellness': 29,
#          'WP184': 1,
#          'айленд': 1,
#          '_': 18,
#          'скатерть': 27,
#          'династия': 2,
#          'полиэфир': 10,
#          '350х180': 2,
#          'сливочный': 4,
#          'WT355': 1,
#          '02': 4,
#          'лососевый': 6,
#          'хлопковый': 9,
#          '40х60': 2,
#          '6194': 1,
#          '45х75': 6,
#          '6195': 1,
#          'батарея': 4,
#          'СБ5': 2,
#          'ника': 74,
#          'кувшин': 3,
#          'кумган': 1,
#          '1408003': 1,
#          'вилка': 5,
#          'столовая': 6,
#          'RIPPLE': 5,
#          'мм': 36,
#          'ACR013': 1,
#          'ложка': 12,
#          'ACR023': 1,
#          'чайная': 1,
#          'ACR033': 1,
#          'столовый': 7,
#          'г': 61,
#          'ACR042': 2,
#          'чили': 4,
#          'связка': 3,
#          'GP60': 1,
#          'адиантум': 1,
#          'лиза': 1,
#          'коралловый': 3,
#          'ковер': 8,
#          'MULTY': 1,
#          'RUS': 2,
#          '120х180см': 1,
#          'РР214': 1,
#          '07034': 1,
#          'перчатка': 6,
#          'латексный': 2,
#          '№': 81,
#          'дом': 1,
#          'утолщенный': 1,
#          'Rozenbal': 11,
#          'R105628': 1,
#          'стремянка': 35,
#          'Hailo': 9,
#          '4302': 1,
#          '301': 1,
#          'LivingStep': 1,
#          'Comfort': 6,
#          'PLus': 1,
#          'ступенчатый': 15,
#          'темнорозовый': 2,
#          'Jean': 1,
#          'Green': 1,
#          'Line': 2,
#          '107х30': 1,
#          'лестница': 9,
#          'Dogrular': 12,
#          'Ufuk': 7,
#          'оцинковывать': 11,
#          'ми': 2,
#          'колесный': 17,
#          'Argo': 9,
#          'толкушка': 2,
#          'картофель': 1,
#          'Proline': 1,
#          'Leifheit': 40,
#          '03032': 1,
#          'роза': 68,
#          'маргарита': 2,
#          'пластик': 18,
#          '58': 6,
#          'бутылка': 1,
#          'натуральный': 1,
#          'волокно': 2,
#          'и': 77,
#          'металл': 3,
#          '23': 11,
#          'кремовый': 4,
#          'Burstenmann': 5,
#          '0473': 1,
#          '0003': 1,
#          'костюм': 4,
#          '45см': 2,
#          '4шт': 1,
#          'AHP224': 3,
#          'пищевой': 20,
#          'овальный': 21,
#          'Ekko': 2,
#          '2776': 1,
#          '1404043': 1,
#          'потолочно': 9,
#          '220': 6,
#          '5030': 1,
#          '15': 26,
#          '2775': 1,
#          '1404032': 1,
#          '18': 20,
#          'Иж': 7,
#          '), ': 26,
#          '1404047': 1,
#          'минеральный': 7,
#          'вода': 7,
#          '1404045': 1,
#          '1404006': 1,
#          'лиана': 26,
#          '1703010': 1,
#          'банк': 16,
#          'со': 23,
#          'стеклянный': 18,
#          'COLOR': 6,
#          'SERIES': 4,
#          '300': 9,
#          'VALIANT': 8,
#          'JP': 2,
#          'S300': 1,
#          '280': 4,
#          'S280': 1,
#          'Tris': 3,
#          'ванный': 71,
#          'комната': 52,
#          ', "': 6,
#          'офелия': 1,
#          '40х50': 2,
#          '50х80см': 1,
#          'NTBM50804050': 1,
#          '190': 2,
#          'Ricko': 1,
#          '5м': 1,
#          'Rk': 1,
#          'комплект': 5,
#          'Dasch': 11,
#          '50х80': 6,
#          '55х55': 2,
#          'TL': 2,
#          'E': 2,
#          'лавр': 5,
#          '5755': 1,
#          'стяжка': 2,
#          'оконный': 3,
#          'болт': 1,
#          'ст': 1,
#          '55': 5,
#          'цинк': 1,
#          '1108354': 1,
#          'апельсин': 1,
#          'Welfull': 2,
#          'Daisy': 1,
#          '002': 3,
#          'кампануть': 1,
#          'двухцветный': 1,
#          'душистый': 3,
#          '13': 24,
#          'Alablock': 2,
#          'багажный': 14,
#          'DELTA': 21,
#          'ТБР': 10,
#          '22': 13,
#          'грузоподъемность': 14,
#          'кг': 27,
#          'каркас': 12,
#          'ярко': 7,
#          'C': 4,
#          'Capri': 3,
#          'JET017': 3,
#          'azul': 7,
#          'противень': 1,
#          '340х240х25': 1,
#          'эксперт': 2,
#          'Scovo': 5,
#          'СЭ': 2,
#          '052': 1,
#          ', /': 4,
#          '1503028': 1,
#          '180': 12,
#          'калатея': 2,
#          'влаговпитывать': 2,
#          'ребристый': 4,
#          'материал': 3,
#          '90х120': 1,
#          'Vortex': 2,
#          'K041': 1,
#          'нолина': 1,
#          'цветной': 17,
#          'керамика': 5,
#          'плечики': 10,
#          'размер': 5,
#          '48': 4,
#          ' - ': 4,
#          '54': 6,
#          ' ) "': 1,
#          'мп': 3,
#          '1205160': 2,
#          'подушка': 2,
#          'декоративный': 9,
#          '40': 15,
#          'клетка': 2,
#          'WP44': 1,
#          'атланта': 2,
#          '34': 3,
#          'полотенце': 12,
#          'кухонный': 12,
#          'милый': 1,
#          '* ': 4,
#          'mix': 3,
#          'хлопок': 43,
#          '170': 4,
#          'м2': 8,
#          '38х63': 1,
#          '4630005366090': 1,
#          'хлорофитум': 2,
#          'цикламен': 14,
#          'глоксиния': 2,
#          'азалий': 6,
#          'индик': 4,
#          'биколор': 3,
#          'гортензия': 4,
#          'хризантема': 6,
#          'космо': 1,
#          '1703005': 1,
#          'тыква': 10,
#          'Tuscan': 1,
#          'Wine': 1,
#          '4660': 1,
#          'Lampo': 1,
#          'верона': 3,
#          'одри': 1,
#          '122х42': 6,
#          'ДВ1о': 1,
#          'сковорода': 11,
#          'ALPENKOK': 9,
#          'AK': 12,
#          '24GL': 1,
#          '28': 5,
#          '28GL': 1,
#          'салфетка': 11,
#          'Protec': 3,
#          'Textil': 3,
#          'Lino': 2,
#          '30х43': 3,
#          '6226': 1,
#          'Clean': 6,
#          'Metallic': 2,
#          'металлизированый': 2,
#          '110х30': 3,
#          '114x34': 2,
#          'C34F3M': 1,
#          'вкладыш': 1,
#          'хранение': 10,
#          'cm': 1,
#          'MARMITON': 1,
#          'LG17056': 1,
#          'миксер': 3,
#          'LUX': 6,
#          'DL': 8,
#          '5068': 1,
#          'серо-голубой': 1,
#          '400': 11,
#          'вт': 19,
#          'насадка': 11,
#          'скоростной': 2,
#          'режим': 3,
#          'турбореживать': 1,
#          'влаговпитывающий': 4,
#          'индия': 1,
#          'зигзаг': 1,
#          '6204': 1,
#          'кофр': 5,
#          'медикамент': 1,
#          'отделение': 1,
#          '30x22x12': 1,
#          '4W': 1,
#          '107': 1,
#          'стиральный': 2,
#          'биопорошок': 1,
#          'BONSAI': 1,
#          'концентрировать': 1,
#          '4607974420573': 1,
#          'чистить': 1,
#          'крем': 1,
#          'трудновыводимый': 1,
#          'пятно': 2,
#          'Mama': 4,
#          'Lemon': 1,
#          'stain': 1,
#          'remover': 1,
#          '500': 14,
#          'гр': 4,
#          'индонезия': 1,
#          '8998866106207': 1,
#          'термокружок': 8,
#          'AVEX': 3,
#          'Recharge': 1,
#          'голубой': 29,
#          'AVEX0681': 1,
#          'щетка': 19,
#          'смахивание': 1,
#          'пыль': 4,
#          'разноцветный': 2,
#          '0528': 1,
#          '0000': 5,
#          'мирт': 2,
#          'цветущий': 1,
#          'диаметр': 14,
#          '520138': 1,
#          '140х50': 2,
#          'металлизировать': 3,
#          '135х45': 2,
#          'крепеж': 2,
#          'пружина': 4,
#          'дверной': 3,
#          '1107055': 1,
#          '240': 3,
#          'д': 5,
#          '19': 10,
#          'крепление': 2,
#          '1107014': 1,
#          '5031': 2,
#          '1404021': 1,
#          'Marmiton': 1,
#          'сердце': 4,
#          'антипригарный': 7,
#          'LG17085': 1,
#          'MARBLE': 2,
#          ' = ': 4,
#          '0039A': 1,
#          '26N': 1,
#          '26GL': 1,
#          'напольный': 26,
#          'Colombo': 9,
#          'Star': 3,
#          '3679': 2,
#          'кориандр': 3,
#          'арарат': 3,
#          'петрушка': 8,
#          'универсал': 2,
#          'шалфей': 3,
#          'одежда': 19,
#          'EVA': 4,
#          '60х95': 1,
#          'EVE4214': 1,
#          'принт': 2,
#          '60х100': 3,
#          'EA1104': 1,
#          'платье': 1,
#          'неткать': 1,
#          '135': 1,
#          '2B': 2,
#          '360135': 1,
#          '1703011': 1,
#          'жидкий': 2,
#          'Vestar': 3,
#          '750': 6,
#          '4620757212370': 1,
#          'лапша': 1,
#          '60х90см': 2,
#          'ажурный': 6,
#          'Iron': 3,
#          'Grill': 1,
#          '6207': 1,
#          'пена': 1,
#          'ванна': 15,
#          'хвойный': 1,
#          'пихта': 1,
#          '900': 1,
#          '4620757212424': 1,
#          'складной': 9,
#          'ТХ0253': 1,
#          'пэмби': 2,
#          '350х170': 1,
#          ') "': 5,
#          '- ': 4,
#          'М2506': 1,
#          '1404091': 1,
#          'мерка': 1,
#          '1404028': 1,
#          '1404079': 1,
#          '1404038': 1,
#          '16': 23,
#          'С12129': 1,
#          '1404034': 1,
#          'ручка': 48,
#          'С203': 1,
#          '303': 2,
#          'полимербыт': 12,
#          '1404039': 1,
#          'Haushalt': 1,
#          'M': 6,
#          '122х40': 11,
#          'подрукавник': 3,
#          'п': 2,
#          'штора': 52,
#          'встроенный': 5,
#          'кольцо': 15,
#          'штанга': 7,
#          'душа': 8,
#          'жаккард': 7,
#          'полиамидный': 5,
#          '180х200': 23,
#          'аквамарин': 3,
#          'HSC': 5,
#          'ST04': 3,
#          'aquamarin': 1,
#          'ST12': 1,
#          'blue': 3,
#          'ST05': 1,
#          'beige': 1,
#          'white': 1,
#          '65': 4,
#          'навесный': 2,
#          'ADM125': 1,
#          'аспарагус': 3,
#          'афеляндр': 2,
#          'скуаррос': 2,
#          'дания': 2,
#          'кашпо': 21,
#          'автополив': 2,
#          'свереть': 1,
#          'дерево': 7,
#          '888': 4,
#          '6867540': 1,
#          '0512261': 1,
#          'сверло': 3,
#          'фреза': 2,
#          'нитрид': 2,
#          'титан': 2,
#          '6862060': 1,
#          '0512262': 1,
#          '6862080': 1,
#          '0512263': 1,
#          'дсп': 5,
#          'бэлль': 4,
#          'ЮНИОР2': 2,
#          '112': 5,
#          'БЮ2': 2,
#          'контейнер': 15,
#          'секционный': 3,
#          'лоток': 6,
#          '4312600': 1,
#          'люкс': 19,
#          '130': 1,
#          'ступень': 16,
#          'СА5': 1,
#          'UNIVERSAL': 1,
#          '160х60': 1,
#          'ABU004': 1,
#          'Sarayli': 5,
#          'Orion': 1,
#          '130x44': 2,
#          'мусорный': 2,
#          'ProfiLine': 1,
#          'SoLid': 1,
#          '0514': 1,
#          '089': 1,
#          'перф': 1,
#          '10+': 2,
#          '122': 2,
#          'Н10': 2,
#          '+': 8,
#          'RAINBOW': 1,
#          'хромировать': 2,
#          '201': 1,
#          '5х55х93': 1,
#          'зубной': 6,
#          'паста': 7,
#          'Zact': 3,
#          'эффект': 1,
#          'отбеливание': 1,
#          'кофейный': 1,
#          'никотиновый': 1,
#          'налет': 3,
#          '150': 7,
#          '8806325': 2,
#          '603849': 1,
#          'Lion': 3,
#          'Smokers': 1,
#          'Toothpaste': 2,
#          '8850002805040': 1,
#          'Whitening': 1,
#          '8850002805064': 1,
#          'тонкий': 1,
#          'нарезка': 1,
#          'пилообразный': 1,
#          '2082': 1,
#          'антуриум': 7,
#          'андрианум': 6,
#          'блэк': 7,
#          'мейер': 1,
#          'молодило': 1,
#          'фиалка': 10,
#          '11': 11,
#          '95х33': 2,
#          '848N': 2,
#          'DASCH': 2,
#          'гербера': 3,
#          'душица': 5,
#          'обыкновенный': 7,
#          'лекарственный': 6,
#          'кордан': 3,
#          'мерседес': 1,
#          'карнавал': 1,
#          'кристалл': 1,
#          'тобаго': 1,
#          '1703009': 1,
#          'ТХ0252': 1,
#          'карниз': 8,
#          'телескопический': 5,
#          ' / ': 13,
#          'спирелла': 6,
#          'Magic': 3,
#          'хром': 6,
#          '125': 2,
#          '1050767': 1,
#          'New': 4,
#          'Elegant': 1,
#          '125x45': 1,
#          'Polyline': 1,
#          'аметист': 1,
#          '6230': 1,
#          'Al': 3,
#          'алюминевый': 3,
#          'ти': 2,
#          'унитаз': 3,
#          'VENISE': 1,
#          'керамический': 6,
#          '4007036': 1,
#          'мусор': 7,
#          'FLIP': 2,
#          'BIN': 2,
#          'CURVER': 9,
#          '02171': 2,
#          '547': 1,
#          '00': 9,
#          '535': 1,
#          'СМ4': 1,
#          'швабра': 13,
#          'многофункциональный': 1,
#          'R212522': 1,
#          'ящик': 5,
#          'TEXTILEBOX': 1,
#          '34x20x13': 1,
#          'прозрачный': 9,
#          '03003': 1,
#          '001': 3,
#          '140': 4,
#          'ЛДН': 1,
#          'т': 3,
#          'лувр': 5,
#          '300х150': 2,
#          'салатовый': 4,
#          'WTO305': 2,
#          'подголовник': 3,
#          '25х34': 3,
#          '1620': 1,
#          'фанера': 2,
#          'стелла': 5,
#          'премиум': 4,
#          'СТП2': 1,
#          'розоцветный': 4,
#          'ред': 5,
#          'розебуд': 1,
#          'молодой': 1,
#          'JET001': 1,
#          'банка': 4,
#          '960': 1,
#          'JK': 2,
#          'D960': 1,
#          '1350': 3,
#          'C1350': 1,
#          'ведро': 14,
#          '0516': 1,
#          '570': 1,
#          'текстильный': 16,
#          'бамбук': 6,
#          '180х200см': 3,
#          'DSCN3579': 1,
#          'грин': 5,
#          'форест': 1,
#          'H7239': 1,
#          'лаванда': 9,
#          'розмарин': 10,
#          'полукруглый': 1,
#          'резина': 9,
#          'кокос': 6,
#          '40х68': 5,
#          'Format': 6,
#          'Mezzaluna': 2,
#          'розетт': 1,
#          'PHP': 8,
#          'SRL': 8,
#          '20657': 1,
#          'ножеточка': 1,
#          'универсальный': 14,
#          'рыбка': 1,
#          '1519028': 1,
#          'эссенция': 3,
#          'темно-розовый': 2,
#          'FWM': 3,
#          'Quartz': 1,
#          'pink': 2,
#          'мак': 3,
#          'бутон': 6,
#          'ромашка': 5,
#          'одиночный': 3,
#          'нарцисс': 3,
#          'бархатный': 1,
#          'раскрытый': 1,
#          '63': 3,
#          'тюльпан': 7,
#          'камушек': 1,
#          'транспарент': 1,
#          '5187': 1,
#          'Avantgard': 1,
#          '120х40': 3,
#          'бегония': 10,
#          'ампельный': 25,
#          'блу': 1,
#          'айза': 1,
#          'Mix': 2,
#          'смесь': 20,
#          'корейский': 1,
#          'окраска': 9,
#          '75': 9,
#          'дизайн': 5,
#          'Venezia': 1,
#          '140х55': 3,
#          'настольный': 2,
#          '85': 3,
#          'НД': 1,
#          ', (': 1,
#          'S': 7,
#          '751': 1,
#          'пластхозторг': 2,
#          '1408004': 1,
#          'масленка': 1,
#          'коровка': 1,
#          '17см': 1,
#          '73115': 1,
#          '52': 2,
#          'тула': 1,
#          '1205158': 1,
#          'Jolly': 1,
#          'STABILO': 1,
#          ...})

# %%
# Создадим дополнительный столбец с леммами.

lem = []
for i in ecom_online['product']:
    result = ''.join(m.lemmatize(i)).strip()
    lem.append(result)
ecom_online['lem'] = lem
ecom_online.head(10)
# Out:
#     index                date                           customer_id  order_id  \
# 0       0 2018-10-01 00:00:00  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 1       1 2018-10-01 00:00:00  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 2       2 2018-10-01 00:00:00  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 3       3 2018-10-01 00:00:00  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 4       4 2018-10-01 00:00:00  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 5       5 2018-10-01 00:00:00  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 6       6 2018-10-01 00:00:00  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 7       7 2018-10-01 08:00:00  375e0724-f033-4c76-b579-84969cf38ee2     68479
# 8       8 2018-10-01 08:00:00  6644e5b4-9934-4863-9778-aaa125207701     68478
# 10     10 2018-10-01 11:00:00  161e1b98-45ba-4b4e-8236-e6e3e70f6f7c     68483
#
#                                                                                       product  \
# 0                                             Комнатное растение в горшке Алое Вера, d12, h30
# 1                                          Комнатное растение в горшке Кофе Арабика, d12, h25
# 2                                                                 Радермахера d-12 см h-20 см
# 3                                                            Хризолидокарпус Лутесценс d-9 см
# 4                                                              Циперус Зумула d-12 см h-25 см
# 5                                                                     Шеффлера Лузеана d-9 см
# 6                                                            Юкка нитчатая d-12 см h-25-35 см
# 7                                             Настенная сушилка для белья Gimi Brio Super 100
# 8                                    Таз пластмассовый 21,0 л круглый "Водолей" С614, 1404056
# 10  Вешалка для брюк металлическая с резиновым покрытием 26 см цвет: синяя, Attribute, AHS331
#
#     quantity  price year_month month  year  revenue  \
# 0          1 142.00    2018-10    10  2018   142.00
# 1          1 194.00    2018-10    10  2018   194.00
# 2          1 112.00    2018-10    10  2018   112.00
# 3          1 179.00    2018-10    10  2018   179.00
# 4          1 112.00    2018-10    10  2018   112.00
# 5          1 164.00    2018-10    10  2018   164.00
# 6          1 134.00    2018-10    10  2018   134.00
# 7          1 824.00    2018-10    10  2018   824.00
# 8          1 269.00    2018-10    10  2018   269.00
# 10        10  82.00    2018-10    10  2018   820.00
#
#                                                                                           lem
# 0                                             комнатный растение в горшок алый вера, d12, h30
# 1                                          комнатный растение в горшок кофе арабика, d12, h25
# 2                                                                  радермахер d-12 см h-20 см
# 3                                                            хризолидокарпус лутесценс d-9 см
# 4                                                              циперус зумула d-12 см h-25 см
# 5                                                                       шеффлер лузеан d-9 см
# 6                                                            юкка нитчатый d-12 см h-25-35 см
# 7                                             настенный сушилка для белье Gimi Brio Super 100
# 8                                    таз пластмассовый 21,0 л круглый "водолей" С614, 1404056
# 10  вешалка для брюки металлический с резиновый покрытие 26 см цвет: синий, Attribute, AHS331

# %%
# Создадим словарь с категориями и списком слов.

kitchen = ['антижир', 'банка', 'бидон', 'блюдо', 'блюдце', 'бокал', 'бульонница', 'бутылка', 'бутылочный', 'венчик',
                 'вилка', 'выпечка', 'герметичный', 'губка', 'измельчитель', 'картофелемялка', 'кастрюля', 'кекс',
                 'кипятильник', 'кондитерский', 'кружка', 'крышка', 'кухонный', 'лопатка', 'ложка', 'мантоварка',
                 'мантоварка-пароварка', 'миксер', 'мини-сковорода', 'миска', 'мука', 'нож', 'ножеточка', 'овощеварка',
                 'овощечистка', 'орехоколка', 'отделитель', 'плита', 'половник', 'посуда', 'посудомоечный',
                 'пресс', 'продукт', 'противень', 'разделочный', 'рыбочистка', 'салатник', 'салфетница', 'сахарница', 'свч',
                 'сито', 'скалка', 'скатерть', 'сковорода', 'соковарка', 'соковыжималка', 'сотейник', 'стакан', 'столовый',
                 'тарелка', 'терка', 'термокружок', 'термос', 'термостакан', 'толкушка', 'тортница', 'фужер', 'хлебница',
                 'чайник', 'чайный', 'электроштопор', 'яйцо']


house = ['d-', 'd-5', 'd-7', 'd-9', 'D10', 'd-10', 'd-11', 'D12', 'D12,', 'd12', 'd-12', 'd-13', 'd-14', 'd-15',
                  'd-17', 'd-18', 'd-19', 'd-20', 'd-21', 'D23', 'd-23', 'бак', 'ванна', 'ванная', 'ванный', 'вантуз', 'ваза',
                  'ведро', 'весы', 'вешалка', 'вешалка-перекладина', 'вешалка-плечики', 'вешалка-стойка', 'вешалка-сушилка',
                  'вещь', 'гладильный', 'глажение', 'засор', 'зубной', 'известковый', 'искусственный', 'искуственный', 'калла',
                  'ключница', 'ковер', 'коврик', 'ковш', 'комнатный', 'кондиционер', 'корзина', 'коробка', 'кофр', 'крючок',
                  'лавр', 'лоток', 'мыло', 'мыло-скраб', 'муляж', 'наволочка', 'наматрацник', 'наматрицник-чехол',
                  'наматрасник', 'насадка', 'насадка-моп', 'одеяло', 'окномойка', 'отбеливатель', 'перчатка', 'плед', 'плечики',
                  'подголовник', 'пододеяльник', 'подрукавник', 'подушка', 'покрывало', 'пол', 'полимербыт', 'полировка',
                  'полотенце', 'постельный', 'прищепок', 'простыня', 'пыль', 'пятно', 'радиаторный', 'ролик', 'салфетка',
                  'сантехника', 'светильник', 'скребок', 'совок', 'стиральный', 'стирка', 'сушилка', 'таз', 'ткань', 'тряпка',
                  'тряпкодержатель', 'туалет', 'туалетный', 'увлажнять', 'унитаз', 'унитазный', 'утюг', 'фен', 'фоторамка',
                  'халат', 'хранение', 'цикламен,', 'чехол', 'швабра', 'щетка', 'щетка-утюжок', 'шило', 'штора', 'ручка']

tools = ['болт', 'вентиляционный', 'инструмент', 'карниз', 'комод', 'крепеж', 'лестница-стремянка', 'линейка', 'линейка,',
             'мебельный', 'напильник', 'обувница-3', 'петля', 'петля-стрела', 'подставка', 'полк', 'полка', 'пробка', 'пуф',
             'сварка', 'сверло', 'сверло-фреза,', 'свереть', 'стеллаж', 'стремянка', 'стремянка-табурет', 'строительный',
             'уголок', 'угольник', 'угольник,', 'фиксатор-шар', 'форточный', 'шпингалет', 'штангенциркуль', 'этажерка']

garden = ['автополив', 'аквилегия', 'алиссум', 'анемон', 'антуриум', 'арбуз', 'астра', 'бадан', 'бакоп', 'барвинок', 'бегония',
         'бензин', 'бузульник', 'веник', 'вербейник', 'вербена', 'веревка', 'виола', 'г', 'гайлардий', 'гвоздик', 'георгин',
         'гипсофил', 'гортензия', 'девичий', 'дендробиум', 'дыня', 'ель', 'зола', 'календула', 'калибрахоа', 'камнеломка',
         'кассета', 'кашпо', 'кипарисовик', 'клен', 'клубника', 'колокольчик', 'колосковый', 'кореопсис', 'корыто', 'косметь',
         'котовник', 'лапчатка', 'лен', 'лилейник', 'лобелия', 'многолетний', 'монарда', 'мусор', 'мусорный', 'настурция',
         'нивянник', 'осина', 'папоротник', 'пеларгония', 'петуния', 'пикник', 'пиретрум', 'платикодон', 'почтовый',
         'пьезозажигалка', 'ранункулус', 'рассада', 'роза', 'рудбекия', 'садовый', 'седум', 'солидаго', 'сумка-тележка',
         'тележка', 'томат', 'тюльпан', 'уличный', 'урна', 'урна-пепельница', 'фал', 'физостегия', 'флокс', 'фуксия', 'хоста',
         'хозяйственный', 'хризантема', 'цинния', 'черенок', 'шнур', 'шпагат', 'щетка-сметка', 'энотера', 'эхинацея', 'ясколка', 'овсянница']

other = ['']

# %%
# Определим категории в словаре по ключевым словам.

def category(lem):
    for item in kitchen:
        if item in lem:
            return 'Товары для кухни'
    for item in house:
        if item in lem:
            return 'Товары для дома'

    for item in tools:
        if item in lem:
            return 'Инструменты'

    for item in garden:
        if item in lem:
            return 'Товары для сада'

    for item in other:
        if item in lem:
            return 'Другое'

# %%
# Проверим, всем ли товарам присвоена категория.

ecom_online['category_list'] = ecom_online['lem'].apply(category)
len(ecom_online.query('category_list == "нет категории"'))
# Out:
# 0

# %% [markdown]
# Категория присвоена всем товарам.

# %%
# Посмотрим статистику по категориям.
statistics = ecom_online.groupby('category_list').agg({'product':'count'}).reset_index()
statistics.columns = ['category_list', 'products']
statistics['proportion'] = ((statistics['products'] / len(ecom_online))*100).round(1).astype('str')+'%'
display(statistics.sort_values(by='products', ascending = False))
# Out:
#       category_list  products proportion
# 1   Товары для дома      2388      46.0%
# 3   Товары для сада      2201      42.4%
# 2  Товары для кухни       507       9.8%
# 0       Инструменты        96       1.8%

# %% [markdown]
# Больше всего товаров для дома и сада (46% и 42,4% соответственно). На третьем месте товары для кухни, их всего 9,8%. Инструменты включают в себя 1,8% товаров.

# %% [markdown]
# **Составим рейтинг по самым продаваемым товарам в каждой категории по количеству заказов**

# %%
# Выведем рейтинг из пяти самых продаваемых товаров в каждой категории по количеству заказов.

top5_prod_by_orders = ecom_online.groupby('product')\
                           .agg({'category_list':'first',
                                 'order_id':'nunique',
                                 'customer_id':'nunique',
                                 'quantity':'sum',
                                 'revenue':'sum'})\
                           .reset_index().sort_values(by='order_id', ascending=False)
top5_prod_by_orders.columns = ['product', 'category_list', 'orders', 'customers', 'quantity', 'revenue']

for category in top5_prod_by_orders['category_list'].unique():
    print()
    print('Рейтинг самых продаваемых товаров в каждой категории по количеству заказов: {}'.format(category))
    display(top5_prod_by_orders[top5_prod_by_orders['category_list']==category].head(5))
    print();
# Out:
# Рейтинг самых продаваемых товаров в каждой категории по количеству заказов: Товары для сада
#                                                       product  \
# 996     Пеларгония розебудная Red Pandora укорененный черенок
# 994   Пеларгония розебудная Prins Nikolai укорененный черенок
# 1547               Сумка-тележка 2-х колесная Gimi Argo синяя
# 993            Пеларгония розебудная Mary укорененный черенок
# 995    Пеларгония розебудная Queen Ingrid укорененный черенок
#
#         category_list  orders  customers  quantity  revenue
# 996   Товары для сада      63         61        79 10659.33
# 994   Товары для сада      54         51        61  8222.50
# 1547  Товары для сада      44         41        44 47258.00
# 993   Товары для сада      38         34        46  6200.50
# 995   Товары для сада      31         29        39  5314.33
# Рейтинг самых продаваемых товаров в каждой категории по количеству заказов: Товары для дома
#                                                                 product  \
# 971             Пеларгония зональная диам. 12 см сиреневый полумахровый
# 949  Пеларгония зональная Ринго Вайт d-7 см h-10 см укорененный черенок
# 952            Пеларгония зональная диам. 12 см коралловая полумахровая
# 973          Пеларгония зональная диам. 12 см темнорозовая полумахровая
# 997                            Пеларгония розебудная Rosebud Red d-7 см
#
#        category_list  orders  customers  quantity  revenue
# 971  Товары для дома      50         46        57  9633.00
# 949  Товары для дома      25         24        28  2072.00
# 952  Товары для дома      24         23        27  4658.00
# 973  Товары для дома      22         22        26  4413.00
# 997  Товары для дома      18         18        23  3105.00
# Рейтинг самых продаваемых товаров в каждой категории по количеству заказов: Товары для кухни
#                                                                product  \
# 1832                         Термокружка Яромир КРЕМЛЬ ЯР-2406М 400 мл
# 896              Овощеварка алюминиевая Scovo МТ-045, Хозлэнд, 1502079
# 658              Кувшин пластмассовый с крышкой "Кумган" 2,0 л 1408003
# 1409                    Салатник Luminarc ЭМПИЛАБЛЬ ВЕЛАДА 17 см L7997
# 1450  Скатерть Dasch Донна Роза из ПВХ 0401-2 Розы круглая 152 см 5974
#
#          category_list  orders  customers  quantity  revenue
# 1832  Товары для кухни       5          5         5  1603.00
# 896   Товары для кухни       5          5         5  2245.00
# 658   Товары для кухни       5          5         5   745.00
# 1409  Товары для кухни       5          5         5   820.00
# 1450  Товары для кухни       5          5         6  2652.00
# Рейтинг самых продаваемых товаров в каждой категории по количеству заказов: Инструменты
#                                                        product category_list  \
# 1540               Стяжка оконная с болтом СТ-55 цинк, 1108354   Инструменты
# 1097   Подставка для обуви резиновая Attribute 80x40 см AMC080   Инструменты
# 564                 Комод Эльфпласт № 3 Алфавит оранжевый 301о   Инструменты
# 1538  Стремянки Colombo Leonardo 2 ступени G300A02W серая 3646   Инструменты
# 686                 Линейка, длина 30 см, Truper, RGL-30/14387   Инструменты
#
#       orders  customers  quantity  revenue
# 1540       5          4        37   748.33
# 1097       4          4         4  1416.00
# 564        3          2         3  4047.00
# 1538       3          2         3  8997.00
# 686        3          3         3   741.00

# %% [markdown]
# Тут видно, что если смотреть на категорию Товары для сада, то в лидерах продаж идет Пеларгония розебудная Red Pandora укорененный черенок - 63 заказа с выручкой 10659.33 у.е. Зато, на третьем месте Сумка-тележка 2-х колесная Gimi Argo синяя - 44 заказа, но выручка по ней больше - 47258.00 у.е.
#
# В категории Товары для дома можно видеть, что самое продаваемое наименование - Пеларгония зональная диам. 12 см сиреневый полумахровый. 50 заказов с выручкой 9633.00 у.е.
#
# В категории Товары для кухни можно увидеть, что на все 5 товаров рейтинга сделано по 5 заказов. Больше всего выручка у Скатерть Dasch Донна Роза из ПВХ 0401-2 Розы круглая 152 см 5974, потому что в каком-то из заказов было заказано 2шт., так как общее количество по 5 заказам - 6шт. Поэтому , эта позиция лидирует по выручке 2652.00 у.е. Но, Овощеварка алюминиевая Scovo МТ-045, Хозлэнд, 1502079 не сильно отстает - 2245.00 у.е.
#
# И в категории Инструменты на первом месте по количеству продаж идет Стяжка оконная с болтом СТ-55 цинк, 1108354 - 5 заказов, выручка составила 748.33 у.е. Но, если смотреть по выручке, то здесь лидирует Стремянки Colombo Leonardo 2 ступени G300A02W серая 3646 - 8997.00 у.е. всего с 3 заказами.

# %% [markdown]
# **Составим рейтинг по самым прибыльным товарам в каждой категории**

# %%
# Выведем рейтинг из пяти самых прибыльных товаров в каждой категории.

top5_prod_by_revenue = ecom_online.groupby('product')\
                           .agg({'category_list':'first',
                                 'order_id':'nunique',
                                 'customer_id':'nunique',
                                 'quantity':'sum',
                                 'revenue':'sum'})\
                           .reset_index().sort_values(by='revenue', ascending=False)
top5_prod_by_orders.columns = ['product', 'category_list', 'orders', 'customers', 'quantity', 'revenue']

for category in top5_prod_by_revenue['category_list'].unique():
    print()
    print('Рейтинг самых прибыльных товаров в каждой категории: {}'.format(category))
    display(top5_prod_by_revenue[top5_prod_by_revenue['category_list']==category].head(5))
    print();
# Out:
# Рейтинг самых прибыльных товаров в каждой категории: Товары для дома
#                                                           product  \
# 1144  Простынь вафельная 200х180 см WELLNESS RW180-01 100% хлопок
# 187              Вешалки мягкие для деликатных вещей 3 шт шоколад
# 801                                     Муляж ЯБЛОКО 9 см красное
# 1628                               Сушилка Meliconi Stendy Junior
# 257                Гладильная доска Sarayli New Elegant 125x45 см
#
#         category_list  order_id  customer_id  quantity  revenue
# 1144  Товары для дома         2            1        30 53232.00
# 187   Товары для дома         2            2       335 49596.00
# 801   Товары для дома         6            6       618 32702.00
# 1628  Товары для дома         4            4         4 22376.00
# 257   Товары для дома         7            6         7 17843.00
# Рейтинг самых прибыльных товаров в каждой категории: Товары для сада
#                                                                                      product  \
# 1547                                              Сумка-тележка 2-х колесная Gimi Argo синяя
# 1816  Тележка багажная DELTA ТБР-22 синий грузоподъемность 20 кг сумка и 50 кг каркас РОССИЯ
# 807                              Мусорный контейнер Hailo BigBin Swing 45 0845-010 45 л хром
# 1866                                   Урна уличная "Гео", Hobbyka/Хоббика, 59*37,5см, сталь
# 1600                     Сумка-тележка хозяйственная Rolser IMX006 bassi Logic Tour бордовая
#
#         category_list  order_id  customer_id  quantity  revenue
# 1547  Товары для сада        44           41        44 47258.00
# 1816  Товары для сада         3            3        59 33992.00
# 807   Товары для сада         3            3         5 27560.00
# 1866  Товары для сада         1            1         5 24370.00
# 1600  Товары для сада         2            2         3 23037.00
# Рейтинг самых прибыльных товаров в каждой категории: Товары для кухни
#                                                                                           product  \
# 839                                                 Набор ножей Attribute CHEF 5 предметов AKF522
# 1467          Скатерть круглая d-175 см 50% полиэстер 50% хлопок белая Wellness MLd-187-Эстель*01
# 1444                                       Скатерть 180 см WELLNESS WTd180-Лион*01 100% полиэстер
# 1462  Скатерть Рим 88% полиэфир 12% хлопок прямоугольная 350х150 см голубая Wellness MC355-Рим*16
# 731                                           Модульная стеклянная банка 1,1л, 298264, Brabantia,
#
#          category_list  order_id  customer_id  quantity  revenue
# 839   Товары для кухни         1            1        64 29248.00
# 1467  Товары для кухни         1            1        10 11400.00
# 1444  Товары для кухни         1            1         8  8832.00
# 1462  Товары для кухни         1            1         4  7496.00
# 731   Товары для кухни         2            2         8  6600.00
# Рейтинг самых прибыльных товаров в каждой категории: Инструменты
#                                                        product category_list  \
# 1538  Стремянки Colombo Leonardo 2 ступени G300A02W серая 3646   Инструменты
# 1537  Стремянки Colombo Leonardo 2 ступени G300A02W белая 4096   Инструменты
# 1519    Стремянка COLOMBO FACTOTUM 4 ступени алюминий G110AT4W   Инструменты
# 1531                 Стремянка бытовая Framar Slimmy 4 ступени   Инструменты
# 1527      Стремянка Scab Balzo 762 5 ступеней алюминиевая 3885   Инструменты
#
#       order_id  customer_id  quantity  revenue
# 1538         3            2         3  8997.00
# 1537         2            2         2  7424.00
# 1519         2            1         2  6898.00
# 1531         2            2         3  5622.00
# 1527         1            1         1  5549.00

# %% [markdown]
# По категории Товары для дома, самым прибыльным является Простынь вафельная 200х180 см WELLNESS RW180-01 100% хлопок - 53232.00 у.е.
#
# В категории Товары для сада, самым прибыльным является Сумка-тележка 2-х колесная Gimi Argo синяя - 47258.00 у.е.
#
# В категории Товары для кухни, самым прибыльным является Набор ножей Attribute CHEF 5 предметов AKF522 - 29248.00 у.е.
#
# В категории Инструменты, самым прибыльным является Стремянки Colombo Leonardo 2 ступени G300A02W серая 3646 - 8997.00 у.е.

# %% [markdown]
# **Посмотрим сезонность товаров по категориям и проанализируем продажи категорий товаров по временам года**

# %%
ecom_online.head()
# Out:
#    index       date                           customer_id  order_id  \
# 0      0 2018-10-01  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 1      1 2018-10-01  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 2      2 2018-10-01  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 3      3 2018-10-01  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 4      4 2018-10-01  ee47d746-6d2f-4d3c-9622-c31412542920     68477
#
#                                               product  quantity  price  \
# 0     Комнатное растение в горшке Алое Вера, d12, h30         1 142.00
# 1  Комнатное растение в горшке Кофе Арабика, d12, h25         1 194.00
# 2                         Радермахера d-12 см h-20 см         1 112.00
# 3                    Хризолидокарпус Лутесценс d-9 см         1 179.00
# 4                      Циперус Зумула d-12 см h-25 см         1 112.00
#
#   year_month month  year  revenue  \
# 0    2018-10    10  2018   142.00
# 1    2018-10    10  2018   194.00
# 2    2018-10    10  2018   112.00
# 3    2018-10    10  2018   179.00
# 4    2018-10    10  2018   112.00
#
#                                                   lem    category_list
# 0     комнатный растение в горшок алый вера, d12, h30  Товары для дома
# 1  комнатный растение в горшок кофе арабика, d12, h25  Товары для дома
# 2                          радермахер d-12 см h-20 см  Товары для дома
# 3                    хризолидокарпус лутесценс d-9 см  Товары для дома
# 4                      циперус зумула d-12 см h-25 см  Товары для дома

# %%
# Создадим функцию и пропишем в ней номера месяцев по временам года.

def season_category(month):
    if month >= '03' and month <='05':
        return 'весна'
    elif month >= '06' and month <= '08':
        return 'лето'
    elif month >= '09' and month <= '11':
        return 'осень'
    else:
        return 'зима'

# %%
# Создадим отдельный столбец для времени года.

ecom_online['season_category'] = ecom_online['month'].apply(season_category)
ecom_online.sample(20)
# Out:
#       index                date                           customer_id  \
# 4827   6747 2019-11-01 22:00:00  cf971740-da80-41a6-acfb-ef934cede4b4
# 3415   4021 2019-05-24 13:00:00  118a08f4-ae51-4fc0-9634-639d73deaf08
# 1222   1432 2019-01-03 13:00:00  bad7f5f6-52cc-42cf-924c-5d3f82a249ed
# 1736   2043 2019-02-26 21:00:00  e678ffd3-f88c-4d15-a5b1-aa2c307ce112
# 927    1064 2018-12-02 23:00:00  764d269d-c069-4835-b5be-d95efccf2e59
# 731     855 2018-11-18 15:00:00  8620fc44-c68c-44ed-b7bd-3c10ae9219cb
# 553     649 2018-11-05 21:00:00  639c4989-b0ab-412a-b7ec-be394cb2d372
# 242     267 2018-10-16 08:00:00  cd09ea73-d9ce-48c3-b4c5-018113735e80
# 3879   5619 2019-07-01 20:00:00  713141d7-bbaf-4da9-b43d-f91bd51b423c
# 5180   7100 2019-12-20 11:00:00  cfc55c59-c16e-4f6b-bf9c-71dbd64c9a5a
# 101     113 2018-10-05 17:00:00  552e17df-ba16-4e66-84fb-55a5557a6bea
# 1216   1421 2018-12-30 17:00:00  8c290149-ad54-4d7a-87a7-9386b36390ee
# 4375   6222 2019-08-30 10:00:00  6a86cc77-ef15-496f-b5d3-89005597ee5d
# 357     387 2018-10-23 19:00:00  31849f03-0c26-46ab-b3dd-c0cd8478d623
# 362     392 2018-10-24 07:00:00  6dbae21e-4b94-4b16-9548-24aadf146ae2
# 1390   1634 2019-01-30 13:00:00  395aeb0e-dab1-4dbd-8cbc-219ba2536e8a
# 2112   2493 2019-03-28 11:00:00  02cb74c5-348f-43dc-ba4d-e546a21a07f1
# 981    1121 2018-12-06 17:00:00  82b56a76-0dc9-4dae-aa76-863a9a80f082
# 4034   5836 2019-07-11 12:00:00  f30fea52-f096-4d36-b7eb-33f9f42c291d
# 3224   3809 2019-05-15 08:00:00  3976660e-6cca-4009-a170-be13f13ed459
#
#       order_id  \
# 4827    108976
# 3415     71509
# 1222     69697
# 1736     70478
# 927      69179
# 731      69039
# 553      68870
# 242      68611
# 3879     14882
# 5180    105211
# 101      68544
# 1216     69162
# 4375     14927
# 357      68732
# 362      68735
# 1390     70028
# 2112     70905
# 981      69236
# 4034     71939
# 3224     14778
#
#                                                                                        product  \
# 4827                                                         Муляж Вишня 3 см 10 шт полиуретан
# 3415                                      Сумка-тележка 2-х колесная складная Gimi Flexi серая
# 1222                                    Вешалка настенная НИКА ВП6с с полкой 6 крючков серебро
# 1736                                   Кухонное полотенце вафельное 64х38 см WELLNESS ЭЛИЯ-mix
# 927                                 Банка стеклянная с крышкой Attribute FLEUR 1350 мл ABF100G
# 731                                           Сушилка для белья потолочная Лиана 2,4 м 1703011
# 553                                                  Шнур резиновый для тележки 80 см, 1209001
# 242                       Пружина дверная 240 мм оцинкованная (Д-19 мм) без крепления, 1107014
# 3879                                          Рассада зелени для кухни Мята Спэйниш диам. 9 см
# 5180                                Пеларгония зональная простая цвет фуксии взрослое растение
# 101                                  Ложка чайная RIPPLE сталь 2,5 мм, 3 шт, Attribute, ACR033
# 1216                                 Термометр на окно уличный на липучках Т-5 h-20 см 1210035
# 4375                                                 Роза садовая парковая в горшке Чиппендейл
# 357                                      Кувшин пластмассовый с крышкой "Кумган" 2,0 л 1408003
# 362                           Контейнер для мусора FLIP BIN CURVER 25 л оранжевый 02171-535-00
# 1390                                             Столовая ложка Attribute FORTRESS 2 шт ACF622
# 2112                                   Пеларгония розебудная Prins Nikolai укорененный черенок
# 981   Покрывало жаккард KARNA стеганое KALVEN 260x260 см наволочки 50х70 см 2 шт 8681914002162
# 4034     Чехол для гладильной доски Zalger 520109 130х48 см хлопок, войлок для доски 125х43 см
# 3224                                            Рассада Дыни сорт Колхозница горшок 9х9 см P-9
#
#       quantity   price year_month month  year  revenue  \
# 4827         2   74.00    2019-11    11  2019   148.00
# 3415         1 1649.00    2019-05    05  2019  1649.00
# 1222         1  389.00    2019-01    01  2019   389.00
# 1736         1  104.00    2019-02    02  2019   104.00
# 927          6  194.00    2018-12    12  2018  1164.00
# 731          1  734.00    2018-11    11  2018   734.00
# 553          1   37.00    2018-11    11  2018    37.00
# 242        150   38.00    2018-10    10  2018  5700.00
# 3879         1  120.00    2019-07    07  2019   120.00
# 5180         1  150.00    2019-12    12  2019   150.00
# 101          4  142.00    2018-10    10  2018   568.00
# 1216         2   44.00    2018-12    12  2018    88.00
# 4375         1  188.00    2019-08    08  2019   188.00
# 357          1  149.00    2018-10    10  2018   149.00
# 362          1  787.00    2018-10    10  2018   787.00
# 1390         1  127.00    2019-01    01  2019   127.00
# 2112         1  134.00    2019-03    03  2019   134.00
# 981          1 6134.00    2018-12    12  2018  6134.00
# 4034         2  239.00    2019-07    07  2019   478.00
# 3224         2   38.00    2019-05    05  2019    76.00
#
#                                                                                            lem  \
# 4827                                                         муляж вишня 3 см 10 шт полиуретан
# 3415                                      сумка-тележка 2-х колесный складной Gimi Flexi серый
# 1222                                      вешалка настенный ника ВП6с с полка 6 крючок серебро
# 1736                                   кухонный полотенце вафельный 64х38 см WELLNESS элий-mix
# 927                                  банка стеклянный с крышка Attribute FLEUR 1350 мл ABF100G
# 731                                           сушилка для белье потолочный лиана 2,4 м 1703011
# 553                                                  шнур резиновый для тележка 80 см, 1209001
# 242                       пружина дверной 240 мм оцинковывать (д-19 мм) без крепление, 1107014
# 3879                                          рассада зелень для кухня мята спэйниш диам. 9 см
# 5180                                пеларгония зональный простой цвет фуксия взрослый растение
# 101                                  ложка чайная RIPPLE сталь 2,5 мм, 3 шт, Attribute, ACR033
# 1216                                  термометр на окно уличный на липучка т-5 h-20 см 1210035
# 4375                                                 роза садовый парковый в горшок чиппендейл
# 357                                       кувшин пластмассовый с крышка "кумган" 2,0 л 1408003
# 362                            контейнер для мусор FLIP BIN CURVER 25 л оранжевый 02171-535-00
# 1390                                             столовый ложка Attribute FORTRESS 2 шт ACF622
# 2112                                     пеларгония розебудный Prins Nikolai укоренять черенок
# 981   покрывало жаккард KARNA стеганый KALVEN 260x260 см наволочка 50х70 см 2 шт 8681914002162
# 4034     чехол для гладильный доска Zalger 520109 130х48 см хлопок, войлок для доска 125х43 см
# 3224                                            рассада дыня сорт колхозница горшок 9х9 см P-9
#
#          category_list season_category
# 4827   Товары для дома           осень
# 3415   Товары для сада           весна
# 1222   Товары для дома            зима
# 1736  Товары для кухни            зима
# 927   Товары для кухни            зима
# 731    Товары для дома           осень
# 553    Товары для сада           осень
# 242    Товары для сада           осень
# 3879   Товары для сада            лето
# 5180   Товары для сада            зима
# 101   Товары для кухни           осень
# 1216   Товары для сада            зима
# 4375   Товары для сада            лето
# 357   Товары для кухни           осень
# 362    Товары для сада           осень
# 1390  Товары для кухни            зима
# 2112   Товары для сада           весна
# 981    Товары для дома            зима
# 4034   Товары для дома            лето
# 3224   Товары для сада           весна

# %%
# Посмотрим выручку по категориям товара в медианных значениях.

category_list_rev = (ecom_online.groupby(['category_list'])['revenue'].median().sort_values(ascending=False))
plt.figure(figsize=(15,10))
sns.boxplot(x = 'revenue', 
            y = 'category_list', 
            data = ecom_online, 
            showfliers=False, 
            order=category_list_rev.index)
plt.title('Выручка по категориям товара')
plt.xlabel('Выручка')
plt.ylabel('Сезон')
plt.show();

# %% [markdown]
# Здесь в лидерах категория Инструменты. Затем, Товары для кухни и Товары для дома практически на одном уровне. Товары для кухни немного больше по выручке. Замыкает рейтинг категория Товары для сада.

# %%
# Посмотрим выручку по временам года в медианных значениях.

season_category_rev = (ecom_online.groupby(['season_category'])['revenue'].median().sort_values(ascending=False))
plt.figure(figsize=(15,10))
sns.boxplot(x = 'revenue', 
            y = 'season_category', 
            data = ecom_online, 
            showfliers=False, 
            order=season_category_rev.index)
plt.title('Выручка по временам года')
plt.xlabel('Выручка')
plt.ylabel('Сезон')
plt.show();

# %% [markdown]
# Видно, что на зиму приходится больше всего выручки. Чуть меньше на осень и лето. Весной этот показатель небольшой.

# %%
# Также, можно посмотреть выручку по месяцам.

year_month_rev = (ecom_online.groupby(['year_month'])['revenue'].median().sort_values(ascending=False))
plt.figure(figsize=(15,10))
sns.boxplot(x = 'revenue', 
            y = 'year_month', 
            data = ecom_online,
            showfliers=False, 
            order=year_month_rev.index)
plt.title('Выручка по месяцам')
plt.xlabel('Выручка')
plt.ylabel('Месяц')
plt.show();

# %% [markdown]
# Больше всего выручка была в январе 2019 года и в декабре 2018 года. Самые провальные месяцы по выручке - апрель и май 2019 года. Это соответствует предыдущему графику выручки по временам года.

# %%
# Для наглядности посмотрим распределение заказов по месяцам.

orders_date = ecom_online.groupby('year_month')['order_id'].nunique().reset_index()
orders_date['year_month'] = orders_date['year_month'].astype(str)
orders_date.columns = ['date', 'orders']

plt.figure(figsize=(14, 6))
sns.lineplot(x='date', y='orders', color='purple', data=orders_date)
plt.title('Количество заказов за весь период')
plt.xlabel('Дата')
plt.ylabel('Количество заказов')
plt.grid(True)
plt.xticks(rotation=50)
plt.show();

# %% [markdown]
# На графике видны пики в зимние периоды. В 2018 году количество заказов выросло к декабрю почти до 235. К январю 2019 года идет резкий спад. Скорее всего это связано с новогодними праздниками. Далее, в феврале 2019 года количество заказов обновляет пик - 250. В конце весеннего периода идет постепенное снижение и минимум приходится на июнь 2019 года. Весь летний период идет некоторый боковик, который колеблется от 160 заказов до почти 200. В осенний период, начиная с сентября 2019 года, идет планомерное восстановление количества заказов переходящее в зимний период, где количество заказов снова подбирается к пиковым значениям декабря 2018 года и выходит на новые максимумы. Зимний период для компании явно является прибыльным.

# %% [markdown]
# **Посчитаем выручку и количество покупателей по категориям**

# %%
# Сгруппируем данные по категориям.

category_gr = ecom_online.groupby('category_list').agg({'revenue':'sum', 'customer_id':'nunique'})
display(category_gr)
# Out:
#                     revenue  customer_id
# category_list
# Инструменты       135277.33           88
# Товары для дома  1900462.50         1641
# Товары для кухни  395732.00          422
# Товары для сада  1167048.58          844

# %%
# Посмотрим сумму выручки по категориям на графике.

sns.set_style('whitegrid')
sns.set_context('talk')
category_gr.plot(kind='barh', y=['revenue'], figsize=(10,7), grid=True, fontsize=16, legend=False)
plt.title('Сумма выручки по категориям.', fontsize=16)
plt.xlabel('Категории')
plt.ylabel('Cумма выручки')
plt.show();

# %%
# Посмотрим количество покупателей по категориям.

sns.set_style('whitegrid')
sns.set_context('talk')
category_gr.plot(kind='barh', y=['customer_id'], figsize=(10, 8), grid=True, fontsize=15, legend=False)
plt.title('Количество покупателей по категориям')
plt.xlabel('Покупатели')
plt.ylabel('Категории')
plt.show();

# %% [markdown]
# **Вывод**
#
# Больше всего выручки и покупателей в категории Товары для дома: 190 0462.50 у.е. и 1641 покупателей.
#
# Следом идет категория Товары для сада: 1 167 048.58 у.е. и 844 покупателей.
#
# Далее по убывающей - Товары для кухни с выручкой 395 732.00 у.е. и с 422 покупателями, и Инструменты с выручкой 135 277.33 и с 88 покупателями.
#
# Здесь видно, что в суммарном соотношении, категории товары для дома и сада приносят магазину значительную часть выручки.

# %% [markdown]
# ## Шаг 4. Сегментация покупателей на основе истории их покупок

# %% [markdown]
# **Сделаем кластеризацию**

# %%
# Добавим столбец с количеством товаров в заказе.

ecom_online['order_product_cnt'] = ecom_online.groupby('order_id')['product'].transform('count')

# Добавим столбец со стоимостью по каждой позиции в заказе.

ecom_online['price_per_product'] = ecom_online['price'] * ecom_online['quantity']

# Добавим столбец со стоимостью заказа.

ecom_online['order_price'] = ecom_online.groupby('order_id')['price_per_product'].transform('sum')

# Добавим столбец с количеством заказов на человека и средним чеком.

avg_orders_cnt_per_customers = ecom_online.groupby(
    'customer_id')['order_id'].nunique().reset_index(name='avg_orders_cnt_per_customer')
ecom_online = ecom_online.merge(avg_orders_cnt_per_customers, on='customer_id', how='left')

avg_checks = ecom_online.groupby('customer_id').agg({'price':'sum', 'order_id':'nunique'}).reset_index()
avg_checks['avg_check'] = avg_checks['price'] / avg_checks['order_id']
ecom_online = ecom_online.merge(avg_checks[['customer_id', 'avg_check']], on='customer_id', how='left')

# %%
# Проверим.

ecom_online.head(10)
# Out:
#    index                date                           customer_id  order_id  \
# 0      0 2018-10-01 00:00:00  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 1      1 2018-10-01 00:00:00  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 2      2 2018-10-01 00:00:00  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 3      3 2018-10-01 00:00:00  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 4      4 2018-10-01 00:00:00  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 5      5 2018-10-01 00:00:00  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 6      6 2018-10-01 00:00:00  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 7      7 2018-10-01 08:00:00  375e0724-f033-4c76-b579-84969cf38ee2     68479
# 8      8 2018-10-01 08:00:00  6644e5b4-9934-4863-9778-aaa125207701     68478
# 9     10 2018-10-01 11:00:00  161e1b98-45ba-4b4e-8236-e6e3e70f6f7c     68483
#
#                                                                                      product  \
# 0                                            Комнатное растение в горшке Алое Вера, d12, h30
# 1                                         Комнатное растение в горшке Кофе Арабика, d12, h25
# 2                                                                Радермахера d-12 см h-20 см
# 3                                                           Хризолидокарпус Лутесценс d-9 см
# 4                                                             Циперус Зумула d-12 см h-25 см
# 5                                                                    Шеффлера Лузеана d-9 см
# 6                                                           Юкка нитчатая d-12 см h-25-35 см
# 7                                            Настенная сушилка для белья Gimi Brio Super 100
# 8                                   Таз пластмассовый 21,0 л круглый "Водолей" С614, 1404056
# 9  Вешалка для брюк металлическая с резиновым покрытием 26 см цвет: синяя, Attribute, AHS331
#
#    quantity  price year_month month  year  revenue  \
# 0         1 142.00    2018-10    10  2018   142.00
# 1         1 194.00    2018-10    10  2018   194.00
# 2         1 112.00    2018-10    10  2018   112.00
# 3         1 179.00    2018-10    10  2018   179.00
# 4         1 112.00    2018-10    10  2018   112.00
# 5         1 164.00    2018-10    10  2018   164.00
# 6         1 134.00    2018-10    10  2018   134.00
# 7         1 824.00    2018-10    10  2018   824.00
# 8         1 269.00    2018-10    10  2018   269.00
# 9        10  82.00    2018-10    10  2018   820.00
#
#                                                                                          lem  \
# 0                                            комнатный растение в горшок алый вера, d12, h30
# 1                                         комнатный растение в горшок кофе арабика, d12, h25
# 2                                                                 радермахер d-12 см h-20 см
# 3                                                           хризолидокарпус лутесценс d-9 см
# 4                                                             циперус зумула d-12 см h-25 см
# 5                                                                      шеффлер лузеан d-9 см
# 6                                                           юкка нитчатый d-12 см h-25-35 см
# 7                                            настенный сушилка для белье Gimi Brio Super 100
# 8                                   таз пластмассовый 21,0 л круглый "водолей" С614, 1404056
# 9  вешалка для брюки металлический с резиновый покрытие 26 см цвет: синий, Attribute, AHS331
#
#      category_list season_category  order_product_cnt  price_per_product  \
# 0  Товары для дома           осень                  7             142.00
# 1  Товары для дома           осень                  7             194.00
# 2  Товары для дома           осень                  7             112.00
# 3  Товары для дома           осень                  7             179.00
# 4  Товары для дома           осень                  7             112.00
# 5  Товары для дома           осень                  7             164.00
# 6  Товары для дома           осень                  7             134.00
# 7  Товары для дома           осень                  1             824.00
# 8  Товары для дома           осень                  1             269.00
# 9  Товары для дома           осень                  1             820.00
#
#    order_price  avg_orders_cnt_per_customer  avg_check
# 0      1037.00                            1    1037.00
# 1      1037.00                            1    1037.00
# 2      1037.00                            1    1037.00
# 3      1037.00                            1    1037.00
# 4      1037.00                            1    1037.00
# 5      1037.00                            1    1037.00
# 6      1037.00                            1    1037.00
# 7       824.00                            1     824.00
# 8       269.00                            2     153.50
# 9       820.00                            1      82.00

# %%
# Группируем данные по customer_id. Возьмем средние значения по переменным:

cluster = ecom_online.groupby('customer_id').agg({
    'quantity':'sum',
    'price':'mean',
    'price_per_product':'mean',
    'order_product_cnt':'mean',
    'order_price':'mean',
    'avg_check':'mean',
    'avg_orders_cnt_per_customer':'mean',
    'revenue':'mean'}).reset_index()

cluster.columns = [
    'customer_id',
    'quantity',
    'price',
    'price_per_product', # средняя стоимостью по каждой позиции в заказе
    'order_product_cnt', # среднее количество товаров в заказе
    'avg_price_per_order', # средняя цена на товар в заказе
    'avg_check', # средний чек
    'avg_orders_cnt_per_customer',
    'revenue'] # среднее количество заказов на покупателя

# Посмотрим.

cluster.sample(10)
# Out:
#                                customer_id  quantity   price  \
# 351   2600a998-670d-4750-a932-c2cdd39a607e         2  434.00
# 596   3e5908af-3bba-4fb0-90cf-31a03ddc13f2         3   22.00
# 847   5bee7748-a089-4d7c-a1ad-075cd8846a41         1 3599.00
# 1124  78b971d9-a0d5-40a1-8dd1-c3562b88dbc5         2  187.00
# 1813  c0d260e0-e0e7-4176-976b-46c6125f77d4         1  524.00
# 1025  6eeca375-0727-4407-8e46-8c2acb31fbd5         2  292.00
# 1362  93630d8b-bbf7-47db-a3f1-ff276065c532         2  371.00
# 612   3ffe7cfb-f00f-4d04-a2f2-38dfe7116cbd         5   45.00
# 144   0f0640d2-b04c-4110-8bfd-2302f6d8faa0         1 1912.00
# 676   48294bee-94cc-4eed-a7c0-7c6848b349fe         9  136.00
#
#       price_per_product  order_product_cnt  avg_price_per_order  avg_check  \
# 351              434.00               1.00               434.00     434.00
# 596               66.00               1.00                66.00      22.00
# 847             3599.00               1.00              3599.00    3599.00
# 1124             374.00               1.00               374.00     187.00
# 1813             524.00               1.00               524.00     524.00
# 1025             292.00               1.00               292.00     292.00
# 1362             371.00               1.00               371.00     371.00
# 612              225.00               1.00               225.00      45.00
# 144             1912.00               1.00              1912.00    1912.00
# 676              143.50               8.00              1148.00    1088.00
#
#       avg_orders_cnt_per_customer  revenue
# 351                             2   434.00
# 596                             1    66.00
# 847                             1  3599.00
# 1124                            1   374.00
# 1813                            1   524.00
# 1025                            2   292.00
# 1362                            2   371.00
# 612                             1   225.00
# 144                             1  1912.00
# 676                             1   143.50

# %%
# Посмотрим матрицу корреляций.

corr_matrix = cluster.corr()

plt.figure(figsize=(15, 10))
sns.heatmap(corr_matrix, annot=True, square=True, cmap='seismic')
plt.title('Матрица корреляции для переменных')
plt.show();

# %% [markdown]
# Видно, что есть взаимосвязь между некоторыми переменными. Взаимосвязь прослеживается между avg_price_per_order - средняя цена на товар в заказе и avg_check - средний чек (corr = 0,51). Еще есть переменные, которые положительно коррелируют со средней ценой на товар в заказе, это order_product_cnt - среднее количество товаров в заказе (corr = 0,083). Также есть корреляция с avg_check - средний чек и price_per_product - средняя стоимость по каждой позиции в заказе (corr = 0,49). И еще одна положительная корреляция: avg_check - средний чек и order_product_cnt - среднее количество товаров в заказе (corr = 0,15). Далее, положительная корреляция прослеживается у avg_price_per_order - средняя цена на товар в заказе и price_per_product - средняя стоимость по каждой позиции в заказе (corr = 0,93). И небольшая положительная корреляция между avg_check - средний чек и avg_orders_cnt_per_customer - среднее количество заказов на покупателя (corr = 0,00062).
#
# Средний чек коррелирует с большим количеством переменных.

# %%
# Проведем кластеризацию. Оставляем количественные данные.

x = cluster[['price_per_product', 'order_product_cnt',  'avg_price_per_order', 'avg_check', 'avg_orders_cnt_per_customer']]

# %%
# Стандартизируем данные. Создадим объект класса Scaler.

sc = StandardScaler()

# Обучим модель и преобразуем набор данных.

x_sc = sc.fit_transform(x)

# Рассчитаем матрицу расстояний с помощью метода linkage.

linked = linkage(x_sc, method = 'ward')

# Построим дендрограмму.

plt.figure(figsize=(15, 10))
dendrogram(linked, orientation='top', show_leaf_counts=True, truncate_mode='lastp', p=30, leaf_rotation=90, leaf_font_size=15)
plt.title('Кластеризация клиентов интернет-магазина товаров для дома и быта «Пока все ещё тут»', fontsize=16)
plt.xlabel('Размер кластера')
plt.ylabel('Расстояние')
plt.show();

# %% [markdown]
# Тут можно видеть, что выделяются 5 кластеров.

# %% [markdown]
# **Обучим модель кластеризации алгоритмом K-Means и спрогнозируем сегменты покупателей**

# %%
km = KMeans(n_clusters = 5, random_state = 0)
labels = km.fit_predict(x_sc)
cluster['cluster'] = labels
cluster
# Out:
#                                customer_id  quantity   price  \
# 0     000d6849-084e-4d9f-ac03-37174eaf60c4         4  138.75
# 1     001cee7f-0b29-4716-b202-0042213ab038         1  442.00
# 2     00299f34-5385-4d13-9aea-c80b81658e1b         2  457.00
# 3     002d4d3a-4a59-406b-86ec-c3314357e498         1 1649.00
# 4     003bbd39-0000-41ff-b7f9-2ddaec152037         2 1162.00
# ...                                    ...       ...     ...
# 2402  ff601403-b094-4b86-9ac6-264d725b9277         2  869.50
# 2403  ffaeab76-3a8d-49ee-860f-17273b2fc8a2         1  397.00
# 2404  ffb5976a-7a4d-460b-95c4-5ffaba31cb24         1  389.00
# 2405  ffb80538-3fda-4351-8ea9-9d2bec58bb07         1  974.00
# 2406  ffe82299-3f5b-4214-87fe-3d36ecccfac3         1  577.00
#
#       price_per_product  order_product_cnt  avg_price_per_order  avg_check  \
# 0                138.75               4.00               555.00     555.00
# 1                442.00               1.00               442.00     442.00
# 2                914.00               1.00               914.00     457.00
# 3               1649.00               1.00              1649.00    1649.00
# 4               2324.00               1.00              2324.00    1162.00
# ...                 ...                ...                  ...        ...
# 2402             869.50               1.00               869.50     869.50
# 2403             397.00               1.00               397.00     397.00
# 2404             389.00               1.00               389.00     389.00
# 2405             974.00               1.00               974.00     974.00
# 2406             577.00               1.00               577.00     577.00
#
#       avg_orders_cnt_per_customer  revenue  cluster
# 0                               1   138.75        0
# 1                               1   442.00        0
# 2                               1   914.00        0
# 3                               1  1649.00        0
# 4                               1  2324.00        0
# ...                           ...      ...      ...
# 2402                            2   869.50        1
# 2403                            1   397.00        0
# 2404                            1   389.00        0
# 2405                            1   974.00        0
# 2406                            1   577.00        0
#
# [2407 rows x 10 columns]

# %% [markdown]
# Выполнили кластеризацию по алгоритму K-Means.

# %% [markdown]
# **Выведем статистику по кластерам**

# %%
cluster.groupby('cluster').mean().T.style.set_precision(2)
# Out:
# <style  type="text/css" >
# </style><table id="T_92cb3_" ><thead>    <tr>        <th class="index_name level0" >cluster</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>        <th class="col_heading level0 col2" >2</th>        <th class="col_heading level0 col3" >3</th>        <th class="col_heading level0 col4" >4</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_92cb3_level0_row0" class="row_heading level0 row0" >quantity</th>
#                         <td id="T_92cb3_row0_col0" class="data row0 col0" >4.69</td>
#                         <td id="T_92cb3_row0_col1" class="data row0 col1" >2.98</td>
#                         <td id="T_92cb3_row0_col2" class="data row0 col2" >105.40</td>
#                         <td id="T_92cb3_row0_col3" class="data row0 col3" >18.41</td>
#                         <td id="T_92cb3_row0_col4" class="data row0 col4" >8.73</td>
#             </tr>
#             <tr>
#                         <th id="T_92cb3_level0_row1" class="row_heading level0 row1" >price</th>
#                         <td id="T_92cb3_row1_col0" class="data row1 col0" >431.37</td>
#                         <td id="T_92cb3_row1_col1" class="data row1 col1" >632.22</td>
#                         <td id="T_92cb3_row1_col2" class="data row1 col2" >1524.23</td>
#                         <td id="T_92cb3_row1_col3" class="data row1 col3" >120.32</td>
#                         <td id="T_92cb3_row1_col4" class="data row1 col4" >3108.83</td>
#             </tr>
#             <tr>
#                         <th id="T_92cb3_level0_row2" class="row_heading level0 row2" >price_per_product</th>
#                         <td id="T_92cb3_row2_col0" class="data row2 col0" >682.50</td>
#                         <td id="T_92cb3_row2_col1" class="data row2 col1" >668.36</td>
#                         <td id="T_92cb3_row2_col2" class="data row2 col2" >27749.87</td>
#                         <td id="T_92cb3_row2_col3" class="data row2 col3" >141.96</td>
#                         <td id="T_92cb3_row2_col4" class="data row2 col4" >4162.08</td>
#             </tr>
#             <tr>
#                         <th id="T_92cb3_level0_row3" class="row_heading level0 row3" >order_product_cnt</th>
#                         <td id="T_92cb3_row3_col0" class="data row3 col0" >1.44</td>
#                         <td id="T_92cb3_row3_col1" class="data row3 col1" >1.11</td>
#                         <td id="T_92cb3_row3_col2" class="data row3 col2" >2.00</td>
#                         <td id="T_92cb3_row3_col3" class="data row3 col3" >13.62</td>
#                         <td id="T_92cb3_row3_col4" class="data row3 col4" >1.13</td>
#             </tr>
#             <tr>
#                         <th id="T_92cb3_level0_row4" class="row_heading level0 row4" >avg_price_per_order</th>
#                         <td id="T_92cb3_row4_col0" class="data row4 col0" >789.72</td>
#                         <td id="T_92cb3_row4_col1" class="data row4 col1" >685.89</td>
#                         <td id="T_92cb3_row4_col2" class="data row4 col2" >33363.20</td>
#                         <td id="T_92cb3_row4_col3" class="data row4 col3" >1779.27</td>
#                         <td id="T_92cb3_row4_col4" class="data row4 col4" >4392.12</td>
#             </tr>
#             <tr>
#                         <th id="T_92cb3_level0_row5" class="row_heading level0 row5" >avg_check</th>
#                         <td id="T_92cb3_row5_col0" class="data row5 col0" >508.84</td>
#                         <td id="T_92cb3_row5_col1" class="data row5 col1" >644.30</td>
#                         <td id="T_92cb3_row5_col2" class="data row5 col2" >1697.40</td>
#                         <td id="T_92cb3_row5_col3" class="data row5 col3" >1528.34</td>
#                         <td id="T_92cb3_row5_col4" class="data row5 col4" >3254.69</td>
#             </tr>
#             <tr>
#                         <th id="T_92cb3_level0_row6" class="row_heading level0 row6" >avg_orders_cnt_per_customer</th>
#                         <td id="T_92cb3_row6_col0" class="data row6 col0" >1.00</td>
#                         <td id="T_92cb3_row6_col1" class="data row6 col1" >2.02</td>
#                         <td id="T_92cb3_row6_col2" class="data row6 col2" >1.20</td>
#                         <td id="T_92cb3_row6_col3" class="data row6 col3" >1.07</td>
#                         <td id="T_92cb3_row6_col4" class="data row6 col4" >1.28</td>
#             </tr>
#             <tr>
#                         <th id="T_92cb3_level0_row7" class="row_heading level0 row7" >revenue</th>
#                         <td id="T_92cb3_row7_col0" class="data row7 col0" >682.50</td>
#                         <td id="T_92cb3_row7_col1" class="data row7 col1" >668.36</td>
#                         <td id="T_92cb3_row7_col2" class="data row7 col2" >27749.87</td>
#                         <td id="T_92cb3_row7_col3" class="data row7 col3" >141.96</td>
#                         <td id="T_92cb3_row7_col4" class="data row7 col4" >4162.08</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# **Вывод**
#
# Кластер 0:
#
# * price_per_product - средняя стоимостью по каждой позиции в заказе 682.50 у.е.
# * order_product_cnt - среднее количество товаров в заказе 1.44
# * avg_price_per_order - средняя цена на товар в заказе 789.72 у.е.
# * avg_check' - средний чек 508.84 у.е.
# * avg_orders_cnt_per_customer - среднее количество заказов на покупателя 1.00
#
# Кластер выделяется тем, что в нем небольшие показатели по переменным. Здесь, видмио, покупают простые розничные покупатели на небольшие суммы и малым объемом. Возможно это покупатели, которые целенаправленно берут конкретные позиции в магазине потому что им удобно их тут покупать по разным причинам.
#
# Кластер 1:
#
# * price_per_product - средняя стоимостью по каждой позиции в заказе 668.36 у.е.
# * order_product_cnt - среднее количество товаров в заказе 1.11
# * avg_price_per_order - средняя цена на товар в заказе 685.89 у.е.
# * avg_check' - средний чек 644.30 у.е.
# * avg_orders_cnt_per_customer - среднее количество заказов на покупателя 2.02
#
# Кластер похож на предыдущий, в нем средняя стоимость по каждой позиции в заказе немного меньше, чем в Кластере 0.
# Среднее количество товаров в заказе почти такая же в сревнении с предыдущим кластером. Также, показатели по средней цене на товар в заказе и средний чек колеблется наравне с Кластером 0. А вот показатель среднего количества заказов на покупателя в два раза больше. Здесь берут товар чуть больше по количеству.
#
# Кластер 2:
#
# * price_per_product - средняя стоимостью по каждой позиции в заказе 27749.87 у.е.
# * order_product_cnt - среднее количество товаров в заказе 2.00
# * avg_price_per_order - средняя цена на товар в заказе 33363.20 у.е.
# * avg_check' - средний чек 1697.40 у.е.
# * avg_orders_cnt_per_customer - среднее количество заказов на покупателя 1.20
#
# Кластер выделяется тем, что в нем средняя стоимостью по каждой позиции в заказе 27749.87 у.е. и средняя цена на товар в заказе 33363.20 у.е. Если учесть показатели по среднему количеству товаров в заказе и среднее количество заказов на покупателя, то здесь уже покупается явно не мелочевка.
#
# Кластер 3:
#
# * price_per_product - средняя стоимостью по каждой позиции в заказе 141.96 у.е.
# * order_product_cnt - среднее количество товаров в заказе 13.62
# * avg_price_per_order - средняя цена на товар в заказе 1779.27 у.е.
# * avg_check - средний чек 1528.34 у.е.
# * avg_orders_cnt_per_customer - среднее количество заказов на покупателя 1.07
#
# Кластер выделяется тем, что в нем средние показатели по переменным, но среднее количество товаров в заказе довольно большое. Предположу, что здесь оптовики, которые закупают небольшими партиями.
#
# Кластер 4:
#
# * price_per_product - средняя стоимостью по каждой позиции в заказе 4162.08 у.е.
# * order_product_cnt - среднее количество товаров в заказе 1.13
# * avg_price_per_order - средняя цена на товар в заказе 4392.12 у.е.
# * avg_check - средний чек 3254.69 у.е.
# * avg_orders_cnt_per_customer - среднее количество заказов на покупателя 1.07
#
# Хорошие показатели по средней цене на товар в заказе и средний чек, хотя количество товаров в заказе и количество заказов на покупателя небольшие. В этом кластере тоже больше качественные, чем количественные покупатели.

# %% [markdown]
# ## Шаг 5. Проверка статистических гипотез

# %% [markdown]
# **Статистическая значимость различий в среднем чеке заказа между сегментами покупателей присутствует.**

# %% [markdown]
# Гипотеза 1.
#
# Сформулируем нулевую и альтернативную гипотезы:
#
# H0: Статистическая значимость различий в среднем чеке заказа между сегментами покупателей отсутствует.
#
# H1: Статистическая значимость различий в среднем чеке заказа между сегментами покупателей присутствует.

# %% [markdown]
# *Делаем выборку по 0 и 1 кластерам.*

# %%
# Сгенерируем две независимые выборки.

cluster_0 = cluster[cluster['cluster']==0]['avg_check']
cluster_1 = cluster[cluster['cluster']==1]['avg_check']

# %%
# Оценим дисперсию по выборкам. Если различие будет более 5% - принимаем вывод, что дисперсии не равны.

print('Дисперсия кластера_0: {} '.format(np.var(cluster_0, ddof=1)))
print('Дисперсия кластера_1: {} '.format(np.var(cluster_1, ddof=1)))
print('Соотношение дисперсий: {} '.format((np.var(cluster_1, ddof=1))/(np.var(cluster_0, ddof=1))))
# Out:
# Дисперсия кластера_0: 246291.45727630786
# Дисперсия кластера_1: 289569.5437240974
# Соотношение дисперсий: 1.1757189913381243

# %%
# Проверим гипотезы.

alpha = 0.05

results = stats.mannwhitneyu(cluster_0, cluster_1)

print('P-value =', results.pvalue)

if (results.pvalue < alpha):
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
# Out:
# P-value = 3.347260613430138e-13
# Отвергаем нулевую гипотезу

# %%
print('Медиана кластера_0: {} '.format(int(np.median(cluster_0))))
print('Медиана кластера_1: {} '.format(int(np.median(cluster_1))))
print('Соотношение: {:.2f}'.format(np.median(cluster_1) / np.median(cluster_0)))
# Out:
# Медиана кластера_0: 352
# Медиана кластера_1: 458
# Соотношение: 1.30

# %% [markdown]
# *Делаем выборку по 1 и 2 кластерам.*

# %%
# Сгенерируем две независимые выборки.

cluster_1 = cluster[cluster['cluster']==1]['avg_check']
cluster_2 = cluster[cluster['cluster']==2]['avg_check']

# %%
# Оценим дисперсию по выборкам. Если различие будет более 5% - принимаем вывод, что дисперсии не равны.

print('Дисперсия кластера_1: {} '.format(np.var(cluster_1, ddof=1)))
print('Дисперсия кластера_2: {} '.format(np.var(cluster_2, ddof=1)))
print('Соотношение дисперсий: {} '.format((np.var(cluster_2, ddof=1))/(np.var(cluster_1, ddof=1))))
# Out:
# Дисперсия кластера_1: 289569.5437240974
# Дисперсия кластера_2: 3552711.8
# Соотношение дисперсий: 12.268941527169144

# %%
# Проверим гипотезы.

alpha = 0.05

results = stats.mannwhitneyu(cluster_1, cluster_2)

print('P-value =', results.pvalue)

if (results.pvalue < alpha):
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
# Out:
# P-value = 0.11684650646628486
# Не получилось отвергнуть нулевую гипотезу

# %%
print('Медиана кластера_1: {} '.format(int(np.median(cluster_1))))
print('Медиана кластера_2: {} '.format(int(np.median(cluster_2))))
print('Соотношение: {:.2f}'.format(np.median(cluster_2) / np.median(cluster_1)))
# Out:
# Медиана кластера_1: 458
# Медиана кластера_2: 1039
# Соотношение: 2.27

# %% [markdown]
# *Делаем выборку по 2 и 3 кластерам.*

# %%
# Сгенерируем две независимые выборки.

cluster_2 = cluster[cluster['cluster']==2]['avg_check']
cluster_3 = cluster[cluster['cluster']==3]['avg_check']

# %%
# Оценим дисперсию по выборкам. Если различие будет более 5% - принимаем вывод, что дисперсии не равны.

print('Дисперсия кластера_2: {} '.format(np.var(cluster_2, ddof=1)))
print('Дисперсия кластера_3: {} '.format(np.var(cluster_3, ddof=1)))
print('Соотношение дисперсий: {} '.format((np.var(cluster_3, ddof=1))/(np.var(cluster_2, ddof=1))))
# Out:
# Дисперсия кластера_2: 3552711.8
# Дисперсия кластера_3: 726359.9446811636
# Соотношение дисперсий: 0.20445225663425998

# %%
# Проверим гипотезы.

alpha = 0.05

results = stats.mannwhitneyu(cluster_2, cluster_3)

print('P-value =', results.pvalue)

if (results.pvalue < alpha):
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
# Out:
# P-value = 0.5886781640312297
# Не получилось отвергнуть нулевую гипотезу

# %%
print('Медиана кластера_2: {} '.format(int(np.median(cluster_2))))
print('Медиана кластера_3: {} '.format(int(np.median(cluster_3))))
print('Соотношение: {:.2f}'.format(np.median(cluster_3) / np.median(cluster_2)))
# Out:
# Медиана кластера_2: 1039
# Медиана кластера_3: 1320
# Соотношение: 1.27

# %% [markdown]
# *Делаем выборку по 3 и 4 кластерам.*

# %%
# Сгенерируем две независимые выборки.

cluster_3 = cluster[cluster['cluster']==3]['avg_check']
cluster_4 = cluster[cluster['cluster']==4]['avg_check']

# %%
# Оценим дисперсию по выборкам. Если различие будет более 5% - принимаем вывод, что дисперсии не равны.

print('Дисперсия кластера_3: {} '.format(np.var(cluster_3, ddof=1)))
print('Дисперсия кластера_4: {} '.format(np.var(cluster_4, ddof=1)))
print('Соотношение дисперсий: {} '.format((np.var(cluster_4, ddof=1))/(np.var(cluster_3, ddof=1))))
# Out:
# Дисперсия кластера_3: 726359.9446811636
# Дисперсия кластера_4: 3503240.1899288283
# Соотношение дисперсий: 4.823008503678681

# %%
# Проверим гипотезы.

alpha = 0.05

results = stats.mannwhitneyu(cluster_3, cluster_4)

print('P-value =', results.pvalue)

if (results.pvalue < alpha):
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
# Out:
# P-value = 6.1296901749508376e-18
# Отвергаем нулевую гипотезу

# %%
print('Медиана кластера_3: {} '.format(int(np.median(cluster_3))))
print('Медиана кластера_4: {} '.format(int(np.median(cluster_4))))
print('Соотношение: {:.2f}'.format(np.median(cluster_4) / np.median(cluster_3)))
# Out:
# Медиана кластера_3: 1320
# Медиана кластера_4: 2935
# Соотношение: 2.22

# %% [markdown]
# *Делаем выборку по 4 и 0 кластерам.*

# %%
# Сгенерируем две независимые выборки.

cluster_4 = cluster[cluster['cluster']==4]['avg_check']
cluster_0 = cluster[cluster['cluster']==0]['avg_check']

# %%
# Оценим дисперсию по выборкам. Если различие будет более 5% - принимаем вывод, что дисперсии не равны.

print('Дисперсия кластера_4: {} '.format(np.var(cluster_4, ddof=1)))
print('Дисперсия кластера_0: {} '.format(np.var(cluster_0, ddof=1)))
print('Соотношение дисперсий: {} '.format((np.var(cluster_0, ddof=1))/(np.var(cluster_4, ddof=1))))
# Out:
# Дисперсия кластера_4: 3503240.1899288283
# Дисперсия кластера_0: 246291.45727630786
# Соотношение дисперсий: 0.07030390265113723

# %%
# Проверим гипотезы.

alpha = 0.05

results = stats.mannwhitneyu(cluster_4, cluster_0)

print('P-value =', results.pvalue)

if (results.pvalue < alpha):
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
# Out:
# P-value = 1.735741506484491e-90
# Отвергаем нулевую гипотезу

# %%
print('Медиана кластера_4: {} '.format(int(np.median(cluster_4))))
print('Медиана кластера_0: {} '.format(int(np.median(cluster_0))))
print('Соотношение: {:.2f}'.format(np.median(cluster_0) / np.median(cluster_4)))
# Out:
# Медиана кластера_4: 2935
# Медиана кластера_0: 352
# Соотношение: 0.12

# %% [markdown]
# **Вывод**
#
# При выборке по 0 и 1 кластерам:
#
# P-value = 3.34. Мы отвергли нулевую гипотезу.
#
# При выборке по 1 и 2 кластерам:
#
# P-value = 0.11. Не получилось отвергнуть нулевую гипотезу.
#
# При выборке по 2 и 3 кластерам:
#
# P-value = 0.58. Не получилось отвергнуть нулевую гипотезу.
#
# При выборке по 3 и 4 кластерам:
#
# P-value = 6.12. Мы отвергли нулевую гипотезу.
#
# При выборке по 4 и 0 кластерам:
#
# P-value = 1.73. Мы отвергли нулевую гипотезу.
#
# Из 5 раз - 3 раза была отвергнута нулевая гипотеза, 2 раза не получилось отвергнуть нулевую гипотезу.
#
# Таким образом, исходя из большинства в 1, статистическая значимость различий в среднем чеке заказа между сегментами покупателей присутствует.

# %% [markdown]
# **Статистическая значимость различий в среднем объёме продаж между сегментами присутствует.**

# %% [markdown]
# Гипотеза 2.
#
# Сформулируем нулевую и альтернативную гипотезы:
#
# H0: Статистическая значимость различий в среднем объёме продаж между сегментами отсутствует.
#
# H1: Статистическая значимость различий в среднем объёме продаж между сегментами присутствует.

# %%
display(cluster.groupby(['cluster']).mean().T)
# Out:
# cluster                          0      1        2       3       4
# quantity                      4.69   2.98   105.40   18.41    8.73
# price                       431.37 632.22  1524.23  120.32 3108.83
# price_per_product           682.50 668.36 27749.87  141.96 4162.08
# order_product_cnt             1.44   1.11     2.00   13.62    1.13
# avg_price_per_order         789.72 685.89 33363.20 1779.27 4392.12
# avg_check                   508.84 644.30  1697.40 1528.34 3254.69
# avg_orders_cnt_per_customer   1.00   2.02     1.20    1.07    1.28
# revenue                     682.50 668.36 27749.87  141.96 4162.08

# %% [markdown]
# *Делаем выборку по 0 и 1 кластерам.*

# %%
# Сгенерируем две независимые выборки.

s_cluster_0 = cluster[cluster['cluster']==0]['revenue']
s_cluster_1 = cluster[cluster['cluster']==1]['revenue']

# %%
# Оценим дисперсию по выборкам. Если различие будет более 5% - принимаем вывод, что дисперсии не равны.

print('Дисперсия кластера_0: {} '.format(np.var(s_cluster_0, ddof=1)))
print('Дисперсия кластера_1: {} '.format(np.var(s_cluster_1, ddof=1)))
print('Соотношение дисперсий: {} '.format((np.var(s_cluster_1, ddof=1))/(np.var(s_cluster_0, ddof=1))))
# Out:
# Дисперсия кластера_0: 478562.9522237346
# Дисперсия кластера_1: 311936.6183679865
# Соотношение дисперсий: 0.6518194041526055

# %%
# Проверим гипотезы.

alpha = 0.05

results = stats.mannwhitneyu(s_cluster_0, s_cluster_1)

print('P-value =', results.pvalue)

if (results.pvalue < alpha):
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
# Out:
# P-value = 0.09466569079213594
# Не получилось отвергнуть нулевую гипотезу

# %%
print('Медиана кластера_0: {} '.format(int(np.median(s_cluster_0))))
print('Медиана кластера_1: {} '.format(int(np.median(s_cluster_1))))
print('Соотношение: {:.2f}'.format(np.median(s_cluster_1) / np.median(s_cluster_0)))
# Out:
# Медиана кластера_0: 450
# Медиана кластера_1: 480
# Соотношение: 1.07

# %% [markdown]
# *Делаем выборку по 1 и 2 кластерам.*

# %%
# Сгенерируем две независимые выборки.

s_cluster_1 = cluster[cluster['cluster']==1]['revenue']
s_cluster_2 = cluster[cluster['cluster']==2]['revenue']

# %%
# Оценим дисперсию по выборкам. Если различие будет более 5% - принимаем вывод, что дисперсии не равны.

print('Дисперсия кластера_1: {} '.format(np.var(s_cluster_1, ddof=1)))
print('Дисперсия кластера_2: {} '.format(np.var(s_cluster_2, ddof=1)))
print('Соотношение дисперсий: {} '.format((np.var(s_cluster_2, ddof=1))/(np.var(s_cluster_1, ddof=1))))
# Out:
# Дисперсия кластера_1: 311936.6183679865
# Дисперсия кластера_2: 249383128.75555557
# Соотношение дисперсий: 799.4673086484588

# %%
# Проверим гипотезы.

alpha = 0.05

results = stats.mannwhitneyu(s_cluster_1, s_cluster_2)

print('P-value =', results.pvalue)

if (results.pvalue < alpha):
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
# Out:
# P-value = 0.00011437980116564217
# Отвергаем нулевую гипотезу

# %%
print('Медиана кластера_1: {} '.format(int(np.median(s_cluster_1))))
print('Медиана кластера_2: {} '.format(int(np.median(s_cluster_2))))
print('Соотношение: {:.2f}'.format(np.median(s_cluster_2) / np.median(s_cluster_1)))
# Out:
# Медиана кластера_1: 480
# Медиана кластера_2: 26616
# Соотношение: 55.45

# %% [markdown]
# *Делаем выборку по 2 и 3 кластерам.*

# %%
# Сгенерируем две независимые выборки.

s_cluster_2 = cluster[cluster['cluster']==2]['revenue']
s_cluster_3 = cluster[cluster['cluster']==3]['revenue']

# %%
# Оценим дисперсию по выборкам. Если различие будет более 5% - принимаем вывод, что дисперсии не равны.

print('Дисперсия кластера_2: {} '.format(np.var(s_cluster_2, ddof=1)))
print('Дисперсия кластера_3: {} '.format(np.var(s_cluster_3, ddof=1)))
print('Соотношение дисперсий: {} '.format((np.var(s_cluster_3, ddof=1))/(np.var(s_cluster_2, ddof=1))))
# Out:
# Дисперсия кластера_2: 249383128.75555557
# Дисперсия кластера_3: 4953.460423334392
# Соотношение дисперсий: 1.9862852984693106e-05

# %%
# Проверим гипотезы.

alpha = 0.05

results = stats.mannwhitneyu(s_cluster_2, s_cluster_3)

print('P-value =', results.pvalue)

if (results.pvalue < alpha):
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
# Out:
# P-value = 5.1051987464082376e-08
# Отвергаем нулевую гипотезу

# %%
print('Медиана кластера_2: {} '.format(int(np.median(s_cluster_2))))
print('Медиана кластера_3: {} '.format(int(np.median(s_cluster_3))))
print('Соотношение: {:.2f}'.format(np.median(s_cluster_3) / np.median(s_cluster_2)))
# Out:
# Медиана кластера_2: 26616
# Медиана кластера_3: 128
# Соотношение: 0.00

# %% [markdown]
# *Делаем выборку по 3 и 4 кластерам.*

# %%
# Сгенерируем две независимые выборки.

s_cluster_3 = cluster[cluster['cluster']==3]['revenue']
s_cluster_4 = cluster[cluster['cluster']==4]['revenue']

# %%
# Оценим дисперсию по выборкам. Если различие будет более 5% - принимаем вывод, что дисперсии не равны.

print('Дисперсия кластера_3: {} '.format(np.var(s_cluster_3, ddof=1)))
print('Дисперсия кластера_4: {} '.format(np.var(s_cluster_4, ddof=1)))
print('Соотношение дисперсий: {} '.format((np.var(s_cluster_4, ddof=1))/(np.var(s_cluster_3, ddof=1))))
# Out:
# Дисперсия кластера_3: 4953.460423334392
# Дисперсия кластера_4: 5321963.991874309
# Соотношение дисперсий: 1074.3931589326926

# %%
# Проверим гипотезы.

alpha = 0.05

results = stats.mannwhitneyu(s_cluster_3, s_cluster_4)

print('P-value =', results.pvalue)

if (results.pvalue < alpha):
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
# Out:
# P-value = 4.416689043519738e-40
# Отвергаем нулевую гипотезу

# %%
print('Медиана кластера_3: {} '.format(int(np.median(s_cluster_3))))
print('Медиана кластера_4: {} '.format(int(np.median(s_cluster_4))))
print('Соотношение: {:.2f}'.format(np.median(s_cluster_4) / np.median(s_cluster_3)))
# Out:
# Медиана кластера_3: 128
# Медиана кластера_4: 3562
# Соотношение: 27.72

# %% [markdown]
# *Делаем выборку по 4 и 0 кластерам.*

# %%
# Сгенерируем две независимые выборки.

s_cluster_4 = cluster[cluster['cluster']==4]['revenue']
s_cluster_0 = cluster[cluster['cluster']==0]['revenue']

# %%
# Оценим дисперсию по выборкам. Если различие будет более 5% - принимаем вывод, что дисперсии не равны.

print('Дисперсия кластера_4: {} '.format(np.var(s_cluster_4, ddof=1)))
print('Дисперсия кластера_0: {} '.format(np.var(s_cluster_0, ddof=1)))
print('Соотношение дисперсий: {} '.format((np.var(s_cluster_0, ddof=1))/(np.var(s_cluster_4, ddof=1))))
# Out:
# Дисперсия кластера_4: 5321963.991874309
# Дисперсия кластера_0: 478562.9522237346
# Соотношение дисперсий: 0.08992224542563891

# %%
# Проверим гипотезы.

alpha = 0.05

results = stats.mannwhitneyu(s_cluster_4, s_cluster_0)

print('P-value =', results.pvalue)

if (results.pvalue < alpha):
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
# Out:
# P-value = 8.081155529013755e-108
# Отвергаем нулевую гипотезу

# %%
print('Медиана кластера_4: {} '.format(int(np.median(s_cluster_4))))
print('Медиана кластера_0: {} '.format(int(np.median(s_cluster_0))))
print('Соотношение: {:.2f}'.format(np.median(s_cluster_0) / np.median(s_cluster_4)))
# Out:
# Медиана кластера_4: 3562
# Медиана кластера_0: 450
# Соотношение: 0.13

# %% [markdown]
# **Вывод**
#
# При выборке по 0 и 1 кластерам:
#
# P-value = 0.094. Не получилось отвергнуть нулевую гипотезу.
#
# При выборке по 1 и 2 кластерам:
#
# P-value = P-value = 0.00011. Мы отвергли нулевую гипотезу.
#
# При выборке по 2 и 3 кластерам:
#
# P-value = 5.10. Мы отвергли нулевую гипотезу.
#
# При выборке по 3 и 4 кластерам:
#
# P-value = 4.41. Мы отвергли нулевую гипотезу.
#
# При выборке по 4 и 0 кластерам:
#
# P-value = 8.08. Мы отвергли нулевую гипотезу.
#
# Таким образом, статистическая значимость различий в среднем объёме продаж между сегментами присутствует.

# %%
# Объединим кластеры с датасетом.

cluster = cluster[['customer_id', 'cluster']].reset_index(drop=True)
ecom_online = ecom_online.merge(cluster, on='customer_id', how='left')

# %% [markdown]
# _Проверим гипотезы._

# %%
# Функция для проведения теста Шапиро-Уилка на нормальность распределения.

def shapiro_test(data, columns):
    results = {}
    for column in columns:
        stat, p = shapiro(data[column])
        results[column] = (stat, p)
    return results

# Функция для проведения теста Левена.
def levene_test(data, group_column, value_columns):
    results = {}
    for column in value_columns:
        groups = [group[column].values for name, group in data.groupby(group_column)]
        stat, p = levene(*groups)
        results[column] = (stat, p)
    return results

columns_to_test = ['avg_check', 'revenue']
shapiro_results = shapiro_test(ecom_online, columns_to_test)
levene_results = levene_test(ecom_online, 'cluster', columns_to_test)

# Вывод результатов теста Шапиро-Уилка.
print('Результаты теста Шапиро-Уилка:')
for column, (stat, p) in shapiro_results.items():
    print(f"{column}: Статистика = {stat}, p-value={p}")

# Вывод результатов теста Левена.
print('\nРезультаты теста Левена:')
for column, (stat, p) in levene_results.items():
    print(f"{column}: Статистика = {stat}, p-value={p}")
# Out:
# Результаты теста Шапиро-Уилка:
# avg_check: Статистика = 0.7856587171554565, p-value=0.0
# revenue: Статистика = 0.3383758068084717, p-value=0.0
#
# Результаты теста Левена:
# avg_check: Статистика = 216.00295965402358, p-value=1.0817166121381863e-171
# revenue: Статистика = 931.6327672671046, p-value=0.0

# %% [markdown]
# **При проведении множественных тестов скорректировать уровень значимости методом Бонферрони: уровень значимости 0.05/5 = 0.01**

# %%
# Функция для проведения теста Крускала-Уоллиса.

def kruskal_test(data, group_column, value_column, alpha_corrected):
    groups = [group[value_column].values for name, group in data.groupby(group_column)]
    stat, p = kruskal(*groups)
    result = f"{value_column}:\n"
    result += f"  Статистика = {stat:.4f}, P-value = {p:.4f}\n"
    if p < alpha_corrected:
        result += f"  Отвергаем нулевую гипотезу: Существуют значимые различия между кластерами для {value_column}.\n"
        result += f"  Это говорит о том, что распределение в {value_column} отличается между кластерами.\n"
    else:
        result += f"  Не получилось отвергнуть нулевую гипотезу: Не существуют значимые различия между кластерами для {value_column}.\n"
        result += f"  Это говорит о том, что распределение в {value_column} между кластерами схоже.\n"
    return result

# Корректированный уровень значимости.
alpha_corrected = 0.01

# Проведение тестов для каждой метрики.
columns_to_test = ['avg_check', 'revenue']

# Вывод результатов.
for column in columns_to_test:
    result = kruskal_test(ecom_online, 'cluster', column, alpha_corrected)
    print(result)
# Out:
# avg_check:
#   Статистика = 2031.3646, P-value = 0.0000
#   Отвергаем нулевую гипотезу: Существуют значимые различия между кластерами для avg_check.
#   Это говорит о том, что распределение в avg_check отличается между кластерами.
#
# revenue:
#   Статистика = 1348.6181, P-value = 0.0000
#   Отвергаем нулевую гипотезу: Существуют значимые различия между кластерами для revenue.
#   Это говорит о том, что распределение в revenue отличается между кластерами.

# %% [markdown]
# Средний чек:
#
# P-value = 0.0000, Статистика = 2031.3646
#
# Мы отвергли нулевую гипотезу. Это говорит о том, что существуют значимые различия между кластерами для среднего чека.
#
# Выручка:
#
# P-value = 0.0000, Статистика = 1348.6181
#
# Мы отвергли нулевую гипотезу. Это говорит о том, что существуют значимые различия между кластерами для среднем объёме заказов.
#
# Тесты Крускала-Уоллиса показали различия между кластерами для обеих метрик. Таким образом, это подтверждает, что кластеры имеют статистически значимые различия в среднем чеке и среднем объеме заказов.

# %%
# Посотмри по каждому кластеру в разрезе категорий товара средний чек и средний объёме продаж.

cluster_0_categories = ecom_online.loc[ecom_online['cluster'] == 0].groupby('category_list').agg({
    'avg_check':'mean', 
    'revenue': 'mean'}).sort_values(by=['avg_check', 'revenue'], ascending=False).head().reset_index()
cluster_0_categories
# Out:
#       category_list  avg_check  revenue
# 0       Инструменты     751.53   988.81
# 1   Товары для сада     661.43   388.93
# 2   Товары для дома     545.52   593.13
# 3  Товары для кухни     497.86   757.09

# %%
cluster_1_categories = ecom_online.loc[ecom_online['cluster'] == 1].groupby('category_list').agg({
    'avg_check':'mean', 
    'revenue': 'mean'}).sort_values(by=['avg_check', 'revenue'], ascending=False).head().reset_index()
cluster_1_categories
# Out:
#       category_list  avg_check  revenue
# 0       Инструменты     866.22  1189.53
# 1   Товары для сада     657.71   501.97
# 2   Товары для дома     633.62   665.15
# 3  Товары для кухни     604.92   574.43

# %%
cluster_2_categories = ecom_online.loc[ecom_online['cluster'] == 2].groupby('category_list').agg({
    'avg_check':'mean', 
    'revenue': 'mean'}).sort_values(by=['avg_check', 'revenue'], ascending=False).head().reset_index()
cluster_2_categories
# Out:
#       category_list  avg_check  revenue
# 0   Товары для сада    2724.00 28544.00
# 1   Товары для дома    1284.00 34221.33
# 2  Товары для кухни    1039.00  5613.33

# %%
cluster_3_categories = ecom_online.loc[ecom_online['cluster'] == 3].groupby('category_list').agg({
    'avg_check':'mean', 
    'revenue': 'mean'}).sort_values(by=['avg_check', 'revenue'], ascending=False).head().reset_index()
cluster_3_categories
# Out:
#       category_list  avg_check  revenue
# 0   Товары для сада    1813.08   126.20
# 1   Товары для дома    1751.55   142.17
# 2  Товары для кухни    1566.03   169.50

# %%
cluster_4_categories = ecom_online.loc[ecom_online['cluster'] == 4].groupby('category_list').agg({
    'avg_check':'mean', 
    'revenue': 'mean'}).sort_values(by=['avg_check', 'revenue'], ascending=False).head().reset_index()
cluster_4_categories
# Out:
#       category_list  avg_check  revenue
# 0   Товары для сада    3898.47  4098.64
# 1       Инструменты    3097.12  2958.81
# 2   Товары для дома    3009.88  3957.16
# 3  Товары для кухни    2375.30  2675.04

# %%
# # Посотмри по каждому кластеру в разрезе сезонности средний чек и средний объёме продаж.

cluster_0_season = ecom_online.loc[ecom_online['cluster'] == 0].groupby('season_category').agg({
    'avg_check':'mean', 
    'revenue': 'mean'}).sort_values(by=['avg_check', 'revenue'], ascending=False).head().reset_index()
cluster_0_season
# Out:
#   season_category  avg_check  revenue
# 0           осень     686.25   565.75
# 1           весна     542.96   461.04
# 2            лето     532.18   531.27
# 3            зима     520.56   670.99

# %%
cluster_1_season = ecom_online.loc[ecom_online['cluster'] == 1].groupby('season_category').agg({
    'avg_check':'mean', 
    'revenue': 'mean'}).sort_values(by=['avg_check', 'revenue'], ascending=False).head().reset_index()
cluster_1_season
# Out:
#   season_category  avg_check  revenue
# 0           осень     665.45   586.81
# 1            зима     657.55   640.36
# 2            лето     621.67   622.82
# 3           весна     596.04   579.53

# %%
cluster_2_season = ecom_online.loc[ecom_online['cluster'] == 2].groupby('season_category').agg({
    'avg_check':'mean', 
    'revenue': 'mean'}).sort_values(by=['avg_check', 'revenue'], ascending=False).head().reset_index()
cluster_2_season
# Out:
#   season_category  avg_check  revenue
# 0           осень    1586.86  8292.86
# 1            зима    1426.00 28650.00
# 2            лето     148.00 49432.00

# %%
cluster_3_season = ecom_online.loc[ecom_online['cluster'] == 3].groupby('season_category').agg({
    'avg_check':'mean', 
    'revenue': 'mean'}).sort_values(by=['avg_check', 'revenue'], ascending=False).head().reset_index()
cluster_3_season
# Out:
#   season_category  avg_check  revenue
# 0            лето    2228.87   140.11
# 1           весна    1829.26   125.74
# 2            зима    1440.37   110.41
# 3           осень    1422.56   150.43

# %%
cluster_4_season = ecom_online.loc[ecom_online['cluster'] == 4].groupby('season_category').agg({
    'avg_check':'mean', 
    'revenue':'mean'}).sort_values(by=['avg_check', 'revenue'], ascending=False).head().reset_index()
cluster_4_season
# Out:
#   season_category  avg_check  revenue
# 0           весна    3653.79  4097.88
# 1            лето    3627.78  4743.24
# 2           осень    3210.21  3240.15
# 3            зима    3054.88  4065.62

# %% [markdown]
# Здесь мы наблюдаем следующее:
#
# Кластер 0 по категориям товаров:
#
# * Категория Инструменты лидирует по среднему чеку 751.53 у.е. и среднему объёму продаж 988.81 у.е.
# * Категория Товары для сада идет за предыдущей категорией по среднему чеку 661.43 у.е., но вот объём продаж тут небольшой по сравнению со всеми категориями - 388.93 у.е
# * Категория Товары для дома показывают третье место по среднему чеку 545.52 у.е. и среднему объёму продаж в 593.13 у.е.
# * Категория Товары для кухни представляет собой самый маленький средний чек по сравнению с другими, но объёму продаж тут довольно хороший - 757.09 у.е.
#
#
# по сезонности:
#
# * осень	даёт средний чек 686.25 у.е. и 565.75 у.е. в среднем объёме продаж.
# * весна, лето и зима по среднему чеку почти в одном диапазоне: 542.96 у.е., 532.18 у.е. и 520.56 у.е. соответственно. По объёму продаж, по всем сезонам лидирует зима - 670.99 у.е.
#
# Тут можно обратить внимание на Категорию Инструменты и на осенний период.
#
# Кластер 1 по категориям товаров:
#
# * Категория Инструменты лидирует по среднему чеку 866.22 у.е. и среднему объёму продаж 1189.53 у.е.
# * Категории Товары для сада, Категория Товары для дома и Товары для кухни идут следом по среднему чеку практически в одном диапазоне: 657.71 у.е., 633.62 у.е. и 604.92 у.е. соответственно. По среднему объёму продаж 501.97 у.е., 665.15 у.е. и 574.43 у.е. соответственно.
#
# по сезонности:
#
# * осень - лидирует по среднему чеку 665.45 у.е. и средний объём продаж 586.81 у.е.
# * остальные сезоны не сильно отстают по среднему чеку - на втором месте зима, далее лето и весна. По объему продаж в этом кластере лидирует зима - 640.36 у.е.
#
# Тут можно также обратить внимание на Категорию Инструменты и осенний и зимний периоды.
#
# Кластер 2 по категориям товаров:
#
# * Здесь лидирует категория Товары для сада со средним чеком 2724.00 у.е., но по объёму продаж лидирует категория Товары для дома  34221.33 у.е. со средним чеком 1284.00 у.е. Замыкает лидерство сегмент Товары для кухни.
# * Категория Инструменты в этот кластер не попала.
#
# по сезонности:
#
# * Осень и зима тут в лидерах совсем с небольшим отрывом друг от друга по среднему чеку: 1586.86 у.е. и 1426.00 у.е. соответственно.
# * Лето здесь совсем с небольшими показателями по среднему чеку 148.00 у.е., зато лидирует по объёму продаж - 49432.00 у.е., самый большой показатель в этом кластере по сезонности.
# * Весна в данном кластере не присутствует.
#
# Тут можно обратить внимание на Категорию Товары для сада и Товары для дома. Осенний и зимний периоды.
# Также, можно заострить внимание на летний период с его объёмом продаж в 49432.00 у.е.
#
# Кластер 3 по категориям товаров:
#
# * Категория Товары для сада здесь в лидерах по среднему чеку - 1813.08 у.е., а вот по объёму продаж Товары для кухни - 169.50
# * Категория Инструменты в этот кластер также не попала.
#
# по сезонности:
#
# * лето в лидерах по среднему чеку - 2228.87 у.е., по объёму продаж - осень и лето.
#
# Тут можно обратить внимание также на Категорию Товары для сада и Товары для кухни. Осенний и летний периоды.
#
# Кластер 4 по категориям товаров:
#
# * Категория Товары для сада как по чеку, так и по объёму продаж безусловный лидер - 3898.47 у.е. и 4098.64 у.е. соответственно.
#
# по сезонности:
#
# * весна в лидерах по среднему чеку - 3653.79 у.е., по выручке лидирует лето - 4743.24 у.е.
#
# Тут можно обратить внимание на Категорию Товары для сада. Весенний и летний периоды.

# %%
# Посмотрим выручку в динамике по категориям товара посезонно для каждого кластера.

cluster_season_category = ecom_online.pivot_table(index=[
    'season_category', 'cluster'], columns='category_list', values='revenue', aggfunc='mean')

df = cluster_season_category.reset_index().melt(id_vars=[
    'season_category', 
    'cluster'], var_name='category_list', value_name='revenue')

season_order = ['зима', 'весна', 'лето', 'осень']

df['season_category'] = pd.Categorical(df['season_category'], categories=season_order, ordered=True)

unique_categories = sorted(df['category_list'].unique())

fig = plt.figure(figsize=(15, 20))
gs = gridspec.GridSpec(3, 2, height_ratios=[1, 1, 1], hspace=0.7, wspace=0.5)

clusters = df['cluster'].unique()

for i, cluster in enumerate(clusters):
    ax = fig.add_subplot(gs[i // 2, i % 2])
    clusters_data = df[df['cluster'] == cluster]
    sns.barplot(x='season_category', y='revenue', hue='category_list', hue_order=unique_categories, data=clusters_data, ax=ax)
    ax.set_title(f'Кластер {cluster}')
    ax.set_xlabel('Сезон')
    ax.set_ylabel('Выручка')
    ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
    if i == 0:
        handles, labels = ax.get_legend_handles_labels()
    ax.legend_.remove()

plt.legend(bbox_to_anchor=(2.05 , 1), loc='upper left', borderaxespad=1)

fig.subplots_adjust(right=0.85, top=0.9, hspace=0.7, wspace=0.5)

fig.suptitle('Выручка в динамике по категориям товара посезонно для каждого кластера', fontsize=17, y=0.95)

plt.show();

# %% [markdown]
# Кластер 0:
#
# Лидирует по выручке Категория Инструменты по всем сезонам. Весной этот показатель больше всего - превышает показатель в 1250 у.е. На втором месте зима с приблизительным показателем в 1150 у.е. Далее осень и лето.
#
# Кластер 1:
#
# Также лидирует Категория Инструменты по всем сезонам. Больше всего этот показатель приходится на лето - более 1600 у.е. На втором месте по всем сезонам идут Товары для дома. На третьем месте Товары для кухни. Эта категория имеет почти такие же значения, как и Товары для дома. Очень близко по показателям выручки. Товары для сада расположились на 4 месте и видно, что осенью немного обогнали Товары для сада по показателю.
#
# Кластер 3:
#
# Здесь в лидерах Товары для кухни в осенний период. Весной эта категория показывает почти равную динамику с категориями Товары для дома и Товары для сада. Категория Инструменты в этом кластере не представлена, видимо, продаж не было совсем.
#
# Кластер 4:
#
# Здесь довольно уверенно показывает себя в летний период Категория Товары для кухни - более 7000 у.е. Также, здесь наблюдается хорошая динамика по выручке у категорий Товары для дома и сада. У Категории Инструментов тоже хорошие показатели, но здесь они на последних местах по выручке.
#
# _Кластер 2_:
#
# На этот кластер можно обратить отдельное внимание, так как в нем представлены всего 3 категории, исключая Инструменты. В летний сезон можно наблюдать очень хорошую динамику у категории Товары для дома. Другие категории по этому показателю в этом сезоне не представлены. Весна для этого кластера вообще является провальным сезоном - показатели отсутствуют. В зимний период можно наблюдать динамику по товарам для сада и дома. Осенью, по категориям представлены только Товары для сада с показателем около 25000 у.е. и совсем небольшим показателем идут Товары для кухни - 5000 у.е.

# %% [markdown]
# ## Общие выводы и рекомендации

# %% [markdown]
# **При загрузки, обработки и изучении данных было выявлено,** что в датасете ecom_online присутствует 6 столбцов, и он состоит из 7474 наблюдений. Вес 350.5+ KB.
#
# Дубликаты и пропуски отсутствуют. Названия столбцов в датаcете приведены к нижнему регистру и нужному формату.
#
# Далее, был приведен столбец с датой нужный формат. Проверили, за какой период предоставлены данные - данные предоставлены с 2018-10-01 00:00:00 по 2020-01-31 15:00:00.
#
# При выявлении 1886 неявных дубликатов - удалили их, так как это скорее всего и есть то задвоение заказов о которых предупреждали, когда из интернета и из системы идет один и тот же заказ.
#
# Удалили заказы, в которых есть разные даты, так как это похоже на сбои при заказе, либо ошибку в записи данных и тестовый заказ для проверки системы на 1000 единиц одного наименования товара. Также, воспользовались 99м перцентилем, чтобы отсечь аномальных клиентов.
#
# Создали отдельно колонки с месяцем и годом. Также, был добавлен столбец с выручкой по заказам.
#
# **В исследовательском анализе данных** была проведена категоризация наименования товара. При рассмотрении категорий заметно, что больше всего товаров для дома и сада (46% и 42,4% соответственно). На третьем месте товары для кухни, их всего 9,8%. Инструменты включают в себя 1,8% товаров.
#
# Если смотреть рейтинг по самым продаваемым товарам в каждой категории по количеству заказов, то в категории Товары для сада в лидерах продаж идет Пеларгония розебудная Red Pandora укорененный черенок - 63 заказа с выручкой 10659.33 у.е. Зато, на третьем месте Сумка-тележка 2-х колесная Gimi Argo синяя - 44 заказа, но выручка по ней больше - 47258.00 у.е.
#
# В категории Товары для дома можно видеть, что самое продаваемое наименование - Пеларгония зональная диам. 12 см сиреневый полумахровый. 50 заказов с выручкой 9633.00 у.е.
#
# В категории Инструменты на первом месте по количеству продаж идет Стяжка оконная с болтом СТ-55 цинк, 1108354 - 5 заказов, выручка составила 748.33 у.е. Но, если смотреть по выручке, то здесь лидирует Стремянки Colombo Leonardo 2 ступени G300A02W серая 3646 - 8997.00 у.е. всего с 3 заказами.
#
# И в категории Товары для кухни можно увидеть, что на все 5 товаров рейтинга сделано по 5 заказов. Больше всего выручка у Скатерть Dasch Донна Роза из ПВХ 0401-2 Розы круглая 152 см 5974, потому что в каком-то из заказов было заказано 2шт., так как общее количество по 5 заказам - 6шт. Поэтому, эта позиция лидирует по выручке 2652.00у.е. Но, Овощеварка алюминиевая Scovo МТ-045, Хозлэнд, 1502079 не сильно отстает - 2245.00 у.е.
#
# По рейтингу с самыми прибыльными товарами в каждой категории видно следующее:
#
# * По категории Товары для дома, самым прибыльным является Простынь вафельная 200х180 см WELLNESS RW180-01 100% хлопок - 53232.00 у.е.
#
# * В категории Товары для сада, самым прибыльным является Сумка-тележка 2-х колесная Gimi Argo синяя - 47258.00 у.е.
#
# * В категории Товары для кухни, самым прибыльным является Набор ножей Attribute CHEF 5 предметов AKF522 - 29248.00 у.е.
#
# * В категории Инструменты, самым прибыльным является Стремянки Colombo Leonardo 2 ступени G300A02W серая 3646 - 8997.00 у.е.
#
# В сезонности товаров по категориям и продаж категорий товаров по временам года, можно сказать, что здесь в лидерах категория Инструменты. Затем, Товары для кухни и Товары для дома практически на одном уровне. Товары для кухни немного больше по выручке. Замыкает рейтинг категория Товары для сада.
#
# Если смотреть по временам года, то видно, что на зиму приходится больше всего выручки. Чуть меньше на осень и лето. Весной этот показатель небольшой.
#
# Если смотреть выручку по месяцам, то больше всего выручка была в январе 2019 года и в декабре 2018 года. Самые провальные месяцы по выручке - апрель и май 2019 года. Это соответствует предыдущему графику выручки по временам года.
#
# Если посмотреть распределение заказов по месяцам, то на графике видны пики в зимние периоды. В 2018 году количество заказов выросло к декабрю почти до 235. К январю 2019 года идет резкий спад. Скорее всего это связано с новогодними праздниками. Далее, в феврале 2019 года количество заказов обновляет пик - 250. В конце весеннего периода идет постепенное снижение и минимум приходится на июнь 2019 года. Весь летний период идет некоторый боковик, который колеблется от 160 заказов до, почти, 200. В осенний период, начиная с сентября 2019 года, идет планомерное восстановление количества заказов переходящее в зимний период, где количество заказов снова подбирается к пиковым значениям декабря 2018 года и выходит на новые максимумы. Зимний период для компании явно является прибыльным.
#
# Выручка и количество покупателей по категориям говорит нам, что больше всего выручки и покупателей в категории Товары для дома: 190 0462.50 у.е. и 1641 покупателей. Следом идет категория Товары для сада: 1 167 048.58 у.е. и 844 покупателей. Далее по убывающей - Товары для кухни с выручкой 395 732.00 у.е. и с 422 покупателями, и Инструменты с выручкой 135 277.33 и с 88 покупателями. Видно, что в суммарном соотношении, категории товары для дома и сада приносят магазину значительную часть выручки.
#
# **При просмотре сегментации покупателей на основе истории их покупок**, тепловая карта показывает, что есть взаимосвязь между некоторыми переменными. Взаимосвязь прослеживается между avg_price_per_order - средняя цена на товар в заказе и avg_check - средний чек (corr = 0,51). Еще есть переменные, которые положительно коррелируют со средней ценой на товар в заказе, это order_product_cnt - среднее количество товаров в заказе (corr = 0,083). Также есть корреляция с avg_check - средний чек и price_per_product - средняя стоимость по каждой позиции в заказе (corr = 0,49). И еще одна положительная корреляция: avg_check - средний чек и order_product_cnt - среднее количество товаров в заказе (corr = 0,15). Далее, положительная корреляция прослеживается у avg_price_per_order - средняя цена на товар в заказе и price_per_product - средняя стоимость по каждой позиции в заказе (corr = 0,93). И небольшая положительная корреляция между avg_check - средний чек и avg_orders_cnt_per_customer - среднее количество заказов на покупателя (corr = 0,00062).
#
# Средний чек коррелирует с большим количеством переменных.
#
# При кластеризации выделяются пять кластеров. При выведении статистики по сегментам покупателей, можно сделать следующие выводы:
#
# Кластер 0:
#
# * price_per_product - средняя стоимостью по каждой позиции в заказе 682.50 у.е.
# * order_product_cnt - среднее количество товаров в заказе 1.44
# * avg_price_per_order - средняя цена на товар в заказе 789.72 у.е.
# * avg_check' - средний чек 508.84 у.е.
# * avg_orders_cnt_per_customer - среднее количество заказов на покупателя 1.00
#
# Кластер выделяется тем, что в нем небольшие показатели по переменным. Здесь, видимо, покупают простые розничные покупатели на небольшие суммы и малым объемом. Возможно это покупатели, которые целенаправленно берут конкретные позиции в магазине, потому что им удобно их тут покупать по разным причинам.
#
# Кластер 1:
#
# * price_per_product - средняя стоимостью по каждой позиции в заказе 668.36 у.е.
# * order_product_cnt - среднее количество товаров в заказе 1.11
# * avg_price_per_order - средняя цена на товар в заказе 685.89 у.е.
# * avg_check' - средний чек 644.30 у.е.
# * avg_orders_cnt_per_customer - среднее количество заказов на покупателя 2.02
#
# Кластер похож на предыдущий, в нем средняя стоимость по каждой позиции в заказе немного меньше, чем в Кластере 0.
# Среднее количество товаров в заказе почти такая же в сревнение с предыдущим кластером. Также, показатели по средней цене на товар в заказе и средний чек колеблется наравне с Кластером 0. А вот показатель среднего количества заказов на покупателя в два раза больше. Здесь берут товар чуть больше по количеству.
#
# Кластер 2:
#
# * price_per_product - средняя стоимостью по каждой позиции в заказе 27749.87 у.е.
# * order_product_cnt - среднее количество товаров в заказе 2.00
# * avg_price_per_order - средняя цена на товар в заказе 33363.20 у.е.
# * avg_check' - средний чек 1697.40 у.е.
# * avg_orders_cnt_per_customer - среднее количество заказов на покупателя 1.20
#
# Кластер выделяется тем, что в нем средняя стоимостью по каждой позиции в заказе 27749.87 у.е. и средняя цена на товар в заказе 33363.20 у.е. Если учесть показатели по среднему количеству товаров в заказе и среднее количество заказов на покупателя, то здесь уже покупается явно не мелочевка.
#
# Кластер 3:
#
# * price_per_product - средняя стоимостью по каждой позиции в заказе 141.96 у.е.
# * order_product_cnt - среднее количество товаров в заказе 13.62
# * avg_price_per_order - средняя цена на товар в заказе 1779.27 у.е.
# * avg_check - средний чек 1528.34 у.е.
# * avg_orders_cnt_per_customer - среднее количество заказов на покупателя 1.07
#
# Кластер выделяется тем, что в нем средние показатели по переменным, но среднее количество товаров в заказе довольно большое. Предположу, что здесь оптовики, которые закупают небольшими партиями.
#
# Кластер 4:
#
# * price_per_product - средняя стоимостью по каждой позиции в заказе 4162.08 у.е.
# * order_product_cnt - среднее количество товаров в заказе 1.13
# * avg_price_per_order - средняя цена на товар в заказе 4392.12 у.е.
# * avg_check - средний чек 3254.69 у.е.
# * avg_orders_cnt_per_customer - среднее количество заказов на покупателя 1.07
#
# Хорошие показатели по средней цене на товар в заказе и средний чек, хотя количество товаров в заказе и количество заказов на покупателя. В этом кластере тоже больше качественные, чем количественные покупатели.
#
# Далее, была сделана проверка статистических гипотез. Гипотезы были сформулированы следующим образом:
#
# 1. Гипотеза. Статистическая значимость различий в среднем чеке заказа между сегментами покупателей присутствует.
#
# Сформулируем нулевую и альтернативную гипотезы:
#
# H0: Статистическая значимость различий в среднем чеке заказа между сегментами покупателей отсутствует.
#
# H1: Статистическая значимость различий в среднем чеке заказа между сегментами покупателей присутствует.
#
#
# 2. Гипотеза. Статистическая значимость различий в среднем объёме продаж между сегментами отсутствует.
#
# Сформулируем нулевую и альтернативную гипотезы:
#
# H0: Статистическая значимость различий в среднем объёме продаж между сегментами отсутствует.
#
# H1: Статистическая значимость различий в среднем объёме продаж между сегментами присутствует.
#
# Гипотеза 1 при множественной проверке показала, что:
#
# При выборке по 0 и 1 кластерам:
#
# P-value = 3.34. Мы отвергли нулевую гипотезу.
#
# При выборке по 1 и 2 кластерам:
#
# P-value = 0.11. Не получилось отвергнуть нулевую гипотезу.
#
# При выборке по 2 и 3 кластерам:
#
# P-value = 0.58. Не получилось отвергнуть нулевую гипотезу.
#
# При выборке по 3 и 4 кластерам:
#
# P-value = 6.12. Мы отвергли нулевую гипотезу.
#
# При выборке по 4 и 0 кластерам:
#
# P-value = 1.73. Мы отвергли нулевую гипотезу.
#
# Из 5 раз - 3 раза была отвергнута нулевая гипотеза, 2 раза не получилось отвергнуть нулевую гипотезу.
#
# Таким образом, исходя из большенства в 1, статистическая значимость различий в среднем чеке заказа между сегментами покупателей присутствует.
#
# Гипотеза 2 при множественной проверке показала, что:
#
# При выборке по 0 и 1 кластерам:
#
# P-value = 0.094. Не получилось отвергнуть нулевую гипотезу.
#
# При выборке по 1 и 2 кластерам:
#
# P-value = P-value = 0.00011. Мы отвергли нулевую гипотезу.
#
# При выборке по 2 и 3 кластерам:
#
# P-value = 5.10. Мы отвергли нулевую гипотезу.
#
# При выборке по 3 и 4 кластерам:
#
# P-value = 4.41. Мы отвергли нулевую гипотезу.
#
# При выборке по 4 и 0 кластерам:
#
# P-value = 8.08. Мы отвергли нулевую гипотезу.
#
# Таким образом, статистическая значимость различий в среднем объёме продаж между сегментами присутствует.
#
# При множественной проверки было выявлено:
#
# Средний чек:
#
# P-value = 0.0000, Статистика = 2031.3646
#
# Мы отвергли нулевую гипотезу. Это говорит о том, что существуют значимые различия между кластерами для среднего чека.
#
# Выручка:
#
# P-value = 0.0000, Статистика = 1348.6181
#
# Мы отвергли нулевую гипотезу. Это говорит о том, что существуют значимые различия между кластерами для среднем объёме заказов.
#
# Тесты Крускала-Уоллиса показали различия между кластерами для обеих метрик. Таким образом, это подтверждает что кластеры имеют статистически значимые различия в среднем чеке и среднем объеме заказов.
#
# _Далее, по каждому кластеру были выведены предпочтительные категории и сезонность. Из чего, было выявлено следующее:_
#
# Здесь мы наблюдаем следующее:
#
# Кластер 0 по категориям товаров:
#
# * Категория Инструменты лидирует по среднему чеку 751.53 у.е. и среднему объёму продаж 988.81 у.е.
# * Категория Товары для сада идет за предыдущей категорией по среднему чеку 661.43 у.е., но вот объём продаж тут небольшой по сравнениюсо всеми категориями - 388.93 у.е
# * Категория Товары для дома показывают третье место по среднему чеку 545.52 у.е. и среднему объёму продаж в 593.13 у.е.
# * Категория Товары для кухни представляет собой самый маленький средний чек по сравнению с другими, но объёму продаж тут довольно хороший - 757.09 у.е.
#
#
# по сезонности:
#
# * осень	даёт средний чек 686.25 у.е. и 565.75 у.е. в среднем объёме продаж.
# * весна, лето и зима по среднему чеку почти в одном диапазоне: 542.96 у.е., 532.18 у.е. и 520.56 у.е. соответственно. По объёму продаж, по всем сезонам лидирует зима - 670.99 у.е.
#
# Тут можно обратить внимание на Категорию Инструменты и на осенний период.
#
# Кластер 1 по категориям товаров:
#
# * Категория Инструменты лидирует по среднему чеку 866.22 у.е. и среднему объёму продаж 1189.53 у.е.
# * Категории Товары для сада, Категория Товары для дома и Товары для кухни идут следом по среднему чеку практически в одном диапазоне: 657.71 у.е., 633.62 у.е. и 604.92 у.е. соответственно. По среднему объёму продаж 501.97 у.е., 665.15 у.е. и 574.43 у.е. соответственно.
#
# по сезонности:
#
# * осень - лидирует по среднему чеку 665.45 у.е. и средний объём продаж 586.81 у.е.
# * остальные сезоны не сильно отстают по среднему чеку - на втором месте зима, далее лето и весна. По объему продаж в этом кластере лидирует зима - 640.36 у.е.
#
# Тут можно также обратить внимание на Категорию Инструменты и осенний и зимний периоды.
#
# Кластер 2 по категориям товаров:
#
# * Здесь лидирует категория Товары для сада со средним чеком 2724.00 у.е., но по объёму продаж лидирует категория Товары для дома  34221.33 у.е. со средним чеком 1284.00 у.е. Замыкает лидерство сегмент Товары для кухни.
# * Категория Инструменты в этот кластер не попала.
#
# по сезонности:
#
# * Осень и зима тут в лидерах совсем с небольшим отрывом друг от друга по среднему чеку: 1586.86 у.е. и 1426.00 у.е. соответственно.
# * Лето здесь совсем с небольшими показателями по среднему чеку 148.00 у.е., зато лидирует по объёму продаж - 49432.00 у.е., самый большой показатель в этом кластере по сезонности.
# * Весна в данном кластере не присутствует.
#
# Тут можно обратить внимание на Категорию Товары для сада и Товары для дома. Осений и зимний периоды.
# Также, можно заострить внимание на летний период с его объёмом продаж в 49432.00 у.е.
#
# Кластер 3 по категориям товаров:
#
# * Категория Товары для сада здесь в лидерах по среднему чеку - 1813.08 у.е., а вот по объёму продаж Товары для кухни - 169.50
# * Категория Инструменты в этот кластер также не попала.
#
# по сезонности:
#
# * лето в лидерах по среднему чеку - 2228.87 у.е., по объёму продаж - осень и лето.
#
# Тут можно обратить внимание также на Категорию Товары для сада и Товары для кухни. Осенний и летний периоды.
#
# Кластер 4 по категориям товаров:
#
# * Категория Товары для сада как по чеку, так и по объёму продаж безусловный лидер - 3898.47 у.е. и 4098.64 у.е. соответственно.
#
# по сезонности:
#
# * весна в лидерах по среднему чеку - 3653.79 у.е., по выручке лидирует лето - 4743.24 у.е.
#
# Тут можно обратить внимание на Категорию Товары для сада. Весенний и летний периоды.
#
# _Если смотреть выручку в динамике по категориям товара посезонно для каждого кластера, то тут можно видеть следующую картину:_
#
# Кластер 0:
#
# Лидирует по выручке Категория Инструменты по всем сезонам. Весной этот показатель больше всего - превышает показатель в 1250 у.е. На втором месте зима с приблизительным показателем в 1150 у.е. Далее осень и лето. Так как в этом кластере основной драйвер роста Инструменты, можно делать несколько рассылок в месяц для еще большего вовлечения покупателей и увеличения продаж (вывода на новый уровень). Можно делать индивидуальные предложения для разного типа клиентов в зависимости от того, насколько часто и в каких объёмах они покупают.
#
# Кластер 1:
#
# Также лидирует Категория Инструменты по всем сезонам. Больше всего этот показатель приходится на лето - более 1600 у.е. На втором месте по всем сезонам идут Товары для дома. На третьем месте Товары для кухни. Эта категория имеет почти такие же значения, как и Товары для дома. Очень близко по показателям выручки. Товары для сада расположились на 4 месте и видно, что осенью немного обогнали Товары для сада по показателю. В этом кластере также можно порекомендовать доп. рассылки на категорию Инструменты, особенно в к летнему сезону. Также, можно делать точечные рассылки по товарам для сада, чтобы поднять категорию выше, так как выручка идет стабильно по всем сезонам. Таким образом, можно поднять и средний чек и объём продаж.
#
# Кластер 3:
#
# Здесь в лидерах Товары для кухни в осенний период. Весной эта категория показывает почти равную динамику с категориями Товары для дома и Товары для сада. Категория Инструменты в этом кластере не представлена, видимо, продаж не было совсем. Здесь, если делать рассылки с промо или скидками, то можно предлагать дополнительно товары по акциям или с подарками категорию с инструментами. Таким образом, есть шанс, что эта категория начнет присутствовать в этом кластере и далее с возможностью увеличения продаж. Проводить акции и рассылки можно делать в осенний период времени, например, вместе с товарами для сада.
#
# Кластер 4:
#
# Здесь довольно уверенно показывает себя в летний период Категория Товары для кухни - более 7000 у.е. Также, здесь наблюдается хорошая динамика по выручке у категорий Товары для дома и сада. У Категории Инструментов тоже хорошие показатели, но здесь они на последних местах по выручке. Так как товары для кухни очень популярны в этом кластере особенно в летнее время, можно смело попробовать рассылки для большего увеличения продаж с этом кластере. особенно можно попробовать активности в другие периоды времени. Это может подтянуть показатели до летних объёмов.
#
# Кластер 2:
#
# На этот кластер можно обратить отдельное внимание, так как в нем представлены всего 3 категории, исключая Инструменты. В летний сезон можно наблюдать очень хорошую динамику у категории Товары для дома. Другие категории по этому показателю в этом сезоне не представлены. Весна для этого кластера вообще является провальным сезоном - показатели отсутствуют. В зимний период можно наблюдать динамику по товарам для сада и дома. Осенью, по категориям представлены только Товары для сада с показателем около 25000 у.е. и совсем небольшим показателем идут Товары для кухни - 5000 у.е. ! Здесь очень интересен период для рассылок в зимний период в категории товаров для сада. Видимо, в этом кластере покупатели часто покупают в зимний период, подготавливаясь к весенне-летнему периоду. Также, к этой категории можно попробовать присоединить предложения в рассылках по инструментам, чтобы вызвать интерес покупателей к этому сегменту товаров для подготовки к весенне-летнему периоду.
#
#
# **Также, магазину можно дать более подробные рекомендации по кластерам:**
#
# * По Кластеру 0 акцентировать внимание Категорию Инструменты, чтобы развивать дальше более высокие показатели и дальше. Для этого можно предлагать разные промо-акции на категорию и заодно подтянуть показатели по летнему и осеннему периодам. Для развития показателей Категории Товары для сада по всем сезонам, покупателям можно предоставлять скидки и проводить маркетинговые мероприятия для увеличения объёмов продаж. Также, для увеличения показателей по сезонности можно делать рассылки с выгодными предложениями.
#
# * По Кластеру 1 можно сделать акцент Категорию Инструменты. Поработать с ассортиментом и его сортировкой, предлагая позиции дороже среднего чека, чтобы еще больше увеличить средние показатели. Чтобы подтянуть категории Товары для сада, Товары для дома и Товары для кухни под показатели категории Инструменты, а возможно вывести их в лидеры, можно проводить акции и спецпредложения. Также, можно сконцентрироваться на периоды весна и лето, чтобы подтянуть показатели по объёму продаж.
#
# * По Кластеру 2 для увеличения продаж можно обратить внимание на категорию Товары для кухни и дать выгодные предложения по ней. Можно провести промо с подарками в зимний и летний периоды. В качестве подарков, можно предлагать разные товары из недорогой кухонной утвари в качестве заботы о покупателях при покупке средних и дорогих товаров. Так как Категория Инструменты в этот кластер не попала, можно сделать акцент на подарках из этой категории, чтобы привлечь к ней внимание. Такие акции можно усиленно проводить весной, чтобы акцентировать внимание на весенне-летнем периоде в качестве начала сезона для Категории Инструменты.
#
# * По Кластеру 3 можно провести такие же акции на Категорию Инструменты как и во втором кластере по той же причине. Проводить акции можно в любой сезон.
#
# * По Кластеру 4 по Категориям товаров для дома и кухни (особенно в летний период) можно сделать совместную акцию, давать скидки на товары и дарить различные подарки. Также, проводить такие маркетинговые акции можно осенью и зимой, для еще большего увеличения продаж в эти периоды времени.

# %% [markdown]
# ## Презентация

# %% [markdown]
# **Ссылка на презентацию:**
#
# https://cloud.mail.ru/public/YbgP/5JQVpTTdx
