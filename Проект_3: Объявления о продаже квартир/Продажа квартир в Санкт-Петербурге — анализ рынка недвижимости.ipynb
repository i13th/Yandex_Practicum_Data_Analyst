# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекс.Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктов за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые — получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# Цель исследования - установить параметры, влияющие на рыночную стоимость объектов недвижимости.
# Исходные данные - данные сервиса «Яндекс.Недвижимость»(архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет).
# Интресующие вопрос:
# Сколько времени занимает продажа квартиры. Когда продажу можно назвать быстрой / долгой.
# Какие факторы больше всего влияют на стоимость квартиры.
# Какая средняя стоимость квартиры в 10 населённых пунктов с наибольшим числом объявлений.
# Какие факторы влияют на стоимость квартиры в центре Санкт-Петербурга.
# Насколько они отличаются от данных в целом по городу.

# %% [markdown]
# # Данное исследование разделим на несколько частей.
# Часть 1. Изучение общей информации.
# * Откроем файл с данными и изучим общую информацию.
# * Просмотрим первые и последние 5 строк таблицы с данными.
# * Познакомимся с данными поближе и просмотрим числовые значения методом describe().
# * А так же ознакомимся с типом данных и общей оиформацией по таблице.
# * Вывод.
#
# Часть 2. Предобработка данных.
# * Приведём формат вывода даты и времени по столбцу "first_day_exposition" к удобному для форматирования и обработки.
# * Произведём подсчёт квартир с нулевым обозначением количества комнат в столбце "rooms".
# * Проверим значения колонки "ceiling_height".
# * Выполним проверку столбца "floors_total" на отсутствующие значения.
# * Проверм данные по столбцу "living_area".
# * Исследуем столбец "kitchen_area" на предмет корректных значений.
# * Исследуем колонку "balcony" на предмет отсутствующих значений.
# * Исследуем столбец "locality_name" на предмет уникальных значений.
# * Просмотрим значения в столбце "airports_nearest".
# * Приведём наименование столбца "cityCenters_nearest" в однотипный формат.
# * Проверим значения столбца "parks_around" на предмет уникальности.
# * Исследуем данные в колонке "parks_nearest".
# * Исследуем столбец "ponds_around" на предмет отсутствующих и недостоверных данных.
# * Проведём исследование данных в колонке "ponds_nearest".
# * Исследуем данные в колонке "days_exposition".
# * Проведём исследование значений столбца "is_apartment".
# * Вывод.
#
# Часть 3. Посчитаем дополнительные данные и добавим их в таблицу.
# * Посчитаем и добавим в таблицу цену квадратного метра.
#     * Вывод.
# * Посчитаем и добавим в таблицу день недели, месяц и год публикации объявления.
#     * Вывод.
# * Посчитаем и добавим в таблицу этаж квартиры; варианты — первый, последний, другой.
#     * Вывод.
# * Посчитаем и добавим в таблицу соотношение жилой и общей площади, а также отношение площади кухни к общей.
#     * Вывод.
# * Вывод.
#
# Часть 4. Проведём исследовательский анализ данных.
# * Изучим следующие параметры: площадь, цена, число комнат, высота потолков. Построим гистограммы для каждого параметра.
#     * Площадь
#     * Цена
#     * Число комнат
#     * Высота потолков
#     * Вывод
# * Изучим время продажи квартиры. Построим гистограмму. Посчитаем среднее и медиану.
#     * Вывод
# * Изучим, зависит ли цена от площади, числа комнат, удалённости от центра.
#     * Вывод
# * Изучим зависимость цены от того, на каком этаже расположена квартира: первом, последнем или другом.
#     * Вывод
# * Также изучим зависимость цены от даты размещения: дня недели, месяца и года.
#     * Вывод
# * Выберем 10 населённых пунктов с наибольшим числом объявлений.
#     * Вывод
# * Посчитайте среднюю цену квадратного метра в этих населённых пунктах.
#     * Вывод
# * Выделим среди них населённые пункты с самой высокой и низкой стоимостью жилья.
#     * Вывод
# * Изучим предложения квартир: Выделим квартиры в Санкт-Петербурге ('locality_name'). Выясним, какая область входит в центр.
#     * Вывод
# * Посчитаем среднюю цену для каждого километра.
# * Выделим сегмент квартир в центре и проанализируем эту территорию.
#     * Вывод.
# * Выделим факторы, которые влияют на стоимость квартиры.
#     * Вывод.
#
# Часть 5. Обший вывод по проведённому исследованию.
# * Общий вывод.

# %% [markdown]
# ### Откройте файл с данными и изучите общую информацию.

# %% [markdown]
# # Импортируем библиотеки.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
pth1 = '/folder_1/data.csv'
pth2 = '/folder_2/data.csv'

if os.path.exists(pth1):
     query_1 = pd.read_csv(pth1)
elif os.path.exists(pth2):
     query_1 = pd.read_csv(pth2)
else:
     print('Something is wrong')
# Out:
# Something is wrong

# %% [markdown]
# # Установим опцию по выводу всех колонок датасета.

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# Импортируем данные в датасет.

# %%
try:
    data = pd.read_csv('/datasets/real_estate_data.csv', sep='\t') 
except:
    data = pd.read_csv('real_estate_data.csv', sep='\t')

# %% [markdown]
# Просмотрим первые и последние 5 строк таблицы с данными.

# %%
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 0            2.70          16.0         51.0      8          NaN   False
# 1             NaN          11.0         18.6      1          NaN   False
# 2             NaN           5.0         34.3      4          NaN   False
# 3             NaN          14.0          NaN      9          NaN   False
# 4            3.03          14.0         32.0     13          NaN   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %%
data.tail()
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 23694             9   9700000.0      133.81  2017-03-21T00:00:00      3
# 23695            14   3100000.0       59.00  2018-01-15T00:00:00      3
# 23696            18   2500000.0       56.70  2018-02-11T00:00:00      2
# 23697            13  11475000.0       76.75  2017-03-28T00:00:00      2
# 23698             4   1350000.0       32.30  2017-07-21T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 23694             3.7           5.0         73.3      3          NaN   False
# 23695             NaN           5.0         38.0      4          NaN   False
# 23696             NaN           3.0         29.7      1          NaN   False
# 23697             3.0          17.0          NaN     12          NaN   False
# 23698             2.5           5.0         12.3      1          NaN   False
#
#        open_plan  kitchen_area  balcony        locality_name  \
# ...

# %% [markdown]
# Просмотрим числовые значения методом describe().

# %%
data.describe().astype('int')
# Out:
#        total_images  last_price  total_area  rooms  ceiling_height  \
# count         23699       23699       23699  23699           14504
# mean              9     6541548          60      2               2
# std               5    10887013          35      1               1
# min               0       12190          12      0               1
# 25%               6     3400000          40      1               2
# 50%               9     4650000          52      2               2
# 75%              14     6800000          69      3               2
# max              50   763000000         900     19             100
#
#        floors_total  living_area  floor  kitchen_area  balcony  \
# count         23613        21796  23699         21421    12180
# mean             10           34      5            10        1
# std               6           22      4             5        1
# min               1            2      1             1        0
# ...

# %% [markdown]
# Смотрим количество дубликатов.

# %%
print('\nЧисло дубликатов:', data.duplicated().sum())
# Out:
# Число дубликатов: 0

# %% [markdown]
# Просмотрим числовые значения методом describe().

# %%
data.describe().astype('int')
# Out:
#        total_images  last_price  total_area  rooms  ceiling_height  \
# count         23699       23699       23699  23699           14504
# mean              9     6541548          60      2               2
# std               5    10887013          35      1               1
# min               0       12190          12      0               1
# 25%               6     3400000          40      1               2
# 50%               9     4650000          52      2               2
# 75%              14     6800000          69      3               2
# max              50   763000000         900     19             100
#
#        floors_total  living_area  floor  kitchen_area  balcony  \
# count         23613        21796  23699         21421    12180
# mean             10           34      5            10        1
# std               6           22      4             5        1
# min               1            2      1             1        0
# ...

# %% [markdown]
# Изучаем общую информацию о полученных данных.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# Смотрим пропущенные значения.

# %%
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# cityCenters_nearest      5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %% [markdown]
# Строим гистограммы.

# %%
data.hist(figsize=(15, 20));

# %% [markdown]
# # Вывод

# %% [markdown]
# Судя по данным таблицы основную долю внимания придётся уделить пропущенным или отсутствующим значениям.
# Также, в таблице есть некоторые данные, которые сильно выбиваются из общей массы по значениям.
# Необходимо познакомиться сними поближе.

# %% [markdown]
# Буду искать в данных: выбросы, пропуски,  выявлять нестандартные значения и если нужно, буду их заменять или убирать.
# Также, переводить нужные столбцы в нужные форматы. Если будут некорректные форматы в названиях стобцов, буду приводить их в соответствие, например со змеиным форматом.

# %% [markdown]
# ### Предобработка данных

# %% [markdown]
# # Приведём формат вывода даты и времени по столбцу first_day_exposition к удобному для форматирования и обработки.

# %%
data['first_day_exposition'] = pd.to_datetime(data['first_day_exposition'], format='%Y-%m-%dT%H:%M:%S')

# %%
data.tail(2)
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 23697            13  11475000.0       76.75           2017-03-28      2
# 23698             4   1350000.0       32.30           2017-07-21      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 23697             3.0          17.0          NaN     12          NaN   False
# 23698             2.5           5.0         12.3      1          NaN   False
#
#        open_plan  kitchen_area  balcony        locality_name  \
# 23697      False          23.3      2.0      Санкт-Петербург
# 23698      False           9.0      NaN  поселок Новый Учхоз
#
#        airports_nearest  cityCenters_nearest  parks_around3000  parks_nearest  \
# 23697           39140.0              10364.0               2.0          173.0
# 23698               NaN                  NaN               NaN            NaN
#
#        ponds_around3000  ponds_nearest  days_exposition
# ...

# %% [markdown]
# # Произведём подсчёт квартир с нулевым обозначением количества комнат в столбце rooms.

# %%
data.query('rooms == 0')['rooms'].count()
# Out:
# 197

# %% [markdown]
# Проверим по таблице, к каким данным относятся 0 комнат.

# %%
data.query('rooms == 0').head(10)
# Out:
#      total_images  last_price  total_area first_day_exposition  rooms  \
# 144             1   2450000.0       27.00           2017-03-30      0
# 349             4   2320000.0       25.00           2017-09-27      0
# 440             8   2480000.0       27.11           2018-03-12      0
# 508             0   3375000.0       34.40           2017-03-28      0
# 608             2   1850000.0       25.00           2019-02-20      0
# 697            12   2500000.0       24.10           2017-12-01      0
# 716             5   1500000.0       17.00           2017-06-07      0
# 780             9   2600000.0       26.10           2018-02-20      0
# 839            14   1900000.0       35.00           2017-04-14      0
# 946             5   2200000.0       23.00           2016-09-27      0
#
#      ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 144             NaN          24.0        15.50      2          NaN    True
# ...

# %% [markdown]
# Предполагаю, что с такой площадью в целом и отсутствием площади кухни - 0 комнат может значить, что это квартиры-студии.
# В таком случае, здесь ошибок в данных нет и мы можем оставить все как есть.

# %% [markdown]
# # Проверяем значения столбца ceiling_height.

# %% [markdown]
# Сначала, вычисляем среднее значение по высоте потолков, ограничивая выборку предельно допустимыми значениями.

# %%
data.query('ceiling_height > 2 and ceiling_height < 8.3')['ceiling_height'].mean()
# Out:
# 2.728440956858407

# %% [markdown]
# Надо приравнять невошедшие значения к среднему, так как нет потолков выше 8.3 метра и ниже 2 метра.

# %%
data.loc[data['ceiling_height'] < 2, 'ceiling_height'] = 2.72

# %%
data.loc[data['ceiling_height'] > 8.3, 'ceiling_height'] = 2.72

# %% [markdown]
# Проверяем результат.

# %%
data.query('ceiling_height < 2 and ceiling_height > 8.3')['ceiling_height'].sum()
# Out:
# 0.0

# %% [markdown]
# Теперь можно заполнить отсутствующие значения средней величиной.

# %%
data['ceiling_height'] = data['ceiling_height'].fillna(2.72)

# %% [markdown]
# Смотрим результат.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  datetime64[ns]
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        23699 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
# ...

# %% [markdown]
# # Делаем проверку столбца floors_total на отсутствующие значения.

# %%
data.loc[data['floors_total'].isna()].head(10)
# Out:
#       total_images  last_price  total_area first_day_exposition  rooms  \
# 186             12  11640000.0       65.20           2018-10-02      2
# 237              4   2438033.0       28.10           2016-11-23      1
# 457              4   9788348.0       70.80           2015-08-01      2
# 671              4   6051191.0       93.60           2017-04-06      3
# 1757             5   3600000.0       39.00           2017-04-22      1
# 1930             1   9750000.0       66.77           2016-05-13      2
# 2392             7   5395770.0       53.00           2017-06-29      2
# 2846             4   2325000.0       27.80           2016-09-21      1
# 2952            10   6500000.0       54.30           2019-04-23      1
# 3031             9   6400000.0       56.70           2018-03-27      2
#
#       ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 186             2.72           NaN        30.80      4          NaN   False
# ...

# %%
data['floors_total'].isna().sum()
# Out:
# 86

# %% [markdown]
# В этой выборке видно, что нет возможности по остальным параметрам однозначно сказать об этажности дома.Так что предлагаю, пока, оставить данные без изменений.

# %% [markdown]
# # Проверим данные по столбу living_area.

# %%
data['living_area'].agg(['min','max','mean','median'])
# Out:
# min         2.000000
# max       409.700000
# mean       34.457852
# median     30.000000
# Name: living_area, dtype: float64

# %% [markdown]
# Выводим данные и визуализируем, для каких квартир указаны такие значения для жилой площади.

# %%
data.query('living_area < 5')
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 3242              7   4440000.0        41.0           2017-07-02      1
# 13915            20   6350000.0        52.0           2018-02-06      2
# 21758             0   2330000.0        23.0           2018-01-01      0
# 23574            14  64990000.0       139.0           2015-11-24      3
#
#        ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 3242             2.72          17.0          3.0     17          NaN   False
# 13915            3.00           6.0          2.0      2          NaN   False
# 21758            2.72          24.0          2.0     22          NaN    True
# 23574            3.00           8.0          3.0      8          NaN   False
#
#        open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# 3242       False          11.0      NaN  Санкт-Петербург           19272.0
# ...

# %% [markdown]
# Точно определить какое значение нужно указать, мы не можем.
# Но ясно, что остальной массив данных следует сохранить, по этой причине заменяем неправдоподобные значение на None.

# %%
data.loc[data['living_area'] < 5, 'living_area'] = None

# %%
data['living_area'].isna().sum()
# Out:
# 1907

# %% [markdown]
# Применяем результат None к выбранным строкам.

# %%
data.query('living_area < 5')
# Out:
# Empty DataFrame
# Columns: [total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, cityCenters_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition]
# Index: []

# %% [markdown]
# Неправдоподобные данные по площади жилого помещения устранены.
# К сожалению таких пропущенных значений в столбце много.
# Но удалять строки с другими данными вредно для статистики, оставим строки с неизвестными площадями как есть.

# %% [markdown]
# # Далее нужно исследовать столбец kitchen_area на предмет корректных значений.

# %% [markdown]
# Согласно официальным данным, кухня не может быть меньше 5м2. Нужно выполнить выборку по этому значению.

# %%
data.query('kitchen_area < 5')
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 76               12   2800000.0        55.1           2016-05-14      3
# 298               9   2650000.0        42.8           2017-04-25      2
# 422               8   1700000.0        55.2           2018-03-24      3
# 906              15   2600000.0        27.0           2017-07-10      1
# 1327              6   2650000.0        46.2           2016-12-01      2
# ...             ...         ...         ...                  ...    ...
# 22839            14   3350000.0        27.0           2018-11-03      1
# 22849             6   2380000.0        25.0           2016-03-22      1
# 23110             1   2900000.0        34.0           2018-02-01      2
# 23498             7   1600000.0        54.0           2016-12-26      2
# 23678            10   3500000.0        43.0           2016-05-19      2
#
#        ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# ...

# %%
data['kitchen_area'].isna().sum()
# Out:
# 2278

# %% [markdown]
# Заполним пропуски значениями 0, учтя, что отсутствие данных по площади кухни связано с квартирами, там где комнаты объеденеы с кухней и площадь комнаты уже учитывает площадь кухни.

# %%
data['kitchen_area'] = data['kitchen_area'].fillna(0)

# %% [markdown]
# Вычисляем среднее значение для кухни, отсортировав ненужные значения.

# %%
mean_area = data.query('kitchen_area > 5' and 'kitchen_area < 15')['kitchen_area'].mean()

# %% [markdown]
# Заменяем ошибочные данные среднем значением нашей выборки.

# %%
data.loc[data['kitchen_area'] < 5, 'kitchen_area'] = mean_area

# %% [markdown]
# Проверка результата.

# %%
data.query('kitchen_area < 5')
# Out:
# Empty DataFrame
# Columns: [total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, cityCenters_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition]
# Index: []

# %% [markdown]
# # Исследуем колонку balcony на предмет отсутствующих значений.

# %%
data['balcony'].isna().sum()
# Out:
# 11519

# %% [markdown]
# Тут можно видеть, что пропусков около 50% от всех данных.
# Такое количество пропусков не может быть случайным.
# Нужно ознакомиться со смежными данными колонки.

# %%
data.loc[data['balcony'].isna()]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20  13000000.0      108.00           2019-03-07      3
# 4                 2  10000000.0      100.00           2018-06-19      2
# 5                10   2890000.0       30.40           2018-09-10      1
# 8                20   2900000.0       33.16           2018-05-23      1
# 10                5   5050000.0       39.60           2017-11-16      1
# ...             ...         ...         ...                  ...    ...
# 23692             2   1350000.0       30.00           2017-07-07      1
# 23694             9   9700000.0      133.81           2017-03-21      3
# 23695            14   3100000.0       59.00           2018-01-15      3
# 23696            18   2500000.0       56.70           2018-02-11      2
# 23698             4   1350000.0       32.30           2017-07-21      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# ...

# %% [markdown]
# Судя по всему, предполагаю, что те данные которые имеют пропуски означают отсутствие балкона.
# Поэтому можно указать 0 вместо NaN.

# %%
data['balcony'] = data['balcony'].fillna(0).astype('int')

# %% [markdown]
# Проверка результата удаления значений NaN.

# %%
data['balcony'].isna().sum()
# Out:
# 0

# %% [markdown]
# # Исследуем столбец locality_name на предмет уникальных значений.

# %%
data['locality_name'].unique()
# Out:
# array(['Санкт-Петербург', 'посёлок Шушары', 'городской посёлок Янино-1',
#        'посёлок Парголово', 'посёлок Мурино', 'Ломоносов', 'Сертолово',
#        'Петергоф', 'Пушкин', 'деревня Кудрово', 'Коммунар', 'Колпино',
#        'поселок городского типа Красный Бор', 'Гатчина', 'поселок Мурино',
#        'деревня Фёдоровское', 'Выборг', 'Кронштадт', 'Кировск',
#        'деревня Новое Девяткино', 'посёлок Металлострой',
#        'посёлок городского типа Лебяжье',
#        'посёлок городского типа Сиверский', 'поселок Молодцово',
#        'поселок городского типа Кузьмоловский',
#        'садовое товарищество Новая Ропша', 'Павловск',
#        'деревня Пикколово', 'Всеволожск', 'Волхов', 'Кингисепп',
#        'Приозерск', 'Сестрорецк', 'деревня Куттузи', 'посёлок Аннино',
#        'поселок городского типа Ефимовский', 'посёлок Плодовое',
#        'деревня Заклинье', 'поселок Торковичи', 'поселок Первомайское',
# ...

# %%
data['locality_name'].value_counts().tail(20)
# Out:
# посёлок Мыза-Ивановка                1
# деревня Большое Рейзино              1
# деревня Пикколово                    1
# поселок Жилпосёлок                   1
# поселок Усть-Луга                    1
# деревня Каськово                     1
# деревня Пчева                        1
# деревня Трубников Бор                1
# поселок Перово                       1
# деревня Пижма                        1
# деревня Кисельня                     1
# поселок Семиозерье                   1
# деревня Нижняя                       1
# садовое товарищество Приладожский    1
# посёлок Форт Красная Горка           1
# поселок Пчевжа                       1
# поселок Гаврилово                    1
# деревня Раздолье                     1
# деревня Лупполово                    1
# село Никольское                      1
# Name: locality_name, dtype: int64

# %% [markdown]
# Приводим значения к нижнему регистру для избавления от дубликатов.

# %%
data['locality_name'] = data['locality_name'].str.lower()

# %%
data['locality_name'].duplicated().sum()
# Out:
# 23334

# %% [markdown]
# Нужно выполнить замену в написании. Вместо, поселок заменим на посёлок.

# %%
data['locality_name'] = data['locality_name'].str.replace('поселок', 'посёлок')

# %% [markdown]
# Проверим результат.

# %%
data['locality_name'].unique()
# Out:
# array(['санкт-петербург', 'посёлок шушары', 'городской посёлок янино-1',
#        'посёлок парголово', 'посёлок мурино', 'ломоносов', 'сертолово',
#        'петергоф', 'пушкин', 'деревня кудрово', 'коммунар', 'колпино',
#        'посёлок городского типа красный бор', 'гатчина',
#        'деревня фёдоровское', 'выборг', 'кронштадт', 'кировск',
#        'деревня новое девяткино', 'посёлок металлострой',
#        'посёлок городского типа лебяжье',
#        'посёлок городского типа сиверский', 'посёлок молодцово',
#        'посёлок городского типа кузьмоловский',
#        'садовое товарищество новая ропша', 'павловск',
#        'деревня пикколово', 'всеволожск', 'волхов', 'кингисепп',
#        'приозерск', 'сестрорецк', 'деревня куттузи', 'посёлок аннино',
#        'посёлок городского типа ефимовский', 'посёлок плодовое',
#        'деревня заклинье', 'посёлок торковичи', 'посёлок первомайское',
#        'красное село', 'посёлок понтонный', 'сясьстрой', 'деревня старая',
# ...

# %% [markdown]
# Довольно распространенная ошибка с применением буквы 'ё' и 'е' в тексте.
# Это человеческий фактор возникновения ошибки.

# %% [markdown]
# # Посмотрим значения в столбце airports_nearest.

# %% [markdown]
# Выведем значения равные 0 для оценки ошибки в выгрузке данных.

# %%
data.query('airports_nearest == 0')
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 21085             0   7000000.0        34.7           2018-09-23      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 21085             2.7           9.0         19.8      3          NaN   False
#
#        open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# 21085      False           6.0        2  санкт-петербург               0.0
#
#        cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 21085              22801.0               0.0            NaN               0.0
#
#        ponds_nearest  days_exposition
# 21085            NaN             60.0

# %% [markdown]
# Тут видно, что единственное значение, скорее всего, может быть вызвано ошибкой в выгрузке данных.
# Считаю, нужно приравнять это значение к None, так как по смежным данным не получается определить расстояние до объекта в м.

# %%
data.loc[data['airports_nearest'] == 0, 'airports_nearest'] = None

# %% [markdown]
# Проверка

# %%
data.query('airports_nearest == 0')
# Out:
# Empty DataFrame
# Columns: [total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, cityCenters_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition]
# Index: []

# %%
data['airports_nearest'].min()
# Out:
# 6450.0

# %% [markdown]
# Видно, что ближайшая квартира от аэропорта в 6,5км.

# %% [markdown]
# # Приводим столбец cityCenters_nearest в однотипный с другими названиями формат.

# %%
data.rename(columns={'cityCenters_nearest' : 'city_centers_nearest'}, inplace=True)

# %% [markdown]
# Также, я бы привел наименования столбцов parks_around3000 и ponds_around3000 к привычному формату,  по принципу cityCenters_nearest.

# %%
data.rename(columns={'parks_around3000' : 'parks_around', 'ponds_around3000' : 'ponds_around'}, inplace=True)

# %%
data.columns
# Out:
# Index(['total_images', 'last_price', 'total_area', 'first_day_exposition',
#        'rooms', 'ceiling_height', 'floors_total', 'living_area', 'floor',
#        'is_apartment', 'studio', 'open_plan', 'kitchen_area', 'balcony',
#        'locality_name', 'airports_nearest', 'city_centers_nearest',
#        'parks_around', 'parks_nearest', 'ponds_around', 'ponds_nearest',
#        'days_exposition'],
#       dtype='object')

# %% [markdown]
# Переименовываем столбцы и приводим в соответствие.

# %% [markdown]
# # Проверяем значение столбца parks_around на предмет уникальности.

# %%
data['parks_around'].unique()
# Out:
# array([ 1.,  0.,  2., nan,  3.])

# %%
data['parks_around'].isna().sum()
# Out:
# 5518

# %% [markdown]
# Тут мы видим, что отсутствующие значения могут говорить на о том, что парков вблизи 3км нет.
# Заменяем их на нулевое значение и заменяем тип данных на целочисленный.

# %%
data['parks_around'] = data['parks_around'].fillna(0).astype('int')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  datetime64[ns]
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        23699 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21792 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          23699 non-null  float64
#  13  balcony               23699 non-null  int64
# ...

# %%
data['parks_around'].agg(['min', 'max'])
# Out:
# min    0
# max    3
# Name: parks_around, dtype: int64

# %%
data.query('parks_around == 0').count()
# Out:
# total_images            15624
# last_price              15624
# total_area              15624
# first_day_exposition    15624
# rooms                   15624
# ceiling_height          15624
# floors_total            15572
# living_area             14295
# floor                   15624
# is_apartment             1828
# studio                  15624
# open_plan               15624
# kitchen_area            15624
# balcony                 15624
# locality_name           15590
# airports_nearest        10101
# city_centers_nearest    10106
# parks_around            15624
# parks_nearest               4
# ponds_around            10106
# ponds_nearest            4290
# days_exposition         13588
# dtype: int64

# %% [markdown]
# # Исследуем данные в колонке parks_nearest.

# %%
data['parks_nearest'].agg(['min', 'max', 'mean', 'median'])
# Out:
# min          1.000000
# max       3190.000000
# mean       490.804555
# median     455.000000
# Name: parks_nearest, dtype: float64

# %%
data['parks_nearest'].isna().sum()
# Out:
# 15620

# %%
mean_data_parks = data.query('parks_nearest > 3000')['parks_nearest'].mean()

# %% [markdown]
# Такие количества отсутствующих значений по приближенности парка говорят о том, что необходимо проверить наличие проблемы при выгрузке данных.
# Так как по столбцу значения заполнены по количеству парков на расстоянии 3км.
# Учитывая, что количество парков, которые находятся на болшем расстоянии чем 3км соответствует количеству пропущенных значений.
# Логично будет произвести замену отсутствующих данных на среднюю величину удаленности до парка более 3км.

# %%
data['parks_nearest'] = data['parks_nearest'].fillna(mean_data_parks)

# %% [markdown]
# # Исследуем столбец ponds_around на предмет недостоверных и отсутствующих значений.

# %%
data['ponds_around'].agg(['min', 'max', 'median'])
# Out:
# min       0.0
# max       3.0
# median    1.0
# Name: ponds_around, dtype: float64

# %%
data['ponds_around'].isna().sum()
# Out:
# 5518

# %% [markdown]
# Нужно выполнить замену отсутствующих значений на 0. Скоре всего данные отсутствуют, потому что на расстоянии 3км водоемов нет.

# %% [markdown]
# Также, изменим тип данных на целочисленный.

# %%
data['ponds_around'] = data['ponds_around'].fillna(0).astype('int')

# %% [markdown]
# # Исследуем столбец ponds_nearest.

# %%
data['ponds_nearest'].agg(['min', 'max', 'median'])
# Out:
# min         13.0
# max       1344.0
# median     502.0
# Name: ponds_nearest, dtype: float64

# %%
data['ponds_nearest'].isna().sum()
# Out:
# 14589

# %% [markdown]
# Больше половины данных не имеют значений, это означает, что водоёмов по близости 3км нет и такие данные заполнять какими-либо значениями не логично.

# %% [markdown]
# # Исследуем данные в столбце days_exposition.

# %%
data['days_exposition'].agg(['min', 'max', 'median'])
# Out:
# min          1.0
# max       1580.0
# median      95.0
# Name: days_exposition, dtype: float64

# %%
data['days_exposition'].isna().sum()
# Out:
# 3181

# %%
data.query('days_exposition == "NaN"')
# Out:
# Empty DataFrame
# Columns: [total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, city_centers_nearest, parks_around, parks_nearest, ponds_around, ponds_nearest, days_exposition]
# Index: []

# %% [markdown]
# Из приведённых выше данных можно сделать вывод, что объявления были размещены, но пропущенные значения в столбце days_exposition означают, что до сих пор объявление актульно и не снято с публикации.

# %% [markdown]
# # Исследуем данные в столбце is_apartment.

# %%
data['is_apartment'].unique()
# Out:
# array([nan, False, True], dtype=object)

# %% [markdown]
# Выведем данные для ознакомеления.

# %%
data.loc[data['is_apartment'].isna()]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20  13000000.0      108.00           2019-03-07      3
# 1                 7   3350000.0       40.40           2018-12-04      1
# 2                10   5196000.0       56.00           2015-08-20      2
# 3                 0  64900000.0      159.00           2015-07-24      3
# 4                 2  10000000.0      100.00           2018-06-19      2
# ...             ...         ...         ...                  ...    ...
# 23694             9   9700000.0      133.81           2017-03-21      3
# 23695            14   3100000.0       59.00           2018-01-15      3
# 23696            18   2500000.0       56.70           2018-02-11      2
# 23697            13  11475000.0       76.75           2017-03-28      2
# 23698             4   1350000.0       32.30           2017-07-21      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# ...

# %%
data.query('is_apartment != True or is_apartment != False')['is_apartment'].count()
# Out:
# 2775

# %% [markdown]
# Ввиду того, что пропущенные значения скорей всего означают, что аппартаменты не входят в предложение по продаже квартир, выполним замену неизвестных данных на значение False и приведём тип данных в bool.

# %%
data['is_apartment'] = data['is_apartment'].fillna(False)

# %% [markdown]
# Проверим результат.

# %%
data['is_apartment'].unique()
# Out:
# array([False,  True])

# %% [markdown]
# Выведем таблицу для ознакомления с данными после выполнения изменений.

# %%
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0           2019-03-07      3
# 1             7   3350000.0        40.4           2018-12-04      1
# 2            10   5196000.0        56.0           2015-08-20      2
# 3             0  64900000.0       159.0           2015-07-24      3
# 4             2  10000000.0       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 0            2.70          16.0         51.0      8         False   False
# 1            2.72          11.0         18.6      1         False   False
# 2            2.72           5.0         34.3      4         False   False
# 3            2.72          14.0          NaN      9         False   False
# 4            3.03          14.0         32.0     13         False   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %% [markdown]
# # Вывод.

# %% [markdown]
# По результату проведённой обработки данных можно сказать, что довольно большая часть данных которая может влиять на итоговую статистику, а так же на решение о прибретении квартир, потеряна при выгрузке таблицы либо отсутствует. Об этом обязательно необходимо сообщить ответственным сотрудникам по выгрузке и сбору данных.

# %% [markdown]
# ### Посчитайте и добавьте в таблицу новые столбцы

# %%
low_percentele = 0.01
hihg_percentele = 0.99

last_price_low = data['last_price'].quantile(low_percentele)
last_price_high = data['last_price'].quantile(hihg_percentele)

print(f'Нижняя граница last_price {last_price_low}')
print(f'Верхнее граница last_price {last_price_high}')

print(
    'Процент отброшенных значений = ',
    round(
        100 - len(data.query('@last_price_low <= last_price <= @last_price_high'))
        / len(data['last_price']) * 100,
        2
    ),
    '%'
)
# Out:
# Нижняя граница last_price 1000000.0
# Верхнее граница last_price 36000000.0
# Процент отброшенных значений =  1.95 %

# %% [markdown]
# # Считаем цену квадратного метра.

# %%
data['price_per_square_meter'] = data['last_price'] / data['total_area']

# %% [markdown]
# Добавим столбец price_per_square_meter и чтобы удобно было смотреть, приведем к типу int.

# %%
data['price_per_square_meter'] = data['price_per_square_meter'].astype('int')

# %% [markdown]
# Проверям.

# %%
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0           2019-03-07      3
# 1             7   3350000.0        40.4           2018-12-04      1
# 2            10   5196000.0        56.0           2015-08-20      2
# 3             0  64900000.0       159.0           2015-07-24      3
# 4             2  10000000.0       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 0            2.70          16.0         51.0      8         False   False
# 1            2.72          11.0         18.6      1         False   False
# 2            2.72           5.0         34.3      4         False   False
# 3            2.72          14.0          NaN      9         False   False
# 4            3.03          14.0         32.0     13         False   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %%
data['price_per_square_meter'].mean().round(1)
# Out:
# 99421.2

# %% [markdown]
# # Вывод.

# %% [markdown]
# При довольно сильном разбросе цен предложений квартир,средняя цена за м2 составляет 100 тыс.руб.

# %% [markdown]
# # Посчитаем и добавим в таблицу день недели, месяц и год публикации объявления.

# %% [markdown]
# Новый столбец назовём day_of_week_exposition.

# %% [markdown]
# Создаем столбец дня недели.

# %%
data['day_of_week_exposition'] = data['first_day_exposition'].dt.weekday

# %% [markdown]
# Создаем столбец месяца.

# %%
data['month_exposition'] = data['first_day_exposition'].dt.month

# %% [markdown]
# И создаем столбец года.

# %%
data['years_exposition'] = data['first_day_exposition'].dt.year

# %% [markdown]
# Проверям.

# %%
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0           2019-03-07      3
# 1             7   3350000.0        40.4           2018-12-04      1
# 2            10   5196000.0        56.0           2015-08-20      2
# 3             0  64900000.0       159.0           2015-07-24      3
# 4             2  10000000.0       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 0            2.70          16.0         51.0      8         False   False
# 1            2.72          11.0         18.6      1         False   False
# 2            2.72           5.0         34.3      4         False   False
# 3            2.72          14.0          NaN      9         False   False
# 4            3.03          14.0         32.0     13         False   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %%
data['years_exposition'].value_counts()
# Out:
# 2018    8519
# 2017    8190
# 2019    2879
# 2016    2783
# 2015    1191
# 2014     137
# Name: years_exposition, dtype: int64

# %% [markdown]
# # Вывод.

# %% [markdown]
# Очевидно, что количество предложений на рынке недвижимости было пиковым значением в 2017 и 2018 годах, а вот в 2019 количество предложений сократилось в 4 раза и вернулось на уровень 2016 года.

# %% [markdown]
# # Разделим на группы этажи квартир и добавим их в таблицу. Варианты: первый, последний, другой.

# %% [markdown]
# Новый столбец назовём group.

# %%
last_floor = data.query('floors_total/floor == 1')

# %%
data['group'] = data['floor']

# %%
data.loc[data['group'] == 1, 'group'] = 'Первый'

# %%
data.loc[last_floor.index, 'group'] = 'Последний'

# %%
data.loc[(data['group'] != 'Первый') & (data['group']!='Последний'), 'group'] = 'Другой'

# %%
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0           2019-03-07      3
# 1             7   3350000.0        40.4           2018-12-04      1
# 2            10   5196000.0        56.0           2015-08-20      2
# 3             0  64900000.0       159.0           2015-07-24      3
# 4             2  10000000.0       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 0            2.70          16.0         51.0      8         False   False
# 1            2.72          11.0         18.6      1         False   False
# 2            2.72           5.0         34.3      4         False   False
# 3            2.72          14.0          NaN      9         False   False
# 4            3.03          14.0         32.0     13         False   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %%
data['group'].value_counts()
# Out:
# Другой       17446
# Последний     3361
# Первый        2892
# Name: group, dtype: int64

# %% [markdown]
# # Вывод.

# %% [markdown]
# Судя по количеству предложений, более актуальны квартиры на любом этаже кроме первого и последнего.

# %% [markdown]
# # Посчитаем и добавим в таблицу соотношение жилой и общей площади, а также отношение площади кухни к общей.

# %%
data['attitude_liv/total'] = (data['living_area']/data['total_area']).round(2)

# %%
data['attitude_kitch/total'] = (data['kitchen_area']/data['total_area']).round(2)

# %% [markdown]
# Проверям результат

# %%
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0           2019-03-07      3
# 1             7   3350000.0        40.4           2018-12-04      1
# 2            10   5196000.0        56.0           2015-08-20      2
# 3             0  64900000.0       159.0           2015-07-24      3
# 4             2  10000000.0       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 0            2.70          16.0         51.0      8         False   False
# 1            2.72          11.0         18.6      1         False   False
# 2            2.72           5.0         34.3      4         False   False
# 3            2.72          14.0          NaN      9         False   False
# 4            3.03          14.0         32.0     13         False   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %%
data['attitude_liv/total'].mean().round(2)
# Out:
# 0.56

# %%
data['attitude_kitch/total'].mean().round(2)
# Out:
# 0.19

# %% [markdown]
# # Промежуточный вывод.

# %% [markdown]
# По среднестатисическим данным площадь кухни занимает практически 20% от общей площади, а жилая площадь только половину, это говорит о том, что в основном в продаже 1-2 комнатные квартиры с небольшой кухней.

# %% [markdown]
# # Вывод.

# %% [markdown]
# По результату проведённого анализа нельзя не заметить, что активные продажи жилья начались с 2017 года, а предложения первого и последнего этажей в сумме по количеству объявлений уступает любому другому больше чем в три раза от всего количества объявлений.
# В среднем, жилая площадь предложенных квартир знимает всего половину от общей площади, в то время как площадь кухни доходит до 20% от общей площади.
# При всём этом, средняя цена за м2 достигает 100 тыс.руб.

# %% [markdown]
# ### Проведите исследовательский анализ данных

# %% [markdown]
# # Изучим следующие параметры:площадь, цена, число комнат, высота потолков. Построим гистограммы для каждого параметра.

# %% [markdown]
# Смотрим площадь.

# %%
print('Диаграмма размаха площади квартиры')
data.boxplot(column=['total_area'], figsize=(10,5), grid=True)
plt.ylabel('Площадь квартиры в метрах')
plt.show()
# Out:
# Диаграмма размаха площади квартиры

# %%
data['total_area'].describe()
# Out:
# count    23699.000000
# mean        60.348651
# std         35.654083
# min         12.000000
# 25%         40.000000
# 50%         52.000000
# 75%         69.900000
# max        900.000000
# Name: total_area, dtype: float64

# %% [markdown]
# Отсечём чрезмерно выбивающиеся значения согласно распределению данных ящика с усами, площадь свыше 100м2 для дальнейшей статистики нам не интересна.

# %%
good_data = data.query('total_area < 100')

# %%
print('Диаграмма размаха площади квартиры после отсечения выбивающихся значений')
good_data.boxplot(column=['total_area'], figsize=(9,5), grid=True)
plt.ylabel('площадь квартиры в квадратных метрах')
plt.show()
# Out:
# Диаграмма размаха площади квартиры после отсечения выбивающихся значений

# %% [markdown]
# Построим гистограмму.

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
good_data.sort_values(by='total_area', ascending=True).plot(kind='hist', y='total_area', title='Распределение предложений квартир по площади', bins=100, figsize=(15,5), grid=True)
plt.xlabel('Площадь квартиры в кв.метрах')
plt.ylabel('Количество предложений')
plt.show()

# %% [markdown]
# Смотрим цену.

# %%
print('Диаграмма размаха цены предложений')
good_data.boxplot('last_price')
plt.ylabel('цена на момент снятия с публикации')
plt.show()
# Out:
# Диаграмма размаха цены предложений

# %% [markdown]
# Отбросим выбивающиеся значения по цене, т.к. они будут мешать при построении графика, а также усложнят анализ и прочтение данных с гистограммы.
# Очевидно, что стоимость квартир свыше 9 млн. встречается редко данных, отсечём лишнее.

# %%
good_data = good_data.query('last_price < 9000000')

# %%
good_data.plot(kind='hist', y='last_price', title='Распределение предложений квартир по цене',grid=True, bins=50, figsize=(15,5))
plt.ylabel('количество предложений')
plt.xlabel('цена на момент снятия с публикации')
plt.show()

# %% [markdown]
# Из графика хорошо виден ценовой сегмент квартир в районе 4 млн.руб.

# %% [markdown]
# Смотрим число комнат.

# %%
good_data.plot(kind='hist',y='rooms',title='Распределение предложений по количеству комнат',grid=True, bins=50, figsize=(5,8))
plt.xlabel('Количество комнат')
plt.ylabel('Количество предложений')
plt.show()

# %% [markdown]
# Смотрим высоту потолков.

# %%
print('Диаграмма размаха высоты потолков')
good_data.boxplot(column=['ceiling_height'], figsize=(8,5), grid=True)

plt.ylabel('Высота потолков')
plt.show()
# Out:
# Диаграмма размаха высоты потолков

# %% [markdown]
# Основываясь на графике "ящика с усами", отсечём квартиры с потолками свыше 2,9 метра, а так же ниже 2,4 метра.

# %%
good_data = good_data.query('ceiling_height < 2.9 and ceiling_height > 2.4')
good_data.plot(kind='hist',y='ceiling_height',grid=True, bins=10, figsize=(10,5),title='Распределение предложений по высоте потолков')
plt.xlabel('Высота потолоков')
plt.ylabel('Количество предложений')
plt.show()

# %% [markdown]
# # Вывод.

# %% [markdown]
# По результату проведённого анализа площади, цены, числа комнат и высоты потолков, однозначно можно сказать, что подавляющее большинство объявлений о продаже квартир составляют 1-2 комнатные квартиры в ценовом диапазоне 4 млн.руб и высотой потолков в 2,75 метра.

# %% [markdown]
# # Изучим время продажи квартиры. Построим гистограмму. Посчитаем среднее и медиану.

# %%
good_data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 1             7   3350000.0        40.4           2018-12-04      1
# 2            10   5196000.0        56.0           2015-08-20      2
# 5            10   2890000.0        30.4           2018-09-10      1
# 6             6   3700000.0        37.3           2017-11-02      1
# 7             5   7915000.0        71.6           2019-04-18      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 1            2.72          11.0         18.6      1         False   False
# 2            2.72           5.0         34.3      4         False   False
# 5            2.72          12.0         14.4      5         False   False
# 6            2.72          26.0         10.6      6         False   False
# 7            2.72          24.0          NaN     22         False   False
#
#    open_plan  kitchen_area  balcony              locality_name  \
# ...

# %%
print('Диаграмма размаха времени продажи квартиры')
good_data.boxplot('days_exposition')
plt.ylabel('Время продажи квартиры')
plt.show()
# Out:
# Диаграмма размаха времени продажи квартиры

# %% [markdown]
# Значение по количеству дней в продаже свыше 250 лучше отсечь, т.к. это редкие, скорее всего, квартиры с нестандартной планировкой и такие квартиры могут продаваться очень долго, для статистики они нам не нужны, т.к. сильно меняют сренее значение по сроку продажи квартир.

# %%
good_data = good_data.query('days_exposition < 250')

# %%
good_data['days_exposition'].agg(['mean','median'])
# Out:
# mean      80.930545
# median    60.000000
# Name: days_exposition, dtype: float64

# %%
good_data.plot(kind='hist',y='days_exposition',title='Распределение количества продаж по времени', bins=100, figsize=(10,5))
plt.xlabel('Сколько дней было размещено объявление (от публикации до снятия)')
plt.ylabel('Количество объявлений')
plt.show()

# %% [markdown]
# # Вывод.

# %% [markdown]
# В среднем продажа среднестатистичекой квартиры занимает 2-3 месяца в зависимотсти от сопутствующих факторов(площади, цены, удалённости от центра).

# %% [markdown]
# # Изучим, зависит ли цена от площади, числа комнат, удалённости от центра.

# %%
pd.options.mode.chained_assignment = None
good_data['city_centers_nearest'] = good_data['city_centers_nearest']/1000
(good_data
    
     .pivot_table(index='last_price', values=['total_area','rooms','city_centers_nearest'])
     .plot(style='o',grid=True, figsize=(12, 5), title='График зависимости цены от площади, числа комнат, удалённости от центра')
)
plt.xlabel('Цена на момент снятия с публикации')
plt.ylabel('Удалённость от центра\n Число комнат\n Площадь')
plt.show()

# %% [markdown]
# # Изучим зависимость цены от того, на каком этаже расположена квартира: первом, последнем или другом.

# %%
(good_data
     .pivot_table(index='group', values='last_price').sort_values(by='last_price', ascending=True)
     .plot(grid=True, figsize=(9, 5),linewidth=3, title='Зависимость цены от этажа расположения квартиры')
)
plt.xlabel('Этаж расположения квартиры')
plt.ylabel('Цена')
plt.show()

# %%
good_data.pivot_table(index='group',values='last_price',aggfunc='count').plot.pie(y='last_price', figsize=(7,7), label='', title='График количественного отношения распределения предложений в зависимости от этажа')
plt.show()

# %% [markdown]
# # Вывод.

# %% [markdown]
# Глядя на графики становится очевидно, что ценится любой другой этаж здания кроме первого и последнего, как по цене, так и по количеству предложений на рынке.
# А так же очевидна зависимость цены от удалённости от центра и площади квартиры, чем квартира больше и ближе к центру, тем цена выше.
# Чего нельзя однозначно сказать о количестве комнат, здесь график цены меняется не так значительно.

# %% [markdown]
# # Изучим зависимость цены от даты размещения: дня недели, месяца и года.

# %%
(good_data
    
     .pivot_table(index='day_of_week_exposition', values=['last_price'])
     .plot(grid=True, figsize=(10, 5),linewidth=3,title='Зависимость цены от даты размещения')
)
plt.xlabel('День размещения')
plt.ylabel('Цена')

plt.show()

# %%
(good_data
    
     .pivot_table(index='month_exposition', values=['last_price'])
     .plot(grid=True, figsize=(10, 5),linewidth=3, title='Зависимость цены от месяца размещения')
)
plt.xlabel('Месяц размещения')
plt.ylabel('Цена')

plt.show()

# %%
(good_data
    
     .pivot_table(index='years_exposition', values=['last_price'])
     .plot(grid=True, figsize=(10, 5),linewidth=3,title='зависимость цены от года размещения')
     
)
plt.xlabel('Год размещения')
plt.ylabel('Цена')
plt.show()

# %% [markdown]
# # Вывод.

# %% [markdown]
# Объявления размещённые до четверга имеют большую цену, чем в другие дни недели.
# #На графике помесячного размещения объявлений хорошо просматирваются два падения - это середина и конец года, в эти месяцы лучше квартиры не продавать, т.к. средняя стоимость ранка будет ниже чем в другие месяцы.
# По годовой тенденции наблюдается падение в стоимости жилья в 2015-2017 годах и резкий взлёт стоимости начиная с 2018 года, что вызвано скорей всего большим спросом на рынке недвижимости.

# %% [markdown]
# # Выберем 10 населённых пунктов с наибольшим числом объявлений.

# %%
data_top_10 = data.pivot_table(index='locality_name', values=['first_day_exposition'], aggfunc='count').sort_values(by='first_day_exposition', ascending=False).head(10)
data_top_10.columns=['number_of_ads']
data_top_10
# Out:
#                    number_of_ads
# locality_name
# санкт-петербург            15721
# посёлок мурино               556
# посёлок шушары               440
# всеволожск                   398
# пушкин                       369
# колпино                      338
# посёлок парголово            327
# гатчина                      307
# деревня кудрово              299
# выборг                       237

# %% [markdown]
# # Вывод.

# %% [markdown]
# Очевидный лидер по количеству объявлений это "Санкт_Петербург", остальные номинанты ТОП-10 расположены по области города примерно с равным количеством объявлений.

# %% [markdown]
# # Посчитаем среднюю цену квадратного метра в этих населённых пунктах.

# %%
data_top_10['cost_per_meter_mean'] = data.pivot_table(index='locality_name', values='price_per_square_meter', aggfunc='mean')
data_top_10_s = data_top_10.style.format({'cost_per_meter_mean':'{:.2f} ₽'})
data_top_10_s = data_top_10.sort_values(by = 'cost_per_meter_mean', ascending=False)
data_top_10_s
# Out:
#                    number_of_ads  cost_per_meter_mean
# locality_name
# санкт-петербург            15721        114848.565231
# пушкин                       369        103125.373984
# деревня кудрово              299         92473.086957
# посёлок парголово            327         90175.489297
# посёлок мурино               556         85681.305755
# посёлок шушары               440         78676.904545
# колпино                      338         75424.150888
# гатчина                      307         68745.693811
# всеволожск                   398         68654.007538
# выборг                       237         58141.489451

# %% [markdown]
# # Вывод.

# %% [markdown]
# По средней стоимости за квадратный метр жилья можно сказать, что малое количество объявлений не сильно влияет на цену м2. Так, например, Пушкин и посёлок Парголово имеют практически ту же цену в 100т.р. за м2 что и жилплощадь в Санкт-Петербурге.

# %% [markdown]
# # Выделим среди них населённые пункты с самой высокой и низкой стоимостью жилья.

# %% [markdown]
# Cамая высокая стоимость.

# %%
data_top_10_s[data_top_10_s['cost_per_meter_mean'] == data_top_10_s['cost_per_meter_mean'].max()]
# Out:
#                  number_of_ads  cost_per_meter_mean
# locality_name
# санкт-петербург          15721        114848.565231

# %% [markdown]
# Здесь видно, что самая высокая стоимость жилья из 10 населённых пунктов с наибольшим числом объявленийв Санкт-Петербурге.

# %%
data_top_10_s.sort_values('locality_name', ascending = False).head(10)
# Out:
#                    number_of_ads  cost_per_meter_mean
# locality_name
# санкт-петербург            15721        114848.565231
# пушкин                       369        103125.373984
# посёлок шушары               440         78676.904545
# посёлок парголово            327         90175.489297
# посёлок мурино               556         85681.305755
# колпино                      338         75424.150888
# деревня кудрово              299         92473.086957
# гатчина                      307         68745.693811
# выборг                       237         58141.489451
# всеволожск                   398         68654.007538

# %% [markdown]
# Cамая низкая стоимость.

# %%
data_top_10_s[data_top_10_s['cost_per_meter_mean'] == data_top_10_s['cost_per_meter_mean'].min()]
# Out:
#                number_of_ads  cost_per_meter_mean
# locality_name
# выборг                   237         58141.489451

# %% [markdown]
# Самая низкая стоимость в Выборге.

# %%
data_top_10_s.sort_values('locality_name', ascending = False).head(10)
data_top_10_s
# Out:
#                    number_of_ads  cost_per_meter_mean
# locality_name
# санкт-петербург            15721        114848.565231
# пушкин                       369        103125.373984
# деревня кудрово              299         92473.086957
# посёлок парголово            327         90175.489297
# посёлок мурино               556         85681.305755
# посёлок шушары               440         78676.904545
# колпино                      338         75424.150888
# гатчина                      307         68745.693811
# всеволожск                   398         68654.007538
# выборг                       237         58141.489451

# %% [markdown]
# Смотрим.

# %%
data_top_10.sort_values('cost_per_meter_mean', ascending = True, inplace = True,)
data_top_10.plot(y = 'cost_per_meter_mean', kind = 'barh', legend = False, title = 'Населённые пункты с самой высокой и низкой стоимостью жилья')
plt.show()

# %% [markdown]
# # Вывод.

# %% [markdown]
# Самая низкая стоимость жилья из нашей ТОП-10 расположена в Выборге, а на первом месте расположился Санкт-Петребург, с незначительным отрывом от Пушкино.

# %% [markdown]
# # Изучим предложения квартир: выделим квартиры в Санкт-Петербурге ('locality_name').

# %% [markdown]
# Выясним, какая область входит в центр.

# %%
local_spb = data.loc[data['locality_name'] == 'санкт-петербург']

# %%
local_spb['city_centers_nearest'].isna().sum()
# Out:
# 61

# %%
local_spb = local_spb.dropna(subset = ['city_centers_nearest'])

# %% [markdown]
# Создадим столбец с расстоянием до центра в километрах и округлим их до целых значений.

# %%
local_spb['city_centers_nearest_km'] = (local_spb['city_centers_nearest']/1000).round().astype(int)

# %%
local_spb['city_centers_nearest_km'].describe()
# Out:
# count    15660.000000
# mean        11.596041
# std          4.863594
# min          0.000000
# 25%          8.000000
# 50%         12.000000
# 75%         15.000000
# max         29.000000
# Name: city_centers_nearest_km, dtype: float64

# %%
print('Диаграмма размаха удалённости от центра')
local_spb.boxplot('city_centers_nearest_km')

plt.ylabel('Километры от центра города')
plt.show()
# Out:
# Диаграмма размаха удалённости от центра

# %%
local_spb = local_spb.loc[local_spb['city_centers_nearest_km'] < 24]

# %% [markdown]
# # Вывод.

# %% [markdown]
# Очевидно, что город Санкт-Петрбург очень большой, но даже для него расстояние больше 24 км от центра не может считаться центром города, по-этому мы отсекли мешающие статисткие и анализу данные.

# %% [markdown]
# # Посчитаем среднюю цену для каждого километра.

# %%
local_spb.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0           2019-03-07      3
# 2            10   5196000.0        56.0           2015-08-20      2
# 3             0  64900000.0       159.0           2015-07-24      3
# 4             2  10000000.0       100.0           2018-06-19      2
# 7             5   7915000.0        71.6           2019-04-18      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 0            2.70          16.0         51.0      8         False   False
# 2            2.72           5.0         34.3      4         False   False
# 3            2.72          14.0          NaN      9         False   False
# 4            3.03          14.0         32.0     13         False   False
# 7            2.72          24.0          NaN     22         False   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %%
mean_cost_per_km = local_spb['last_price'].sum()/local_spb['city_centers_nearest_km'].sum()
print('Средняя цена для каждого километра составляет {:.0f} ₽'.format(mean_cost_per_km))
# Out:
# Средняя цена для каждого километра составляет 701890 ₽

# %% [markdown]
# Построим график: он будет показывать, как цена зависит от удалённости от центра. А так же определим границу центральной зоны.

# %%
local_spb.pivot_table(index = 'city_centers_nearest_km', values = 'last_price', aggfunc = 'mean').plot(figsize = (10,5), grid = True, linewidth = 3, title = 'График зависимости цены от удалённости от центра')
plt.xlabel('Километры от центра города')
plt.ylabel('Средняя стоимость предложения')
plt.show()

# %% [markdown]
# Видно, что падение цены на графике сильно изменилось при достижении значения в 9-10 км, это говорит нам, что центральным районом можно считать все квартиры в удалении от центра не более чем на 10км.

# %% [markdown]
# # Выделим сегмент квартир в центре. Проанализируем эту территорию и изучим следующие параметры: площадь, цена, число комнат, высота потолков.

# %%
local_spb_centre = local_spb.loc[local_spb['city_centers_nearest_km']<10]

# %%
analysis_1=local_spb_centre[['locality_name','total_area','last_price','rooms','ceiling_height']].reset_index(drop=True)

# %%
analysis_1.corr()
# Out:
#                 total_area  last_price     rooms  ceiling_height
# total_area        1.000000    0.643813  0.750790        0.314814
# last_price        0.643813    1.000000  0.351014        0.181108
# rooms             0.750790    0.351014  1.000000        0.273154
# ceiling_height    0.314814    0.181108  0.273154        1.000000

# %%
analysis_1.describe()
# Out:
#         total_area    last_price        rooms  ceiling_height
# count  4715.000000  4.715000e+03  4715.000000     4715.000000
# mean     86.437506  1.327110e+07     2.671050        2.917637
# std      56.839196  2.224446e+07     1.393877        0.335133
# min      12.000000  1.219000e+04     0.000000        2.000000
# 25%      51.000000  5.954074e+06     2.000000        2.720000
# 50%      72.600000  8.500000e+06     3.000000        2.750000
# 75%     102.000000  1.307500e+07     3.000000        3.070000
# max     900.000000  7.630000e+08    19.000000        6.000000

# %%
pd.plotting.scatter_matrix(analysis_1, figsize=(10, 10)) 
plt.show()

# %% [markdown]
# # Вывод.

# %% [markdown]
# Из приведённых графиков становится очевидно, что основной сегмент квартир в центре города занимают 2-3 комнатные квартиры, площадью до 73 кв.метров, с потолками 2,75 средней ценой до 8,5 млн. рублей.

# %% [markdown]
# # Выделим факторы, которые влияют на стоимость квартиры(число комнат, этаж, удалённость от центра, дата размещения объявления).

# %%
analysis_2=local_spb_centre[['last_price','rooms','floor','city_centers_nearest_km','first_day_exposition']]
pd.plotting.scatter_matrix(analysis_2, figsize=(10, 10))
plt.show()

# %% [markdown]
# Определим зависимость цены от даты размещения объявления при помощи графика.

# %%
local_spb_centre.pivot_table(index=['day_of_week_exposition','month_exposition','years_exposition'], values='last_price', aggfunc='mean').sort_values(by='years_exposition').plot(grid=True,linewidth=3, alpha=0.7, label='2015',figsize=(15,5), title='Зависимость цены от даты размещения объявления')

plt.xlabel('Дата размещения объявления')
plt.ylabel('Цена')
plt.show()

# %% [markdown]
# # Вывод.

# %% [markdown]
# В целом из графиков можно сделать вывод о том, что цена объявелния квартир в центре города не зависит от удалённости от центра, зависимость цены менятся только от площади и количесва комнат, так же ценятся квартиры в центре города не выше 10 этажа. Изучив зависимость этажности и удаления от центра можно заметить, что чем дальше от центра города, тем выше этаж квартиры в объявлении. А вот по дате размещения объявления заметен основной пик в стоимости жилья в 2015-2016 годах с плавным снижением к 2019 году, в то время как по остальным предложениям стоимость жилья за пределами центра активно растёт начиная с 2017 года.

# %% [markdown]
# ### Общий вывод

# %% [markdown]
# Подводя итог проделанной работы по подготовке данных к анализу, мы столкнулись с пропущенными значениями и обработали их где это необходимо. Заменили типы данных для удобной работы.
# Посчитали и добавили в таблицу цену квадратного метра жилья, вывели из даты дни недели, месяцы и года размещения объявлений, добавили категории по этажам квартир. Изучили параметры на наличие выбивающихся значений, такие как: площадь, цена, число комнат, высота потолков. Были определены аномалии в данных параметрах. Также, мы выявили при помощи диаграммы размаха, что нормальные значения продажи квартир варьируются от 1 до 600 дней. Мы выявили, что на стоимость квадратного метра квартиры больше всего влияют количество комнат, этаж, близость к центру. Незначительно на стоимость квадратного метра влияют день, месяц, год размещения и общая площадь. Также понятно, что на стоимость квадратного метра квартиры больше всего влияют количество комнат, этаж квартиры, близость к центру. Незначительно на стоимость квадратного метра влияют день, месяц, год размещения и общая площадь. Также важно учитывать, что, рассматривая среднюю стоимость квартир в 2014-2019 годах, мы не делали сегментацию рынка, а лишь смотрели средние показатели по рынку в целом. Т.е. возможно, что цены на аналогичные квартиры в разных годах вели себя абсолютно по-разному. Т.е., например, в то время когда средняя стоимость метра по рынку в 2016-2017 годах была наиболее низкой, какие-то аналогичные прошлым годам квартиры могли и не падать в цене, а наоборот дорожать.
#
# Обнаружены пропуски в датасете.
# Кол-во столбцов с пропусками 14 (всего в датасете 22 столбца).
# Явных дубликатов в датаесете не было обнаружено.
# Замечены аномалии, к примеру, минимальное значение потолка 1 метр, а максимальное 100 метров.
# Найдены пропуски, дубликаты и аномалии в датасете.
# Была проведена работа по заполнению пропусков, удаление ненужных строк из датасета.
# Аномалии и дубликаты обработаны.
# Заменены неявные дубликаты (раньше названия населенных пунктов повторялись из-за разной записи е-ё и так далее).
# Столбец с датой приведен к правильному формату.
# Пропуски в столбце с высотой потолков приравняли к средней.
# Проработаны пропуски в столбце living area, они составляли ~8 процентов от датасета.
# Замена на булев тип данных в столбцах, где это необходимо.
# Пропуски в kitchen area исправлены и заменены средним значением.
# Пропуски и неправдоподобные значения в living area и living area заменены на None.
#
# В датафрейм добавлены новые показатели:
# отношение кухни и жилой площади к общей площади помещения, цена за кв метр, день, месяц и год публикации объявлений, категория этажа.
#
# Общая площадь:
# Данные распределены нормально, есть выбросы но они не сильно влияют на данные.
# Цена:
# Данные также распределены нормально, видны выбросы, но они также не сильно влияют на результат, общая картина ясна.
# Число комнат:
# На диограмме видно, что бóльшее кол-во объявлений – это квартиры с 1 или 2 комнатами. Квартир с 7 комнатами как и ожидалось меньше всех. Распределение нормальное.
# Высота потолков:
# Выбросы не сильно влияют на распределение. Данные нормальные и представляют собой понятную картину относительно высоты потолков.
#
# Среднее значение длительности размещения квартиры на площадке Яндекса равняется 180 дням, а медиана равна 95 дням. Выявлены выбивающиеся значения. Аномалии находятся на 45, 60, 7, 30, 90 днях.
#
# Срок продажи квартиры:
# Чаще всего квартиру продают за 95 дней. Если меньше 45 дней, то это быстро, если дольше 230 дней - это долго.
# Есть большое число квартир, проданных всего за несколько дней после публикации.
# Также есть варианты, которые продавались несколько десятков месяцев.
#
# Факторы, влияющие на стоимость:
#
# На стоимость больше влияет площадь квартиры, нежели число комнат. Т.е. могут быть дорогие квартиры с малым числом комнат, но где комнаты просторные.
# Первый этаж значительно дешевле остальных вариантов. Также стоимость квартиры на последнем этаже ниже, чем на остальных, кроме первого.
#
# Выявлена стоимость квадратного метра в топ-10 населённых пунктов:
#
# Дороже всего квадратный метр в Санкт-Петербурге - 114848
#
# Дешевле всего квадратный метр в Выборге - 58141
#
# Факторы, влияющие на стоимость в центре Санкт-Петербурга:
#
# В центре города практически нет разницы, насколько квартира удалена от условного центра города.
# В центре города последний этаж практически не влияет на стоимость квартиры, в отличие от остального города.
# В центре есть очень дорогие однокомнатные квартиры.
#
# Итоги: На стоимость квадратного метра квартиры больше всего влияют: общая площадь, этажность, расстояние до центра и год публикации.Незначительно на стоимость квадратного метра влияют день, месяц и кол-во комнат. Центром Петербурга можно считать квартиры, находящиеся в радиусе 7 км. Разница между общим датасетом и квартирами в центре СПб различается.
